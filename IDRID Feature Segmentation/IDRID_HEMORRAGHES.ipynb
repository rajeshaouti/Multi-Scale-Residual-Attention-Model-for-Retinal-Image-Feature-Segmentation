# %% [markdown]
# # Imports

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
import torchvision.transforms as transforms
from torchvision import datasets
from PIL import Image
import os
import numpy as np
import matplotlib.pyplot as plt
import albumentations as A
from albumentations.pytorch import ToTensorV2
from PIL import Image
from torchinfo import summary
import torch.nn.functional as F
from operator import add
# Out:
# /home/raouti/.local/lib/python3.11/site-packages/albumentations/__init__.py:13: UserWarning: A new version of Albumentations is available: 2.0.3 (you have 1.4.14). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)
# Out:
# cuda

# %%
PATCH_SIZE = 256
OVERLAP = '50'

# %% [markdown]
# # Model

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class UNet(nn.Module):
    def __init__(self):
        super(UNet, self).__init__()
        
        # Downsampling (encoder) blocks
        self.enc1 = MultiPathBlock(in_channels = 3, out_channels = 16, stride=1, dilation= [1,3,5,7])
        self.enc2 = MultiPathBlock(in_channels = 16, out_channels = 32, stride=1, dilation= [1,3,5])
        self.enc3 = MultiPathBlock(in_channels = 32, out_channels = 64, stride=1, dilation= [1,3])
        self.enc4 = MultiPathBlock(in_channels = 64, out_channels = 128, stride=1, dilation= [1])

        # Bottleneck
        self.bottleneck = self.conv_block(128, 256)

        # Upsampling (decoder) blocks
        self.upconv4 = nn.ConvTranspose2d(256, 128, kernel_size=2, stride=2)
        self.dec4 = MultiPathBlock(in_channels = 128 + 128, out_channels = 128, stride=1, dilation= [1])

        self.upconv3 = nn.ConvTranspose2d(128, 64, kernel_size=2, stride=2)
        self.dec3 = MultiPathBlock(in_channels = 64 + 64, out_channels = 64, stride=1, dilation= [1,3])

        self.upconv2 = nn.ConvTranspose2d(64, 32, kernel_size=2, stride=2)
        self.dec2 = MultiPathBlock(in_channels = 32 + 32, out_channels = 32, stride=1, dilation= [1,3,5])

        self.upconv1 = nn.ConvTranspose2d(32, 16, kernel_size=2, stride=2)
        self.dec1 = MultiPathBlock(in_channels = 16 + 16, out_channels = 16, stride=1, dilation= [1,3,5,7])

        # Final output layer
        self.final_conv = nn.Conv2d(16, 1, kernel_size=1)


        # Intermediate Layers
        self.out_2 = self.conv_block_intermediate_output(32, 1)
        self.out_3 = self.conv_block_intermediate_output(64, 1)
        self.out_4 = self.conv_block_intermediate_output(128, 1)
    
    def conv_block_intermediate_output(self, in_channels, out_channels):
        return nn.Conv2d(in_channels, out_channels, kernel_size=1)
    def conv_block(self, in_channels, out_channels):
        block = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size = 3, dilation=1, padding = 1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels,  kernel_size = 3, dilation=1,padding = 1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True)
        )
        return block

    def forward(self, x):
        # Encoder path
        e1 = self.enc1(x)
        e2 = self.enc2(F.max_pool2d(e1, 2))
        e3 = self.enc3(F.max_pool2d(e2, 2))
        e4 = self.enc4(F.max_pool2d(e3, 2))

        # Bottleneck
        b = self.bottleneck(F.max_pool2d(e4, 2))

        # Decoder path
        d4 = self.upconv4(b)
        d4 = torch.cat((d4, e4), dim=1)
        d4 = self.dec4(d4)
        out_d4 = self.out_4(d4)  

        d3 = self.upconv3(d4)
        d3 = torch.cat((d3, e3), dim=1)
        d3 = self.dec3(d3)
        out_d3 = self.out_3(d3)  

        d2 = self.upconv2(d3)
        d2 = torch.cat((d2, e2), dim=1)
        d2 = self.dec2(d2)
        out_d2 = self.out_2(d2) 

        d1 = self.upconv1(d2)
        d1 = torch.cat((d1, e1), dim=1)
        d1 = self.dec1(d1)

        # Final output
        out = self.final_conv(d1)
        return out, out_d4, out_d3, out_d2  

class StandardConvBlock(nn.Module):
    def __init__(self, in_channels, out_channels, stride=1, dilation=1):
        super(StandardConvBlock, self).__init__()
        self.conv = nn.Conv2d(
            in_channels, out_channels, kernel_size=3, stride=stride, padding=dilation, dilation=dilation, bias=False
        )
        self.bn = nn.BatchNorm2d(out_channels)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.conv(x)
        x = self.bn(x)
        x = self.relu(x)
        return x

class SinglePathBlock(nn.Module):
    def __init__(self,in_channels, out_channels, stride=1, dilation= 1):
        super(SinglePathBlock,self).__init__()
        
        self.single_path_block_1 =  nn.Sequential(
            StandardConvBlock(in_channels, out_channels, stride=stride, dilation=dilation),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(),
            )
        
        self.single_path_block_2 =  nn.Sequential(
            StandardConvBlock(out_channels, out_channels, stride=stride, dilation=dilation),
            nn.BatchNorm2d(out_channels),
            CBAM(out_channels),
            nn.ReLU(),
            )
        
        self.channel_modification = nn.Conv2d(in_channels,out_channels,kernel_size = 1)

    def forward(self,x):

        identity = x
        out_block_1 = self.single_path_block_1(x)
        
        if out_block_1.shape[1] != x.shape[1]:
            identity = self.channel_modification(x)
        
        out_block_2 = self.single_path_block_2(out_block_1)
        
        out_block_2 = out_block_2 + identity

        return out_block_2


class MultiPathBlock(nn.Module):
    def __init__(self, in_channels, out_channels, stride=1, dilation= [1, 3, 5, 7]):
        super(MultiPathBlock, self).__init__()
        
        self.parallel_paths = nn.ModuleList([
            SinglePathBlock(in_channels, out_channels, stride=1, dilation= d)
            for d in dilation
        ])

    def forward(self, x):
        out = 0
        for path in self.parallel_paths:
            out += path(x)

        return out

class CBAM(nn.Module):
    def __init__(self, channels, reduction_ratio=16, kernel_size=7):
        super(CBAM, self).__init__()
        self.channel_attention = nn.Sequential(
            nn.AdaptiveAvgPool2d(1),
            nn.Conv2d(channels, channels // reduction_ratio, kernel_size=1, bias=False),
            nn.ReLU(),
            nn.Conv2d(channels // reduction_ratio, channels, kernel_size=1, bias=False),
            nn.Sigmoid()
        )
        self.spatial_attention = nn.Sequential(
            nn.Conv2d(2, 1, kernel_size=kernel_size, stride=1, padding=kernel_size // 2, bias=False),
            nn.Sigmoid()
        )

    def forward(self, x):
        channel_attention = self.channel_attention(x)
        x = x * channel_attention
        max_pool = torch.max(x, dim=1, keepdim=True)[0]
        avg_pool = torch.mean(x, dim=1, keepdim=True)
        spatial_attention = self.spatial_attention(torch.cat([max_pool, avg_pool], dim=1))
        x = x * spatial_attention
        return x

# %%
MODEL = UNet()
(summary(model=MODEL,
          input_size=(32, 3, PATCH_SIZE, PATCH_SIZE),
          col_names=["input_size", "output_size", "num_params", "trainable"],
          col_width=20,
          row_settings=["var_names"]
  ))
# Out:
# =================================================================================================================================================
# Layer (type (var_name))                                           Input Shape          Output Shape         Param #              Trainable
# =================================================================================================================================================
# UNet (UNet)                                                       [32, 3, 256, 256]    [32, 1, 256, 256]    --                   True
# ├─MultiPathBlock (enc1)                                           [32, 3, 256, 256]    [32, 16, 256, 256]   --                   True
# │    └─ModuleList (parallel_paths)                                --                   --                   --                   True
# │    │    └─SinglePathBlock (0)                                   [32, 3, 256, 256]    [32, 16, 256, 256]   3,058                True
# │    │    └─SinglePathBlock (1)                                   [32, 3, 256, 256]    [32, 16, 256, 256]   3,058                True
# │    │    └─SinglePathBlock (2)                                   [32, 3, 256, 256]    [32, 16, 256, 256]   3,058                True
# │    │    └─SinglePathBlock (3)                                   [32, 3, 256, 256]    [32, 16, 256, 256]   3,058                True
# ├─MultiPathBlock (enc2)                                           [32, 16, 128, 128]   [32, 32, 128, 128]   --                   True
# │    └─ModuleList (parallel_paths)                                --                   --                   --                   True
# │    │    └─SinglePathBlock (0)                                   [32, 16, 128, 128]   [32, 32, 128, 128]   14,850               True
# │    │    └─SinglePathBlock (1)                                   [32, 16, 128, 128]   [32, 32, 128, 128]   14,850               True
# │    │    └─SinglePathBlock (2)                                   [32, 16, 128, 128]   [32, 32, 128, 128]   14,850               True
# ├─MultiPathBlock (enc3)                                           [32, 32, 64, 64]     [32, 64, 64, 64]     --                   True
# │    └─ModuleList (parallel_paths)                                --                   --                   --                   True
# │    │    └─SinglePathBlock (0)                                   [32, 32, 64, 64]     [32, 64, 64, 64]     58,530               True
# │    │    └─SinglePathBlock (1)                                   [32, 32, 64, 64]     [32, 64, 64, 64]     58,530               True
# ├─MultiPathBlock (enc4)                                           [32, 64, 32, 32]     [32, 128, 32, 32]    --                   True
# │    └─ModuleList (parallel_paths)                                --                   --                   --                   True
# │    │    └─SinglePathBlock (0)                                   [32, 64, 32, 32]     [32, 128, 32, 32]    232,674              True
# ├─Sequential (bottleneck)                                         [32, 128, 16, 16]    [32, 256, 16, 16]    --                   True
# │    └─Conv2d (0)                                                 [32, 128, 16, 16]    [32, 256, 16, 16]    295,168              True
# │    └─BatchNorm2d (1)                                            [32, 256, 16, 16]    [32, 256, 16, 16]    512                  True
# │    └─ReLU (2)                                                   [32, 256, 16, 16]    [32, 256, 16, 16]    --                   --
# │    └─Conv2d (3)                                                 [32, 256, 16, 16]    [32, 256, 16, 16]    590,080              True
# │    └─BatchNorm2d (4)                                            [32, 256, 16, 16]    [32, 256, 16, 16]    512                  True
# │    └─ReLU (5)                                                   [32, 256, 16, 16]    [32, 256, 16, 16]    --                   --
# ├─ConvTranspose2d (upconv4)                                       [32, 256, 16, 16]    [32, 128, 32, 32]    131,200              True
# ├─MultiPathBlock (dec4)                                           [32, 256, 32, 32]    [32, 128, 32, 32]    --                   True
# │    └─ModuleList (parallel_paths)                                --                   --                   --                   True
# │    │    └─SinglePathBlock (0)                                   [32, 256, 32, 32]    [32, 128, 32, 32]    478,434              True
# ├─Conv2d (out_4)                                                  [32, 128, 32, 32]    [32, 1, 32, 32]      129                  True
# ├─ConvTranspose2d (upconv3)                                       [32, 128, 32, 32]    [32, 64, 64, 64]     32,832               True
# ├─MultiPathBlock (dec3)                                           [32, 128, 64, 64]    [32, 64, 64, 64]     --                   True
# │    └─ModuleList (parallel_paths)                                --                   --                   --                   True
# │    │    └─SinglePathBlock (0)                                   [32, 128, 64, 64]    [32, 64, 64, 64]     119,970              True
# │    │    └─SinglePathBlock (1)                                   [32, 128, 64, 64]    [32, 64, 64, 64]     119,970              True
# ├─Conv2d (out_3)                                                  [32, 64, 64, 64]     [32, 1, 64, 64]      65                   True
# ├─ConvTranspose2d (upconv2)                                       [32, 64, 64, 64]     [32, 32, 128, 128]   8,224                True
# ├─MultiPathBlock (dec2)                                           [32, 64, 128, 128]   [32, 32, 128, 128]   --                   True
# │    └─ModuleList (parallel_paths)                                --                   --                   --                   True
# │    │    └─SinglePathBlock (0)                                   [32, 64, 128, 128]   [32, 32, 128, 128]   30,210               True
# │    │    └─SinglePathBlock (1)                                   [32, 64, 128, 128]   [32, 32, 128, 128]   30,210               True
# │    │    └─SinglePathBlock (2)                                   [32, 64, 128, 128]   [32, 32, 128, 128]   30,210               True
# ├─Conv2d (out_2)                                                  [32, 32, 128, 128]   [32, 1, 128, 128]    33                   True
# ├─ConvTranspose2d (upconv1)                                       [32, 32, 128, 128]   [32, 16, 256, 256]   2,064                True
# ├─MultiPathBlock (dec1)                                           [32, 32, 256, 256]   [32, 16, 256, 256]   --                   True
# │    └─ModuleList (parallel_paths)                                --                   --                   --                   True
# │    │    └─SinglePathBlock (0)                                   [32, 32, 256, 256]   [32, 16, 256, 256]   7,698                True
# │    │    └─SinglePathBlock (1)                                   [32, 32, 256, 256]   [32, 16, 256, 256]   7,698                True
# │    │    └─SinglePathBlock (2)                                   [32, 32, 256, 256]   [32, 16, 256, 256]   7,698                True
# │    │    └─SinglePathBlock (3)                                   [32, 32, 256, 256]   [32, 16, 256, 256]   7,698                True
# ├─Conv2d (final_conv)                                             [32, 16, 256, 256]   [32, 1, 256, 256]    17                   True
# =================================================================================================================================================
# Total params: 2,307,148
# Trainable params: 2,307,148
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 251.13
# =================================================================================================================================================
# Input size (MB): 25.17
# Forward/backward pass size (MB): 23775.38
# Params size (MB): 9.23
# Estimated Total Size (MB): 23809.77
# =================================================================================================================================================

# %%
train_image_dir = f'/scratch/raouti/FUNDUS_DATASETS/IDRID/IDRID_NOV_2024/PREPROCESSED/AUGMENTED/HE_FOLDER/PATCHIFY_512_256_{OVERLAP}_CLAHE_RGB/train/image/'
train_mask_dir =  f'/scratch/raouti/FUNDUS_DATASETS/IDRID/IDRID_NOV_2024/PREPROCESSED/AUGMENTED/HE_FOLDER/PATCHIFY_512_256_{OVERLAP}_CLAHE_RGB/train/mask/'
test_image_dir =  f'/scratch/raouti/FUNDUS_DATASETS/IDRID/IDRID_NOV_2024/PREPROCESSED/AUGMENTED/HE_FOLDER/PATCHIFY_512_256_{OVERLAP}_CLAHE_RGB/test/image/'
test_mask_dir =   f'/scratch/raouti/FUNDUS_DATASETS/IDRID/IDRID_NOV_2024/PREPROCESSED/AUGMENTED/HE_FOLDER/PATCHIFY_512_256_{OVERLAP}_CLAHE_RGB/test/mask/'

# %%
print(train_image_dir)
print(train_mask_dir)
print(test_image_dir)
print(test_mask_dir)
# Out:
# /scratch/raouti/FUNDUS_DATASETS/IDRID/IDRID_NOV_2024/PREPROCESSED/AUGMENTED/HE_FOLDER/PATCHIFY_512_256_50_CLAHE_RGB/train/image/
# /scratch/raouti/FUNDUS_DATASETS/IDRID/IDRID_NOV_2024/PREPROCESSED/AUGMENTED/HE_FOLDER/PATCHIFY_512_256_50_CLAHE_RGB/train/mask/
# /scratch/raouti/FUNDUS_DATASETS/IDRID/IDRID_NOV_2024/PREPROCESSED/AUGMENTED/HE_FOLDER/PATCHIFY_512_256_50_CLAHE_RGB/test/image/
# /scratch/raouti/FUNDUS_DATASETS/IDRID/IDRID_NOV_2024/PREPROCESSED/AUGMENTED/HE_FOLDER/PATCHIFY_512_256_50_CLAHE_RGB/test/mask/

# %%
img_testing = sorted(os.listdir(train_image_dir))
lab_testing = sorted(os.listdir(train_mask_dir))
print(len(img_testing))
img_path = os.path.join(train_image_dir,img_testing[10])
mask_path = os.path.join(train_mask_dir, lab_testing[10])
IMAGE = Image.open(img_path)
LAB = Image.open(mask_path)
# Out:
# 1908

# %%
image_transform = transforms.Compose([
    transforms.Resize((PATCH_SIZE, PATCH_SIZE)),
    transforms.ToTensor()
])

IMAGE_TESTING = image_transform(IMAGE)
LAB_TESTING = image_transform(LAB)

# %%
plt.imshow(IMAGE_TESTING.permute(1,2,0),cmap = 'gray')

# %%
plt.imshow(LAB_TESTING.permute(1,2,0),cmap = 'gray')

# %%
class SegmentationDataset(Dataset):
    def __init__(self, image_dir, mask_dir, transform=None):
        self.image_dir = image_dir
        self.mask_dir = mask_dir
        self.transform = transform
        self.images = os.listdir(image_dir)
        self.labels = os.listdir(mask_dir)
        self.images.sort()
        self.labels.sort()


    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_path = os.path.join(self.image_dir, self.images[idx])
        mask_path = os.path.join(self.mask_dir, self.labels[idx])
        image = Image.open(img_path)
        mask = Image.open(mask_path)
        image = np.array(Image.open(img_path))  
        mask = np.array(Image.open(mask_path).convert("L")) 

        if self.transform:
            transformed = self.transform(image=image, mask=mask)
            image = transformed['image'].float()/255
            mask = transformed['mask'].unsqueeze(0).float()/255

        return image, mask

# %%
train_transform = A.Compose([A.Resize(PATCH_SIZE,PATCH_SIZE),  
                                        ToTensorV2() 
                                        ])

val_transform = A.Compose([A.Resize(PATCH_SIZE,PATCH_SIZE),
                                    ToTensorV2() 
                                     ])


train_dataset = SegmentationDataset(image_dir=train_image_dir, mask_dir=train_mask_dir, transform=train_transform)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)

val_dataset = SegmentationDataset(image_dir=test_image_dir, mask_dir=test_mask_dir, transform=val_transform)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

# %%
img,lab= next(iter(train_loader))

# %%
plt.imshow(torch.permute(img[3],(1,2,0)),cmap = 'gray')

# %%
plt.imshow(torch.permute(lab[3],(1,2,0)),cmap = 'gray')

# %% [markdown]
# # Training

# %%
def train(model, loader, optimizer, criterion, device,scheduler):
    model.train()


    total_loss = 0
    len_loader = len(loader)
    max_grad_norm = 1

    for idx,(images, masks) in enumerate(loader):
        images, masks = images.to(device), masks.to(device)
        optimizer.zero_grad()


        outputs, out_d4, out_d3, out_d2 = model(images)       
        loss = LOSS_FUNC(outputs, out_d4, out_d3, out_d2, masks, criterion)

        
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
        
    print(f"_______________________Training - __________________________________")
    epoch_loss = total_loss/ len_loader
    return  epoch_loss

def validate(model, loader, criterion, device,scheduler):

    model.eval()
    total_loss = 0
    len_loader = len(loader)
    with torch.no_grad():
        for idx,(images, masks) in enumerate(loader):
            images, masks = images.to(device), masks.to(device)

            outputs, out_d4, out_d3, out_d2 = model(images)
            loss = LOSS_FUNC(outputs, out_d4, out_d3, out_d2, masks, criterion)

            
            total_loss += loss.item()
    scheduler.step(loss)
    print(f"_______________________Validation - __________________________________")
    epoch_loss = total_loss/ len_loader
    return  epoch_loss

# %% [markdown]
# # Loss Function

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class DiceLoss(nn.Module):
    def __init__(self, weight=None, size_average=True):
        super(DiceLoss, self).__init__()

    def forward(self, inputs, targets, smooth=1):

        inputs = torch.sigmoid(inputs)

        inputs = inputs.view(-1)
        targets = targets.view(-1)

        intersection = (inputs * targets).sum()
        dice = (2.*intersection + smooth)/(inputs.sum() + targets.sum() + smooth)

        return 1 - dice

class DiceBCELoss(nn.Module):
    def __init__(self, weight=None, size_average=True):
        super(DiceBCELoss, self).__init__()

    def forward(self, inputs, targets, smooth=1):

        inputs = torch.sigmoid(inputs)

        inputs = inputs.view(-1)
        targets = targets.view(-1)

        intersection = (inputs * targets).sum()
        dice_loss = 1 - (2.*intersection + smooth)/(inputs.sum() + targets.sum() + smooth)
        BCE = F.binary_cross_entropy(inputs, targets, reduction='mean')
        Dice_BCE = BCE + dice_loss

        return Dice_BCE

def LOSS_FUNC(segmentation_head, aux_out1, aux_out2, aux_out3, masks, criterion):
    loss_head = criterion(segmentation_head, masks)

    mask_aux_1_resized = F.interpolate(masks, size=aux_out1.shape[2:], mode='bilinear', align_corners=True)
    loss_aux1 = criterion(aux_out1, mask_aux_1_resized)

    mask_aux_2_resized = F.interpolate(masks, size=aux_out2.shape[2:], mode='bilinear', align_corners=True)
    loss_aux2 = criterion(aux_out2, mask_aux_2_resized)

    mask_aux_3_resized = F.interpolate(masks, size=aux_out3.shape[2:], mode='bilinear', align_corners=True)
    loss_aux3 = criterion(aux_out3, mask_aux_3_resized)

    total_loss = loss_head + (0.3 * loss_aux1) + (0.2 * loss_aux2) + (0.1 * loss_aux3)
    return total_loss

# %%
model_name = 'IDRID_HE'
checkpoint_name = f'RESULTS/{model_name}/RUN'
log_file_name = f'RESULTS/{model_name}/training_log.txt'
folder_path = f"RESULTS/{model_name}/"  
folder_path
# Out:
# 'RESULTS/IDRID_HE/'

# %%
import torch
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR
import torch.nn.utils as utils
from torch.optim.lr_scheduler import ReduceLROnPlateau


criterion = DiceBCELoss()
num_epochs = 100  
patience = 10  
num_runs = 10  
best_valid_losses = [] 

initial_lr = 0.001
weight_decay = 0.01 
momentum_value = 0.9
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

with open(log_file_name, 'w') as log_file:
        log_file.write(f"STARTING")
    
for run in range(num_runs):
    
    print(f"Starting run {run+1}/{num_runs}")
    print(f"MODEL INTIALIZATION")
    model = UNet().to(device)
    optimizer = optim.Adam(model.parameters(), lr=initial_lr, betas=(0.9, 0.999)) 
    scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=5, verbose=True)

    with open(log_file_name, 'a') as log_file:
        log_file.write(f"RUN NO {run+1}/{num_runs}\n")
        log_file.write("MODEL INTIALIZATION \n")

    best_valid_loss = float("inf")
    total_train_loss = []
    total_val_loss = []
    early_stopping_counter = 0 

    for epoch in range(num_epochs):
        train_loss = train(model, train_loader, optimizer, criterion, device, scheduler)
        valid_loss = validate(model, val_loader, criterion, device, scheduler)
        
        total_train_loss.append(train_loss)
        total_val_loss.append(valid_loss)
    
        if valid_loss < best_valid_loss:
            checkpoint_path = f"{checkpoint_name}_{run+1}.pth"
            print(f"Valid loss improved from {best_valid_loss:.3f} to {valid_loss:.3f}. Saving checkpoint: {checkpoint_path}")
            best_valid_loss = valid_loss
            torch.save(model.state_dict(), checkpoint_path)
            early_stopping_counter = 0 
        else:
            early_stopping_counter += 1
            print(f"No improvement in validation loss for {early_stopping_counter} epochs.")
    
        if early_stopping_counter >= patience:
            print(f"Stopping early after {epoch+1} epochs due to no improvement in validation loss.")
            break

        log_message = f'Epoch: {epoch+1:02} | Train Loss: {train_loss:.3f} | Val. Loss: {valid_loss:.3f}\n'
        print(log_message)
        
        with open(log_file_name, 'a') as log_file:
            log_file.write(log_message)
    
    best_valid_losses.append(best_valid_loss)
    best_log = f"Run {run+1} finished with best validation loss: {best_valid_loss:.3f}\n"
    print(best_log)

    with open(log_file_name, 'a') as log_file:
        log_file.write(best_log)

mean_valid_loss = np.mean(best_valid_losses)
std_valid_loss = np.std(best_valid_losses)
print(f"Mean best validation loss over {num_runs} runs: {mean_valid_loss:.3f}")
print(f"Std of best validation loss over {num_runs} runs: {std_valid_loss:.3f}")
# Out:
# Starting run 1/10
# MODEL INTIALIZATION
# /home/raouti/.local/lib/python3.11/site-packages/torch/optim/lr_scheduler.py:28: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn("The verbose parameter is deprecated. Please use get_last_lr() "
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from inf to 1.383. Saving checkpoint: RESULTS/IDRID_HE/RUN_1.pth
# Epoch: 01 | Train Loss: 1.442 | Val. Loss: 1.383
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 1.383 to 1.126. Saving checkpoint: RESULTS/IDRID_HE/RUN_1.pth
# Epoch: 02 | Train Loss: 0.991 | Val. Loss: 1.126
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 1.126 to 0.988. Saving checkpoint: RESULTS/IDRID_HE/RUN_1.pth
# Epoch: 03 | Train Loss: 0.811 | Val. Loss: 0.988
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 04 | Train Loss: 0.796 | Val. Loss: 1.066
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 2 epochs.
# Epoch: 05 | Train Loss: 0.713 | Val. Loss: 1.079
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 3 epochs.
# Epoch: 06 | Train Loss: 0.650 | Val. Loss: 1.438
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.988 to 0.902. Saving checkpoint: RESULTS/IDRID_HE/RUN_1.pth
# Epoch: 07 | Train Loss: 0.644 | Val. Loss: 0.902
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 08 | Train Loss: 0.632 | Val. Loss: 0.978
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.902 to 0.829. Saving checkpoint: RESULTS/IDRID_HE/RUN_1.pth
# Epoch: 09 | Train Loss: 0.575 | Val. Loss: 0.829
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 10 | Train Loss: 0.564 | Val. Loss: 0.934
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 2 epochs.
# Epoch: 11 | Train Loss: 0.526 | Val. Loss: 1.050
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 3 epochs.
# Epoch: 12 | Train Loss: 0.510 | Val. Loss: 1.020
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 4 epochs.
# Epoch: 13 | Train Loss: 0.490 | Val. Loss: 0.858
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 5 epochs.
# Epoch: 14 | Train Loss: 0.471 | Val. Loss: 0.854
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.829 to 0.812. Saving checkpoint: RESULTS/IDRID_HE/RUN_1.pth
# Epoch: 15 | Train Loss: 0.469 | Val. Loss: 0.812
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 16 | Train Loss: 0.457 | Val. Loss: 0.921
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 2 epochs.
# Epoch: 17 | Train Loss: 0.441 | Val. Loss: 1.007
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 3 epochs.
# Epoch: 18 | Train Loss: 0.415 | Val. Loss: 0.921
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 4 epochs.
# Epoch: 19 | Train Loss: 0.403 | Val. Loss: 0.886
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 5 epochs.
# Epoch: 20 | Train Loss: 0.391 | Val. Loss: 0.958
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 6 epochs.
# Epoch: 21 | Train Loss: 0.366 | Val. Loss: 0.839
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 7 epochs.
# Epoch: 22 | Train Loss: 0.358 | Val. Loss: 0.897
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 8 epochs.
# Epoch: 23 | Train Loss: 0.346 | Val. Loss: 0.853
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 9 epochs.
# Epoch: 24 | Train Loss: 0.346 | Val. Loss: 0.854
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 10 epochs.
# Stopping early after 25 epochs due to no improvement in validation loss.
# Run 1 finished with best validation loss: 0.812
#
# Starting run 2/10
# MODEL INTIALIZATION
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from inf to 1.351. Saving checkpoint: RESULTS/IDRID_HE/RUN_2.pth
# Epoch: 01 | Train Loss: 1.496 | Val. Loss: 1.351
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 1.351 to 1.212. Saving checkpoint: RESULTS/IDRID_HE/RUN_2.pth
# Epoch: 02 | Train Loss: 0.979 | Val. Loss: 1.212
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 1.212 to 1.007. Saving checkpoint: RESULTS/IDRID_HE/RUN_2.pth
# Epoch: 03 | Train Loss: 0.881 | Val. Loss: 1.007
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 04 | Train Loss: 0.808 | Val. Loss: 1.134
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 2 epochs.
# Epoch: 05 | Train Loss: 0.787 | Val. Loss: 1.155
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 3 epochs.
# Epoch: 06 | Train Loss: 0.760 | Val. Loss: 1.029
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 4 epochs.
# Epoch: 07 | Train Loss: 0.701 | Val. Loss: 1.118
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 1.007 to 1.004. Saving checkpoint: RESULTS/IDRID_HE/RUN_2.pth
# Epoch: 08 | Train Loss: 0.662 | Val. Loss: 1.004
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 09 | Train Loss: 0.643 | Val. Loss: 1.039
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 1.004 to 0.884. Saving checkpoint: RESULTS/IDRID_HE/RUN_2.pth
# Epoch: 10 | Train Loss: 0.597 | Val. Loss: 0.884
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.884 to 0.863. Saving checkpoint: RESULTS/IDRID_HE/RUN_2.pth
# Epoch: 11 | Train Loss: 0.580 | Val. Loss: 0.863
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 12 | Train Loss: 0.576 | Val. Loss: 0.879
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 2 epochs.
# Epoch: 13 | Train Loss: 0.561 | Val. Loss: 0.864
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.863 to 0.854. Saving checkpoint: RESULTS/IDRID_HE/RUN_2.pth
# Epoch: 14 | Train Loss: 0.546 | Val. Loss: 0.854
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 15 | Train Loss: 0.535 | Val. Loss: 0.866
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.854 to 0.854. Saving checkpoint: RESULTS/IDRID_HE/RUN_2.pth
# Epoch: 16 | Train Loss: 0.539 | Val. Loss: 0.854
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.854 to 0.841. Saving checkpoint: RESULTS/IDRID_HE/RUN_2.pth
# Epoch: 17 | Train Loss: 0.529 | Val. Loss: 0.841
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 18 | Train Loss: 0.526 | Val. Loss: 0.857
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 2 epochs.
# Epoch: 19 | Train Loss: 0.526 | Val. Loss: 0.863
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 3 epochs.
# Epoch: 20 | Train Loss: 0.520 | Val. Loss: 0.872
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 4 epochs.
# Epoch: 21 | Train Loss: 0.507 | Val. Loss: 0.854
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 5 epochs.
# Epoch: 22 | Train Loss: 0.510 | Val. Loss: 0.872
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.841 to 0.828. Saving checkpoint: RESULTS/IDRID_HE/RUN_2.pth
# Epoch: 23 | Train Loss: 0.497 | Val. Loss: 0.828
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 24 | Train Loss: 0.497 | Val. Loss: 0.874
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 2 epochs.
# Epoch: 25 | Train Loss: 0.489 | Val. Loss: 0.842
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 3 epochs.
# Epoch: 26 | Train Loss: 0.478 | Val. Loss: 0.844
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 4 epochs.
# Epoch: 27 | Train Loss: 0.480 | Val. Loss: 0.867
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 5 epochs.
# Epoch: 28 | Train Loss: 0.473 | Val. Loss: 0.853
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 6 epochs.
# Epoch: 29 | Train Loss: 0.470 | Val. Loss: 0.855
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 7 epochs.
# Epoch: 30 | Train Loss: 0.452 | Val. Loss: 0.854
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 8 epochs.
# Epoch: 31 | Train Loss: 0.458 | Val. Loss: 0.852
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 9 epochs.
# Epoch: 32 | Train Loss: 0.452 | Val. Loss: 0.847
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 10 epochs.
# Stopping early after 33 epochs due to no improvement in validation loss.
# Run 2 finished with best validation loss: 0.828
#
# Starting run 3/10
# MODEL INTIALIZATION
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from inf to 1.322. Saving checkpoint: RESULTS/IDRID_HE/RUN_3.pth
# Epoch: 01 | Train Loss: 1.410 | Val. Loss: 1.322
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 1.322 to 1.159. Saving checkpoint: RESULTS/IDRID_HE/RUN_3.pth
# Epoch: 02 | Train Loss: 0.953 | Val. Loss: 1.159
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 1.159 to 0.989. Saving checkpoint: RESULTS/IDRID_HE/RUN_3.pth
# Epoch: 03 | Train Loss: 0.805 | Val. Loss: 0.989
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 04 | Train Loss: 0.745 | Val. Loss: 1.103
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.989 to 0.932. Saving checkpoint: RESULTS/IDRID_HE/RUN_3.pth
# Epoch: 05 | Train Loss: 0.706 | Val. Loss: 0.932
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.932 to 0.856. Saving checkpoint: RESULTS/IDRID_HE/RUN_3.pth
# Epoch: 06 | Train Loss: 0.665 | Val. Loss: 0.856
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 07 | Train Loss: 0.632 | Val. Loss: 0.962
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 2 epochs.
# Epoch: 08 | Train Loss: 0.605 | Val. Loss: 0.973
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 3 epochs.
# Epoch: 09 | Train Loss: 0.568 | Val. Loss: 0.875
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 4 epochs.
# Epoch: 10 | Train Loss: 0.554 | Val. Loss: 0.859
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 5 epochs.
# Epoch: 11 | Train Loss: 0.541 | Val. Loss: 0.882
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 6 epochs.
# Epoch: 12 | Train Loss: 0.497 | Val. Loss: 0.868
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 7 epochs.
# Epoch: 13 | Train Loss: 0.479 | Val. Loss: 0.896
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 8 epochs.
# Epoch: 14 | Train Loss: 0.455 | Val. Loss: 1.009
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 9 epochs.
# Epoch: 15 | Train Loss: 0.474 | Val. Loss: 0.863
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.856 to 0.823. Saving checkpoint: RESULTS/IDRID_HE/RUN_3.pth
# Epoch: 16 | Train Loss: 0.434 | Val. Loss: 0.823
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 17 | Train Loss: 0.408 | Val. Loss: 0.861
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 2 epochs.
# Epoch: 18 | Train Loss: 0.395 | Val. Loss: 0.836
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 3 epochs.
# Epoch: 19 | Train Loss: 0.393 | Val. Loss: 0.836
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 4 epochs.
# Epoch: 20 | Train Loss: 0.385 | Val. Loss: 0.836
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 5 epochs.
# Epoch: 21 | Train Loss: 0.383 | Val. Loss: 0.841
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 6 epochs.
# Epoch: 22 | Train Loss: 0.376 | Val. Loss: 0.865
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 7 epochs.
# Epoch: 23 | Train Loss: 0.375 | Val. Loss: 0.851
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 8 epochs.
# Epoch: 24 | Train Loss: 0.376 | Val. Loss: 0.853
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 9 epochs.
# Epoch: 25 | Train Loss: 0.369 | Val. Loss: 0.857
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 10 epochs.
# Stopping early after 26 epochs due to no improvement in validation loss.
# Run 3 finished with best validation loss: 0.823
#
# Starting run 4/10
# MODEL INTIALIZATION
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from inf to 1.374. Saving checkpoint: RESULTS/IDRID_HE/RUN_4.pth
# Epoch: 01 | Train Loss: 1.376 | Val. Loss: 1.374
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 1.374 to 1.006. Saving checkpoint: RESULTS/IDRID_HE/RUN_4.pth
# Epoch: 02 | Train Loss: 0.960 | Val. Loss: 1.006
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 1.006 to 1.006. Saving checkpoint: RESULTS/IDRID_HE/RUN_4.pth
# Epoch: 03 | Train Loss: 0.868 | Val. Loss: 1.006
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 1.006 to 0.992. Saving checkpoint: RESULTS/IDRID_HE/RUN_4.pth
# Epoch: 04 | Train Loss: 0.770 | Val. Loss: 0.992
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.992 to 0.947. Saving checkpoint: RESULTS/IDRID_HE/RUN_4.pth
# Epoch: 05 | Train Loss: 0.736 | Val. Loss: 0.947
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 06 | Train Loss: 0.683 | Val. Loss: 1.620
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 2 epochs.
# Epoch: 07 | Train Loss: 0.694 | Val. Loss: 0.956
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 3 epochs.
# Epoch: 08 | Train Loss: 0.647 | Val. Loss: 0.991
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.947 to 0.833. Saving checkpoint: RESULTS/IDRID_HE/RUN_4.pth
# Epoch: 09 | Train Loss: 0.616 | Val. Loss: 0.833
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 10 | Train Loss: 0.579 | Val. Loss: 0.864
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 2 epochs.
# Epoch: 11 | Train Loss: 0.548 | Val. Loss: 0.844
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 3 epochs.
# Epoch: 12 | Train Loss: 0.528 | Val. Loss: 0.955
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.833 to 0.820. Saving checkpoint: RESULTS/IDRID_HE/RUN_4.pth
# Epoch: 13 | Train Loss: 0.523 | Val. Loss: 0.820
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.820 to 0.814. Saving checkpoint: RESULTS/IDRID_HE/RUN_4.pth
# Epoch: 14 | Train Loss: 0.498 | Val. Loss: 0.814
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 15 | Train Loss: 0.479 | Val. Loss: 0.862
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 2 epochs.
# Epoch: 16 | Train Loss: 0.462 | Val. Loss: 0.834
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 3 epochs.
# Epoch: 17 | Train Loss: 0.482 | Val. Loss: 0.824
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 4 epochs.
# Epoch: 18 | Train Loss: 0.433 | Val. Loss: 0.830
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 5 epochs.
# Epoch: 19 | Train Loss: 0.431 | Val. Loss: 0.846
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 6 epochs.
# Epoch: 20 | Train Loss: 0.411 | Val. Loss: 0.868
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 7 epochs.
# Epoch: 21 | Train Loss: 0.392 | Val. Loss: 0.822
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.814 to 0.808. Saving checkpoint: RESULTS/IDRID_HE/RUN_4.pth
# Epoch: 22 | Train Loss: 0.375 | Val. Loss: 0.808
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.808 to 0.785. Saving checkpoint: RESULTS/IDRID_HE/RUN_4.pth
# Epoch: 23 | Train Loss: 0.364 | Val. Loss: 0.785
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 24 | Train Loss: 0.357 | Val. Loss: 0.832
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 2 epochs.
# Epoch: 25 | Train Loss: 0.362 | Val. Loss: 0.815
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 3 epochs.
# Epoch: 26 | Train Loss: 0.342 | Val. Loss: 0.817
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 4 epochs.
# Epoch: 27 | Train Loss: 0.330 | Val. Loss: 0.825
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 5 epochs.
# Epoch: 28 | Train Loss: 0.319 | Val. Loss: 0.837
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 6 epochs.
# Epoch: 29 | Train Loss: 0.296 | Val. Loss: 0.838
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 7 epochs.
# Epoch: 30 | Train Loss: 0.288 | Val. Loss: 0.836
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 8 epochs.
# Epoch: 31 | Train Loss: 0.283 | Val. Loss: 0.832
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 9 epochs.
# Epoch: 32 | Train Loss: 0.280 | Val. Loss: 0.846
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 10 epochs.
# Stopping early after 33 epochs due to no improvement in validation loss.
# Run 4 finished with best validation loss: 0.785
#
# Starting run 5/10
# MODEL INTIALIZATION
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from inf to 1.502. Saving checkpoint: RESULTS/IDRID_HE/RUN_5.pth
# Epoch: 01 | Train Loss: 1.425 | Val. Loss: 1.502
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 1.502 to 1.146. Saving checkpoint: RESULTS/IDRID_HE/RUN_5.pth
# Epoch: 02 | Train Loss: 0.963 | Val. Loss: 1.146
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 1.146 to 1.038. Saving checkpoint: RESULTS/IDRID_HE/RUN_5.pth
# Epoch: 03 | Train Loss: 0.820 | Val. Loss: 1.038
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 1.038 to 0.978. Saving checkpoint: RESULTS/IDRID_HE/RUN_5.pth
# Epoch: 04 | Train Loss: 0.795 | Val. Loss: 0.978
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 05 | Train Loss: 0.748 | Val. Loss: 1.087
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 2 epochs.
# Epoch: 06 | Train Loss: 0.700 | Val. Loss: 1.198
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 3 epochs.
# Epoch: 07 | Train Loss: 0.688 | Val. Loss: 1.073
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 4 epochs.
# Epoch: 08 | Train Loss: 0.630 | Val. Loss: 0.988
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.978 to 0.857. Saving checkpoint: RESULTS/IDRID_HE/RUN_5.pth
# Epoch: 09 | Train Loss: 0.593 | Val. Loss: 0.857
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 10 | Train Loss: 0.563 | Val. Loss: 0.977
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 2 epochs.
# Epoch: 11 | Train Loss: 0.536 | Val. Loss: 0.881
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 3 epochs.
# Epoch: 12 | Train Loss: 0.528 | Val. Loss: 0.998
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 4 epochs.
# Epoch: 13 | Train Loss: 0.532 | Val. Loss: 0.926
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 5 epochs.
# Epoch: 14 | Train Loss: 0.514 | Val. Loss: 0.869
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 6 epochs.
# Epoch: 15 | Train Loss: 0.494 | Val. Loss: 0.882
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 7 epochs.
# Epoch: 16 | Train Loss: 0.450 | Val. Loss: 0.920
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 8 epochs.
# Epoch: 17 | Train Loss: 0.436 | Val. Loss: 0.912
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 9 epochs.
# Epoch: 18 | Train Loss: 0.405 | Val. Loss: 0.881
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 10 epochs.
# Stopping early after 19 epochs due to no improvement in validation loss.
# Run 5 finished with best validation loss: 0.857
#
# Starting run 6/10
# MODEL INTIALIZATION
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from inf to 1.286. Saving checkpoint: RESULTS/IDRID_HE/RUN_6.pth
# Epoch: 01 | Train Loss: 1.450 | Val. Loss: 1.286
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 1.286 to 1.088. Saving checkpoint: RESULTS/IDRID_HE/RUN_6.pth
# Epoch: 02 | Train Loss: 0.975 | Val. Loss: 1.088
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 03 | Train Loss: 0.878 | Val. Loss: 2.159
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 1.088 to 0.979. Saving checkpoint: RESULTS/IDRID_HE/RUN_6.pth
# Epoch: 04 | Train Loss: 0.849 | Val. Loss: 0.979
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 05 | Train Loss: 0.780 | Val. Loss: 1.036
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 2 epochs.
# Epoch: 06 | Train Loss: 0.709 | Val. Loss: 1.144
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 3 epochs.
# Epoch: 07 | Train Loss: 0.681 | Val. Loss: 1.040
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 4 epochs.
# Epoch: 08 | Train Loss: 0.706 | Val. Loss: 1.128
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 5 epochs.
# Epoch: 09 | Train Loss: 0.655 | Val. Loss: 1.092
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.979 to 0.956. Saving checkpoint: RESULTS/IDRID_HE/RUN_6.pth
# Epoch: 10 | Train Loss: 0.606 | Val. Loss: 0.956
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.956 to 0.877. Saving checkpoint: RESULTS/IDRID_HE/RUN_6.pth
# Epoch: 11 | Train Loss: 0.574 | Val. Loss: 0.877
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.877 to 0.872. Saving checkpoint: RESULTS/IDRID_HE/RUN_6.pth
# Epoch: 12 | Train Loss: 0.559 | Val. Loss: 0.872
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.872 to 0.861. Saving checkpoint: RESULTS/IDRID_HE/RUN_6.pth
# Epoch: 13 | Train Loss: 0.512 | Val. Loss: 0.861
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 14 | Train Loss: 0.548 | Val. Loss: 1.287
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 2 epochs.
# Epoch: 15 | Train Loss: 0.531 | Val. Loss: 0.904
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 3 epochs.
# Epoch: 16 | Train Loss: 0.494 | Val. Loss: 1.021
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 4 epochs.
# Epoch: 17 | Train Loss: 0.469 | Val. Loss: 0.922
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 5 epochs.
# Epoch: 18 | Train Loss: 0.459 | Val. Loss: 0.927
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 6 epochs.
# Epoch: 19 | Train Loss: 0.462 | Val. Loss: 1.022
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 7 epochs.
# Epoch: 20 | Train Loss: 0.441 | Val. Loss: 0.951
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 8 epochs.
# Epoch: 21 | Train Loss: 0.418 | Val. Loss: 0.979
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 9 epochs.
# Epoch: 22 | Train Loss: 0.393 | Val. Loss: 0.897
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 10 epochs.
# Stopping early after 23 epochs due to no improvement in validation loss.
# Run 6 finished with best validation loss: 0.861
#
# Starting run 7/10
# MODEL INTIALIZATION
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from inf to 1.350. Saving checkpoint: RESULTS/IDRID_HE/RUN_7.pth
# Epoch: 01 | Train Loss: 1.443 | Val. Loss: 1.350
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 02 | Train Loss: 1.052 | Val. Loss: 1.387
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 1.350 to 1.142. Saving checkpoint: RESULTS/IDRID_HE/RUN_7.pth
# Epoch: 03 | Train Loss: 0.922 | Val. Loss: 1.142
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 1.142 to 0.999. Saving checkpoint: RESULTS/IDRID_HE/RUN_7.pth
# Epoch: 04 | Train Loss: 0.794 | Val. Loss: 0.999
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 05 | Train Loss: 0.766 | Val. Loss: 1.010
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.999 to 0.919. Saving checkpoint: RESULTS/IDRID_HE/RUN_7.pth
# Epoch: 06 | Train Loss: 0.715 | Val. Loss: 0.919
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 07 | Train Loss: 0.657 | Val. Loss: 1.059
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 2 epochs.
# Epoch: 08 | Train Loss: 0.631 | Val. Loss: 0.986
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 3 epochs.
# Epoch: 09 | Train Loss: 0.608 | Val. Loss: 1.041
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 4 epochs.
# Epoch: 10 | Train Loss: 0.609 | Val. Loss: 1.064
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 5 epochs.
# Epoch: 11 | Train Loss: 0.574 | Val. Loss: 0.955
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.919 to 0.914. Saving checkpoint: RESULTS/IDRID_HE/RUN_7.pth
# Epoch: 12 | Train Loss: 0.539 | Val. Loss: 0.914
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.914 to 0.887. Saving checkpoint: RESULTS/IDRID_HE/RUN_7.pth
# Epoch: 13 | Train Loss: 0.514 | Val. Loss: 0.887
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.887 to 0.876. Saving checkpoint: RESULTS/IDRID_HE/RUN_7.pth
# Epoch: 14 | Train Loss: 0.492 | Val. Loss: 0.876
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 15 | Train Loss: 0.480 | Val. Loss: 0.889
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 2 epochs.
# Epoch: 16 | Train Loss: 0.475 | Val. Loss: 0.880
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.876 to 0.868. Saving checkpoint: RESULTS/IDRID_HE/RUN_7.pth
# Epoch: 17 | Train Loss: 0.470 | Val. Loss: 0.868

# %%
plt.figure()
plt.plot(range(1, epoch+2), total_train_loss, label=' train_losses')
plt.plot(range(1, epoch+2), total_val_loss, label='val_losses')
plt.xlabel('Epoch')
plt.ylabel('LOSS')
plt.legend()
plt.title('Train and Validation losses Over Epochs')
plt.show()

# %%
def visualize_predictions(model, loader, device, num_images=5):
    model.eval()
    num_images_plotted = 0
    with torch.no_grad():
        for idx, (images, masks) in enumerate(loader):
            images = images.to(device)
            outputs = model(images)[0]
            preds = torch.sigmoid(outputs) > 0.5
            preds = preds.cpu().numpy()
            masks = masks.cpu().numpy()

            for i in range(images.size(0)):
                plt.figure()
                plt.subplot(1, 3, 1)
                plt.imshow(images[i].permute(1, 2, 0).cpu())
                plt.title('Input Image')

                plt.subplot(1, 3, 2)
                plt.imshow(masks[i][0], cmap='gray')
                plt.title('Ground Truth')

                plt.subplot(1, 3, 3)
                plt.imshow(preds[i].transpose(1, 2, 0), cmap='gray')
                plt.title('Prediction')

                plt.show()
                print(i)

                num_images_plotted += i 
                if i+1 >= num_images:
                    break
            
            if idx+1 >= num_images or num_images_plotted >= num_images:
                break

visualize_predictions(model, val_loader, device, num_images=5)

# %% [markdown]
# # Testing after Training

# %%
import glob
import os
weight_files = sorted(glob.glob(os.path.join(folder_path, "*.pth")))
print(weight_files)
# Out:
# ['RESULTS/IDRID_HE/RUN_1.pth', 'RESULTS/IDRID_HE/RUN_2.pth', 'RESULTS/IDRID_HE/RUN_3.pth', 'RESULTS/IDRID_HE/RUN_4.pth', 'RESULTS/IDRID_HE/RUN_5.pth', 'RESULTS/IDRID_HE/RUN_6.pth', 'RESULTS/IDRID_HE/RUN_7.pth']

# %%
import torch
import numpy as np
from sklearn.metrics import (precision_score, recall_score, f1_score,
                             roc_auc_score, jaccard_score, accuracy_score,
                             confusion_matrix)

def calculate_iou(pred, target):
    intersection = (pred & target).sum()
    union = (pred | target).sum()
    iou = (intersection + 1e-6) / (union + 1e-6)  
    return iou

def calculate_dice(pred, target):
    intersection = (pred & target).sum()
    dice = (2 * intersection + 1e-6) / (pred.sum() + target.sum() + 1e-6)
    return dice

def calculate_specificity(pred, target):
    tn, fp, fn, tp = confusion_matrix(target, pred).ravel()
    specificity = tn / (tn + fp + 1e-6)
    return specificity

weight_files = sorted(glob.glob(os.path.join(folder_path, "*.pth")))

all_weight_ious = []
all_weight_dice = []
all_weight_precisions = []
all_weight_recalls = []
all_weight_f1s = []
all_weight_aucs = []
all_weight_jaccard = []
all_weight_accuracies = []
all_weight_specificities = []

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

output_file = (f'{folder_path}evaluation_results.txt')
with open(output_file, "w") as outfile:
    for idx, weight_file in enumerate(weight_files, start=1):
        MODEL.load_state_dict(torch.load(weight_file, map_location=device))
        MODEL.to(device)
        MODEL.eval()  
        batch_ious = []
        batch_dice = []
        batch_precisions = []
        batch_recalls = []
        batch_f1s = []
        batch_aucs = []
        batch_jaccard = []
        batch_accuracies = []
        batch_specificities = []

        with torch.no_grad():
            for batch in val_loader:
                images, masks = batch
                images = images.to(device)
                masks = masks.to(device)

                outputs = MODEL(images)[0]
                preds = torch.sigmoid(outputs) > 0.5  
                preds = preds.int()
                masks = masks.int()

                preds_np = preds.cpu().numpy().flatten()
                masks_np = masks.cpu().numpy().flatten()

                iou = calculate_iou(preds_np, masks_np)
                dice = calculate_dice(preds_np, masks_np)
                precision = precision_score(masks_np, preds_np, zero_division=1)
                recall = recall_score(masks_np, preds_np, zero_division=1)  
                f1 = f1_score(masks_np, preds_np, zero_division=1)
                jaccard = jaccard_score(masks_np, preds_np, zero_division=1)
                accuracy = accuracy_score(masks_np, preds_np)
                specificity = calculate_specificity(preds_np, masks_np)
                auc = roc_auc_score(masks_np, torch.sigmoid(outputs).cpu().numpy().flatten())

                batch_ious.append(iou)
                batch_dice.append(dice)
                batch_precisions.append(precision)
                batch_recalls.append(recall)
                batch_f1s.append(f1)
                batch_aucs.append(auc)
                batch_jaccard.append(jaccard)
                batch_accuracies.append(accuracy)
                batch_specificities.append(specificity)

        avg_iou = np.mean(batch_ious)
        avg_dice = np.mean(batch_dice)
        avg_precision = np.mean(batch_precisions)
        avg_recall = np.mean(batch_recalls)
        avg_f1 = np.mean(batch_f1s)
        avg_auc = np.mean(batch_aucs)
        avg_jaccard = np.mean(batch_jaccard)
        avg_accuracy = np.mean(batch_accuracies)
        avg_specificity = np.mean(batch_specificities)

        output_str = f"Weight File {idx} ({weight_file}):\n"
        output_str += f"  Average IoU: {avg_iou:.4f}\n"
        output_str += f"  Average Dice Coefficient: {avg_dice:.4f}\n"
        output_str += f"  Average Precision: {avg_precision:.4f}\n"
        output_str += f"  Average Recall (Sensitivity): {avg_recall:.4f}\n"
        output_str += f"  Average F1 Score: {avg_f1:.4f}\n"
        output_str += f"  Average AUC: {avg_auc:.4f}\n"
        output_str += f"  Average Jaccard Score: {avg_jaccard:.4f}\n"
        output_str += f"  Average Accuracy: {avg_accuracy:.4f}\n"
        output_str += f"  Average Specificity: {avg_specificity:.4f}\n\n"

        print(output_str)
        outfile.write(output_str)

        all_weight_ious.append(avg_iou)
        all_weight_dice.append(avg_dice)
        all_weight_precisions.append(avg_precision)
        all_weight_recalls.append(avg_recall)
        all_weight_f1s.append(avg_f1)
        all_weight_aucs.append(avg_auc)
        all_weight_jaccard.append(avg_jaccard)
        all_weight_accuracies.append(avg_accuracy)
        all_weight_specificities.append(avg_specificity)

    overall_str = "Overall Metrics Across All Weight Files:\n"
    overall_str += f"Mean IoU: {np.mean(all_weight_ious):.4f}, Std IoU: {np.std(all_weight_ious):.4f}\n"
    overall_str += f"Mean Dice Coefficient: {np.mean(all_weight_dice):.4f}, Std Dice: {np.std(all_weight_dice):.4f}\n"
    overall_str += f"Mean Precision: {np.mean(all_weight_precisions):.4f}, Std Precision: {np.std(all_weight_precisions):.4f}\n"
    overall_str += f"Mean Recall (Sensitivity): {np.mean(all_weight_recalls):.4f}, Std Recall: {np.std(all_weight_recalls):.4f}\n"
    overall_str += f"Mean F1 Score: {np.mean(all_weight_f1s):.4f}, Std F1: {np.std(all_weight_f1s):.4f}\n"
    overall_str += f"Mean AUC: {np.mean(all_weight_aucs):.4f}, Std AUC: {np.std(all_weight_aucs):.4f}\n"
    overall_str += f"Mean Jaccard Score: {np.mean(all_weight_jaccard):.4f}, Std Jaccard: {np.std(all_weight_jaccard):.4f}\n"
    overall_str += f"Mean Accuracy: {np.mean(all_weight_accuracies):.4f}, Std Accuracy: {np.std(all_weight_accuracies):.4f}\n"
    overall_str += f"Mean Specificity: {np.mean(all_weight_specificities):.4f}, Std Specificity: {np.std(all_weight_specificities):.4f}\n"

    print(overall_str)
    outfile.write(overall_str)
# Out:
# Weight File 1 (RESULTS/IDRID_HE/RUN_1.pth):
#   Average IoU: 0.3947
#   Average Dice Coefficient: 0.5655
#   Average Precision: 0.6174
#   Average Recall (Sensitivity): 0.5331
#   Average F1 Score: 0.5655
#   Average AUC: 0.9676
#   Average Jaccard Score: 0.3947
#   Average Accuracy: 0.9932
#   Average Specificity: 0.9971
#
#
# Weight File 2 (RESULTS/IDRID_HE/RUN_2.pth):
#   Average IoU: 0.3826
#   Average Dice Coefficient: 0.5521
#   Average Precision: 0.5696
#   Average Recall (Sensitivity): 0.5459
#   Average F1 Score: 0.5521
#   Average AUC: 0.9673
#   Average Jaccard Score: 0.3826
#   Average Accuracy: 0.9928
#   Average Specificity: 0.9964
#
#
# Weight File 3 (RESULTS/IDRID_HE/RUN_3.pth):
#   Average IoU: 0.3808
#   Average Dice Coefficient: 0.5500
#   Average Precision: 0.6053
#   Average Recall (Sensitivity): 0.5137
#   Average F1 Score: 0.5500
#   Average AUC: 0.9661
#   Average Jaccard Score: 0.3808
#   Average Accuracy: 0.9933
#   Average Specificity: 0.9972
#
#
# Weight File 4 (RESULTS/IDRID_HE/RUN_4.pth):
#   Average IoU: 0.4180
#   Average Dice Coefficient: 0.5890
#   Average Precision: 0.6246
#   Average Recall (Sensitivity): 0.5689
#   Average F1 Score: 0.5890
#   Average AUC: 0.9670
#   Average Jaccard Score: 0.4180
#   Average Accuracy: 0.9936
#   Average Specificity: 0.9972
#
#
# Weight File 5 (RESULTS/IDRID_HE/RUN_5.pth):
#   Average IoU: 0.3690
#   Average Dice Coefficient: 0.5375
#   Average Precision: 0.5507
#   Average Recall (Sensitivity): 0.5396
#   Average F1 Score: 0.5375
#   Average AUC: 0.9497
#   Average Jaccard Score: 0.3690
#   Average Accuracy: 0.9925
#   Average Specificity: 0.9961
#
#
# Weight File 6 (RESULTS/IDRID_HE/RUN_6.pth):
#   Average IoU: 0.3664
#   Average Dice Coefficient: 0.5345
#   Average Precision: 0.6374
#   Average Recall (Sensitivity): 0.4740
#   Average F1 Score: 0.5345
#   Average AUC: 0.9573
#   Average Jaccard Score: 0.3664
#   Average Accuracy: 0.9934
#   Average Specificity: 0.9977
#
#
# Weight File 7 (RESULTS/IDRID_HE/RUN_7.pth):
#   Average IoU: 0.3630
#   Average Dice Coefficient: 0.5310
#   Average Precision: 0.6023
#   Average Recall (Sensitivity): 0.4874
#   Average F1 Score: 0.5310
#   Average AUC: 0.9592
#   Average Jaccard Score: 0.3630
#   Average Accuracy: 0.9930
#   Average Specificity: 0.9971
#
#
# Overall Metrics Across All Weight Files:
# Mean IoU: 0.3821, Std IoU: 0.0179
# Mean Dice Coefficient: 0.5514, Std Dice: 0.0189
# Mean Precision: 0.6011, Std Precision: 0.0285
# Mean Recall (Sensitivity): 0.5232, Std Recall: 0.0311
# Mean F1 Score: 0.5514, Std F1: 0.0189
# Mean AUC: 0.9620, Std AUC: 0.0064
# Mean Jaccard Score: 0.3821, Std Jaccard: 0.0179
# Mean Accuracy: 0.9931, Std Accuracy: 0.0003
# Mean Specificity: 0.9970, Std Specificity: 0.0005
