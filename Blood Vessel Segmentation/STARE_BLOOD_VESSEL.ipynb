# %% [markdown]
# # Imports

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
import torchvision.transforms as transforms
from torchvision import datasets
from PIL import Image
import os
import numpy as np
import matplotlib.pyplot as plt
import albumentations as A
from albumentations.pytorch import ToTensorV2
from PIL import Image
from torchinfo import summary
import torch.nn.functional as F
from operator import add
# Out:
# /home/raouti/.local/lib/python3.11/site-packages/albumentations/__init__.py:13: UserWarning: A new version of Albumentations is available: 2.0.2 (you have 1.4.14). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)
# Out:
# cuda

# %%
PATCH_SIZE = 256
OVERLAP = '50'

# %% [markdown]
# # Model

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class UNet(nn.Module):
    def __init__(self):
        super(UNet, self).__init__()
        
        # Downsampling (encoder) blocks
        self.enc1 = MultiPathBlock(in_channels = 1, out_channels = 16, stride=1, dilation= [1,3,5,7])
        self.enc2 = MultiPathBlock(in_channels = 16, out_channels = 32, stride=1, dilation= [1,3,5])
        self.enc3 = MultiPathBlock(in_channels = 32, out_channels = 64, stride=1, dilation= [1,3])
        self.enc4 = MultiPathBlock(in_channels = 64, out_channels = 128, stride=1, dilation= [1])

        # Bottleneck
        self.bottleneck = self.conv_block(128, 256)

        # Upsampling (decoder) blocks
        self.upconv4 = nn.ConvTranspose2d(256, 128, kernel_size=2, stride=2)
        self.dec4 = MultiPathBlock(in_channels = 128 + 128, out_channels = 128, stride=1, dilation= [1])

        self.upconv3 = nn.ConvTranspose2d(128, 64, kernel_size=2, stride=2)
        self.dec3 = MultiPathBlock(in_channels = 64 + 64, out_channels = 64, stride=1, dilation= [1,3])

        self.upconv2 = nn.ConvTranspose2d(64, 32, kernel_size=2, stride=2)
        self.dec2 = MultiPathBlock(in_channels = 32 + 32, out_channels = 32, stride=1, dilation= [1,3,5])

        self.upconv1 = nn.ConvTranspose2d(32, 16, kernel_size=2, stride=2)
        self.dec1 = MultiPathBlock(in_channels = 16 + 16, out_channels = 16, stride=1, dilation= [1,3,5,7])

        # Final output layer
        self.final_conv = nn.Conv2d(16, 1, kernel_size=1)


        # Intermediate Layers
        self.out_2 = self.conv_block_intermediate_output(32, 1)
        self.out_3 = self.conv_block_intermediate_output(64, 1)
        self.out_4 = self.conv_block_intermediate_output(128, 1)
    
    def conv_block_intermediate_output(self, in_channels, out_channels):
        return nn.Conv2d(in_channels, out_channels, kernel_size=1)
    def conv_block(self, in_channels, out_channels):
        block = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size = 3, dilation=1, padding = 1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels,  kernel_size = 3, dilation=1,padding = 1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True)
        )
        return block

    def forward(self, x):
        # Encoder path
        e1 = self.enc1(x)
        e2 = self.enc2(F.max_pool2d(e1, 2))
        e3 = self.enc3(F.max_pool2d(e2, 2))
        e4 = self.enc4(F.max_pool2d(e3, 2))

        # Bottleneck
        b = self.bottleneck(F.max_pool2d(e4, 2))

        # Decoder path
        d4 = self.upconv4(b)
        d4 = torch.cat((d4, e4), dim=1)
        d4 = self.dec4(d4)
        out_d4 = self.out_4(d4)  # deep supervision output 1

        d3 = self.upconv3(d4)
        d3 = torch.cat((d3, e3), dim=1)
        d3 = self.dec3(d3)
        out_d3 = self.out_3(d3)  # deep supervision output 2

        d2 = self.upconv2(d3)
        d2 = torch.cat((d2, e2), dim=1)
        d2 = self.dec2(d2)
        out_d2 = self.out_2(d2)  # deep supervision output 3

        d1 = self.upconv1(d2)
        d1 = torch.cat((d1, e1), dim=1)
        d1 = self.dec1(d1)

        # Final output
        out = self.final_conv(d1)
        return out, out_d4, out_d3, out_d2  

class StandardConvBlock(nn.Module):
    def __init__(self, in_channels, out_channels, stride=1, dilation=1):
        super(StandardConvBlock, self).__init__()
        self.conv = nn.Conv2d(
            in_channels, out_channels, kernel_size=3, stride=stride, padding=dilation, dilation=dilation, bias=False
        )
        self.bn = nn.BatchNorm2d(out_channels)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.conv(x)
        x = self.bn(x)
        x = self.relu(x)
        return x

class SinglePathBlock(nn.Module):
    def __init__(self,in_channels, out_channels, stride=1, dilation= 1):
        super(SinglePathBlock,self).__init__()
        
        self.single_path_block_1 =  nn.Sequential(
            StandardConvBlock(in_channels, out_channels, stride=stride, dilation=dilation),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(),
            )
        
        self.single_path_block_2 =  nn.Sequential(
            StandardConvBlock(out_channels, out_channels, stride=stride, dilation=dilation),
            nn.BatchNorm2d(out_channels),
            CBAM(out_channels),
            nn.ReLU(),
            )
        
        self.channel_modification = nn.Conv2d(in_channels,out_channels,kernel_size = 1)

    def forward(self,x):

        identity = x
        out_block_1 = self.single_path_block_1(x)
        
        if out_block_1.shape[1] != x.shape[1]:
            identity = self.channel_modification(x)
        
        out_block_2 = self.single_path_block_2(out_block_1)
        
        out_block_2 = out_block_2 + identity

        return out_block_2


class MultiPathBlock(nn.Module):
    def __init__(self, in_channels, out_channels, stride=1, dilation= [1, 3, 5, 7]):
        super(MultiPathBlock, self).__init__()
        
        self.parallel_paths = nn.ModuleList([
            SinglePathBlock(in_channels, out_channels, stride=1, dilation= d)
            for d in dilation
        ])

    def forward(self, x):
        out = 0
        for path in self.parallel_paths:
            out += path(x)

        return out

class CBAM(nn.Module):
    def __init__(self, channels, reduction_ratio=16, kernel_size=7):
        super(CBAM, self).__init__()
        self.channel_attention = nn.Sequential(
            nn.AdaptiveAvgPool2d(1),
            nn.Conv2d(channels, channels // reduction_ratio, kernel_size=1, bias=False),
            nn.ReLU(),
            nn.Conv2d(channels // reduction_ratio, channels, kernel_size=1, bias=False),
            nn.Sigmoid()
        )
        self.spatial_attention = nn.Sequential(
            nn.Conv2d(2, 1, kernel_size=kernel_size, stride=1, padding=kernel_size // 2, bias=False),
            nn.Sigmoid()
        )

    def forward(self, x):
        channel_attention = self.channel_attention(x)
        x = x * channel_attention
        max_pool = torch.max(x, dim=1, keepdim=True)[0]
        avg_pool = torch.mean(x, dim=1, keepdim=True)
        spatial_attention = self.spatial_attention(torch.cat([max_pool, avg_pool], dim=1))
        x = x * spatial_attention
        return x

# %%
MODEL = UNet()
(summary(model=MODEL,
          input_size=(32, 1, PATCH_SIZE, PATCH_SIZE), 
          col_names=["input_size", "output_size", "num_params", "trainable"],
          col_width=20,
          row_settings=["var_names"]
  ))
# Out:
# =================================================================================================================================================
# Layer (type (var_name))                                           Input Shape          Output Shape         Param #              Trainable
# =================================================================================================================================================
# UNet (UNet)                                                       [32, 1, 256, 256]    [32, 1, 256, 256]    --                   True
# ├─MultiPathBlock (enc1)                                           [32, 1, 256, 256]    [32, 16, 256, 256]   --                   True
# │    └─ModuleList (parallel_paths)                                --                   --                   --                   True
# │    │    └─SinglePathBlock (0)                                   [32, 1, 256, 256]    [32, 16, 256, 256]   2,738                True
# │    │    └─SinglePathBlock (1)                                   [32, 1, 256, 256]    [32, 16, 256, 256]   2,738                True
# │    │    └─SinglePathBlock (2)                                   [32, 1, 256, 256]    [32, 16, 256, 256]   2,738                True
# │    │    └─SinglePathBlock (3)                                   [32, 1, 256, 256]    [32, 16, 256, 256]   2,738                True
# ├─MultiPathBlock (enc2)                                           [32, 16, 128, 128]   [32, 32, 128, 128]   --                   True
# │    └─ModuleList (parallel_paths)                                --                   --                   --                   True
# │    │    └─SinglePathBlock (0)                                   [32, 16, 128, 128]   [32, 32, 128, 128]   14,850               True
# │    │    └─SinglePathBlock (1)                                   [32, 16, 128, 128]   [32, 32, 128, 128]   14,850               True
# │    │    └─SinglePathBlock (2)                                   [32, 16, 128, 128]   [32, 32, 128, 128]   14,850               True
# ├─MultiPathBlock (enc3)                                           [32, 32, 64, 64]     [32, 64, 64, 64]     --                   True
# │    └─ModuleList (parallel_paths)                                --                   --                   --                   True
# │    │    └─SinglePathBlock (0)                                   [32, 32, 64, 64]     [32, 64, 64, 64]     58,530               True
# │    │    └─SinglePathBlock (1)                                   [32, 32, 64, 64]     [32, 64, 64, 64]     58,530               True
# ├─MultiPathBlock (enc4)                                           [32, 64, 32, 32]     [32, 128, 32, 32]    --                   True
# │    └─ModuleList (parallel_paths)                                --                   --                   --                   True
# │    │    └─SinglePathBlock (0)                                   [32, 64, 32, 32]     [32, 128, 32, 32]    232,674              True
# ├─Sequential (bottleneck)                                         [32, 128, 16, 16]    [32, 256, 16, 16]    --                   True
# │    └─Conv2d (0)                                                 [32, 128, 16, 16]    [32, 256, 16, 16]    295,168              True
# │    └─BatchNorm2d (1)                                            [32, 256, 16, 16]    [32, 256, 16, 16]    512                  True
# │    └─ReLU (2)                                                   [32, 256, 16, 16]    [32, 256, 16, 16]    --                   --
# │    └─Conv2d (3)                                                 [32, 256, 16, 16]    [32, 256, 16, 16]    590,080              True
# │    └─BatchNorm2d (4)                                            [32, 256, 16, 16]    [32, 256, 16, 16]    512                  True
# │    └─ReLU (5)                                                   [32, 256, 16, 16]    [32, 256, 16, 16]    --                   --
# ├─ConvTranspose2d (upconv4)                                       [32, 256, 16, 16]    [32, 128, 32, 32]    131,200              True
# ├─MultiPathBlock (dec4)                                           [32, 256, 32, 32]    [32, 128, 32, 32]    --                   True
# │    └─ModuleList (parallel_paths)                                --                   --                   --                   True
# │    │    └─SinglePathBlock (0)                                   [32, 256, 32, 32]    [32, 128, 32, 32]    478,434              True
# ├─Conv2d (out_4)                                                  [32, 128, 32, 32]    [32, 1, 32, 32]      129                  True
# ├─ConvTranspose2d (upconv3)                                       [32, 128, 32, 32]    [32, 64, 64, 64]     32,832               True
# ├─MultiPathBlock (dec3)                                           [32, 128, 64, 64]    [32, 64, 64, 64]     --                   True
# │    └─ModuleList (parallel_paths)                                --                   --                   --                   True
# │    │    └─SinglePathBlock (0)                                   [32, 128, 64, 64]    [32, 64, 64, 64]     119,970              True
# │    │    └─SinglePathBlock (1)                                   [32, 128, 64, 64]    [32, 64, 64, 64]     119,970              True
# ├─Conv2d (out_3)                                                  [32, 64, 64, 64]     [32, 1, 64, 64]      65                   True
# ├─ConvTranspose2d (upconv2)                                       [32, 64, 64, 64]     [32, 32, 128, 128]   8,224                True
# ├─MultiPathBlock (dec2)                                           [32, 64, 128, 128]   [32, 32, 128, 128]   --                   True
# │    └─ModuleList (parallel_paths)                                --                   --                   --                   True
# │    │    └─SinglePathBlock (0)                                   [32, 64, 128, 128]   [32, 32, 128, 128]   30,210               True
# │    │    └─SinglePathBlock (1)                                   [32, 64, 128, 128]   [32, 32, 128, 128]   30,210               True
# │    │    └─SinglePathBlock (2)                                   [32, 64, 128, 128]   [32, 32, 128, 128]   30,210               True
# ├─Conv2d (out_2)                                                  [32, 32, 128, 128]   [32, 1, 128, 128]    33                   True
# ├─ConvTranspose2d (upconv1)                                       [32, 32, 128, 128]   [32, 16, 256, 256]   2,064                True
# ├─MultiPathBlock (dec1)                                           [32, 32, 256, 256]   [32, 16, 256, 256]   --                   True
# │    └─ModuleList (parallel_paths)                                --                   --                   --                   True
# │    │    └─SinglePathBlock (0)                                   [32, 32, 256, 256]   [32, 16, 256, 256]   7,698                True
# │    │    └─SinglePathBlock (1)                                   [32, 32, 256, 256]   [32, 16, 256, 256]   7,698                True
# │    │    └─SinglePathBlock (2)                                   [32, 32, 256, 256]   [32, 16, 256, 256]   7,698                True
# │    │    └─SinglePathBlock (3)                                   [32, 32, 256, 256]   [32, 16, 256, 256]   7,698                True
# ├─Conv2d (final_conv)                                             [32, 16, 256, 256]   [32, 1, 256, 256]    17                   True
# =================================================================================================================================================
# Total params: 2,305,868
# Trainable params: 2,305,868
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 248.44
# =================================================================================================================================================
# Input size (MB): 8.39
# Forward/backward pass size (MB): 23775.38
# Params size (MB): 9.22
# Estimated Total Size (MB): 23792.99
# =================================================================================================================================================

# %% [markdown]
# # Load Dataset

# %%
train_image_dir = f'/scratch/raouti/FUNDUS_DATASETS/STARE/PATCHIFY_{PATCH_SIZE}_{OVERLAP}/train/image/'
train_mask_dir =  f'/scratch/raouti/FUNDUS_DATASETS/STARE/PATCHIFY_{PATCH_SIZE}_{OVERLAP}/train/mask/'
test_image_dir =  f'/scratch/raouti/FUNDUS_DATASETS/STARE/PATCHIFY_{PATCH_SIZE}_{OVERLAP}/test/image/'
test_mask_dir =   f'/scratch/raouti/FUNDUS_DATASETS/STARE/PATCHIFY_{PATCH_SIZE}_{OVERLAP}/test/mask/'

# %%
print(train_image_dir)
print(train_mask_dir)
print(test_image_dir)
print(test_mask_dir)
# Out:
# /scratch/raouti/FUNDUS_DATASETS/STARE/PATCHIFY_256_50/train/image/
# /scratch/raouti/FUNDUS_DATASETS/STARE/PATCHIFY_256_50/train/mask/
# /scratch/raouti/FUNDUS_DATASETS/STARE/PATCHIFY_256_50/test/image/
# /scratch/raouti/FUNDUS_DATASETS/STARE/PATCHIFY_256_50/test/mask/

# %%
img_testing = sorted(os.listdir(train_image_dir))
lab_testing = sorted(os.listdir(train_mask_dir))
print(len(img_testing))
img_path = os.path.join(train_image_dir,img_testing[10])
mask_path = os.path.join(train_mask_dir, lab_testing[10])
IMAGE = Image.open(img_path)
LAB = Image.open(mask_path)
# Out:
# 576

# %%
image_transform = transforms.Compose([
    transforms.Resize((PATCH_SIZE, PATCH_SIZE)),
    transforms.ToTensor()
])

IMAGE_TESTING = image_transform(IMAGE)
LAB_TESTING = image_transform(LAB)

# %%
plt.imshow(IMAGE_TESTING.permute(1,2,0),cmap = 'gray')

# %%
plt.imshow(LAB_TESTING.permute(1,2,0),cmap = 'gray')

# %%
class SegmentationDataset(Dataset):
    def __init__(self, image_dir, mask_dir, transform=None):
        self.image_dir = image_dir
        self.mask_dir = mask_dir
        self.transform = transform
        self.images = os.listdir(image_dir)
        self.labels = os.listdir(mask_dir)
        self.images.sort()
        self.labels.sort()


    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_path = os.path.join(self.image_dir, self.images[idx])
        mask_path = os.path.join(self.mask_dir, self.labels[idx])
        image = Image.open(img_path)
        mask = Image.open(mask_path)
        image = np.array(Image.open(img_path).convert("L"))
        mask = np.array(Image.open(mask_path).convert("L")) 

        if self.transform:
            transformed = self.transform(image=image, mask=mask)
            image = transformed['image'].float()/255
            mask = transformed['mask'].unsqueeze(0).float()/255

        return image, mask

# %%
train_transform = A.Compose([A.Resize(PATCH_SIZE,PATCH_SIZE),  
                             ToTensorV2() 
                                        ])

val_transform = A.Compose([A.Resize(PATCH_SIZE,PATCH_SIZE),
                                    ToTensorV2() 
                                     ])


train_dataset = SegmentationDataset(image_dir=train_image_dir, mask_dir=train_mask_dir, transform=train_transform)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)

val_dataset = SegmentationDataset(image_dir=test_image_dir, mask_dir=test_mask_dir, transform=val_transform)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

# %%
img,lab= next(iter(train_loader))

# %%
plt.imshow(torch.permute(img[3],(1,2,0)),cmap = 'gray')

# %%
plt.imshow(torch.permute(lab[3],(1,2,0)),cmap = 'gray')

# %% [markdown]
# # Training

# %%
def train(model, loader, optimizer, criterion, device,scheduler):
    model.train()


    total_loss = 0
    len_loader = len(loader)
    max_grad_norm = 1

    for idx,(images, masks) in enumerate(loader):
        images, masks = images.to(device), masks.to(device)
        optimizer.zero_grad()


        outputs, out_d4, out_d3, out_d2 = model(images)       
        loss = LOSS_FUNC(outputs, out_d4, out_d3, out_d2, masks, criterion)
        
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
        
    print(f"_______________________Training - __________________________________")
    epoch_loss = total_loss/ len_loader
    return  epoch_loss

def validate(model, loader, criterion, device,scheduler):

    model.eval()
    total_loss = 0
    len_loader = len(loader)
    with torch.no_grad():
        for idx,(images, masks) in enumerate(loader):
            images, masks = images.to(device), masks.to(device)

            outputs, out_d4, out_d3, out_d2 = model(images)
            loss = LOSS_FUNC(outputs, out_d4, out_d3, out_d2, masks, criterion)
 
            total_loss += loss.item()
    scheduler.step(loss)
    print(f"_______________________Validation - __________________________________")
    epoch_loss = total_loss/ len_loader
    return  epoch_loss

# %% [markdown]
# # Loss Function

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class DiceLoss(nn.Module):
    def __init__(self, weight=None, size_average=True):
        super(DiceLoss, self).__init__()

    def forward(self, inputs, targets, smooth=1):

        inputs = torch.sigmoid(inputs)

        inputs = inputs.view(-1)
        targets = targets.view(-1)

        intersection = (inputs * targets).sum()
        dice = (2.*intersection + smooth)/(inputs.sum() + targets.sum() + smooth)

        return 1 - dice

class DiceBCELoss(nn.Module):
    def __init__(self, weight=None, size_average=True):
        super(DiceBCELoss, self).__init__()

    def forward(self, inputs, targets, smooth=1):

        inputs = torch.sigmoid(inputs)

        inputs = inputs.view(-1)
        targets = targets.view(-1)

        intersection = (inputs * targets).sum()
        dice_loss = 1 - (2.*intersection + smooth)/(inputs.sum() + targets.sum() + smooth)
        BCE = F.binary_cross_entropy(inputs, targets, reduction='mean')
        Dice_BCE = BCE + dice_loss

        return Dice_BCE

def LOSS_FUNC(segmentation_head, aux_out1, aux_out2, aux_out3, masks, criterion):
    loss_head = criterion(segmentation_head, masks)

    mask_aux_1_resized = F.interpolate(masks, size=aux_out1.shape[2:], mode='bilinear', align_corners=True)
    loss_aux1 = criterion(aux_out1, mask_aux_1_resized)

    mask_aux_2_resized = F.interpolate(masks, size=aux_out2.shape[2:], mode='bilinear', align_corners=True)
    loss_aux2 = criterion(aux_out2, mask_aux_2_resized)

    mask_aux_3_resized = F.interpolate(masks, size=aux_out3.shape[2:], mode='bilinear', align_corners=True)
    loss_aux3 = criterion(aux_out3, mask_aux_3_resized)

    total_loss = loss_head + (0.3 * loss_aux1) + (0.2 * loss_aux2) + (0.1 * loss_aux3)

    return total_loss

# %%
model_name = 'STARE'
checkpoint_name = f'RESULTS/{model_name}/RUN'
log_file_name = f'RESULTS/{model_name}/training_log.txt'
folder_path = f"RESULTS/{model_name}/"  
folder_path
# Out:
# 'RESULTS/STARE/'

# %%
import torch
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR
import torch.nn.utils as utils
from torch.optim.lr_scheduler import ReduceLROnPlateau


criterion = DiceBCELoss()
num_epochs = 100  
patience = 10  
num_runs = 10  
best_valid_losses = [] 

initial_lr = 0.001
weight_decay = 0.01 
momentum_value = 0.9
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

with open(log_file_name, 'w') as log_file:
        log_file.write(f"STARTING")
    
for run in range(num_runs):
    
    print(f"Starting run {run+1}/{num_runs}")
    print(f"MODEL INTIALIZATION")
    model = UNet().to(device)
    optimizer = optim.Adam(model.parameters(), lr=initial_lr, betas=(0.9, 0.999))  
    scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=5, verbose=True)

    with open(log_file_name, 'a') as log_file:
        log_file.write(f"RUN NO {run+1}/{num_runs}\n")
        log_file.write("MODEL INTIALIZATION \n")

    best_valid_loss = float("inf")
    total_train_loss = []
    total_val_loss = []
    early_stopping_counter = 0 

    for epoch in range(num_epochs):
        train_loss = train(model, train_loader, optimizer, criterion, device, scheduler)
        valid_loss = validate(model, val_loader, criterion, device, scheduler)
        
        total_train_loss.append(train_loss)
        total_val_loss.append(valid_loss)
    
        if valid_loss < best_valid_loss:
            checkpoint_path = f"{checkpoint_name}_{run+1}.pth"
            print(f"Valid loss improved from {best_valid_loss:.3f} to {valid_loss:.3f}. Saving checkpoint: {checkpoint_path}")
            best_valid_loss = valid_loss
            torch.save(model.state_dict(), checkpoint_path)
            early_stopping_counter = 0  
        else:
            early_stopping_counter += 1
            print(f"No improvement in validation loss for {early_stopping_counter} epochs.")
    
        if early_stopping_counter >= patience:
            print(f"Stopping early after {epoch+1} epochs due to no improvement in validation loss.")
            break

        log_message = f'Epoch: {epoch+1:02} | Train Loss: {train_loss:.3f} | Val. Loss: {valid_loss:.3f}\n'
        print(log_message)
        
        with open(log_file_name, 'a') as log_file:
            log_file.write(log_message)
    
    best_valid_losses.append(best_valid_loss)
    best_log = f"Run {run+1} finished with best validation loss: {best_valid_loss:.3f}\n"
    print(best_log)

    with open(log_file_name, 'a') as log_file:
        log_file.write(best_log)

mean_valid_loss = np.mean(best_valid_losses)
std_valid_loss = np.std(best_valid_losses)
print(f"Mean best validation loss over {num_runs} runs: {mean_valid_loss:.3f}")
print(f"Std of best validation loss over {num_runs} runs: {std_valid_loss:.3f}")
# Out:
# Starting run 1/10
# MODEL INTIALIZATION
# /home/raouti/.local/lib/python3.11/site-packages/torch/optim/lr_scheduler.py:28: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn("The verbose parameter is deprecated. Please use get_last_lr() "
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from inf to 2.340. Saving checkpoint: RESULTS/STARE/RUN_1.pth
# Epoch: 01 | Train Loss: 1.501 | Val. Loss: 2.340
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 2.340 to 1.778. Saving checkpoint: RESULTS/STARE/RUN_1.pth
# Epoch: 02 | Train Loss: 0.983 | Val. Loss: 1.778
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 1.778 to 1.177. Saving checkpoint: RESULTS/STARE/RUN_1.pth
# Epoch: 03 | Train Loss: 0.881 | Val. Loss: 1.177
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 1.177 to 0.826. Saving checkpoint: RESULTS/STARE/RUN_1.pth
# Epoch: 04 | Train Loss: 0.831 | Val. Loss: 0.826
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.826 to 0.770. Saving checkpoint: RESULTS/STARE/RUN_1.pth
# Epoch: 05 | Train Loss: 0.803 | Val. Loss: 0.770
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.770 to 0.725. Saving checkpoint: RESULTS/STARE/RUN_1.pth
# Epoch: 06 | Train Loss: 0.775 | Val. Loss: 0.725
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 07 | Train Loss: 0.754 | Val. Loss: 0.751
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 2 epochs.
# Epoch: 08 | Train Loss: 0.732 | Val. Loss: 0.773
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 3 epochs.
# Epoch: 09 | Train Loss: 0.717 | Val. Loss: 0.740
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 4 epochs.
# Epoch: 10 | Train Loss: 0.702 | Val. Loss: 0.784
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 5 epochs.
# Epoch: 11 | Train Loss: 0.686 | Val. Loss: 0.729
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.725 to 0.711. Saving checkpoint: RESULTS/STARE/RUN_1.pth
# Epoch: 12 | Train Loss: 0.668 | Val. Loss: 0.711
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 13 | Train Loss: 0.654 | Val. Loss: 0.722
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 2 epochs.
# Epoch: 14 | Train Loss: 0.641 | Val. Loss: 0.723
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.711 to 0.698. Saving checkpoint: RESULTS/STARE/RUN_1.pth
# Epoch: 15 | Train Loss: 0.628 | Val. Loss: 0.698
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.698 to 0.696. Saving checkpoint: RESULTS/STARE/RUN_1.pth
# Epoch: 16 | Train Loss: 0.623 | Val. Loss: 0.696
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.696 to 0.690. Saving checkpoint: RESULTS/STARE/RUN_1.pth
# Epoch: 17 | Train Loss: 0.605 | Val. Loss: 0.690
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 18 | Train Loss: 0.594 | Val. Loss: 0.691
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 2 epochs.
# Epoch: 19 | Train Loss: 0.590 | Val. Loss: 0.699
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 3 epochs.
# Epoch: 20 | Train Loss: 0.584 | Val. Loss: 0.697
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.690 to 0.672. Saving checkpoint: RESULTS/STARE/RUN_1.pth
# Epoch: 21 | Train Loss: 0.575 | Val. Loss: 0.672
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.672 to 0.665. Saving checkpoint: RESULTS/STARE/RUN_1.pth
# Epoch: 22 | Train Loss: 0.568 | Val. Loss: 0.665
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 23 | Train Loss: 0.556 | Val. Loss: 0.689
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 2 epochs.
# Epoch: 24 | Train Loss: 0.553 | Val. Loss: 0.700
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 3 epochs.
# Epoch: 25 | Train Loss: 0.549 | Val. Loss: 0.705
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 4 epochs.
# Epoch: 26 | Train Loss: 0.548 | Val. Loss: 0.703
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 5 epochs.
# Epoch: 27 | Train Loss: 0.542 | Val. Loss: 0.699
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 6 epochs.
# Epoch: 28 | Train Loss: 0.541 | Val. Loss: 0.671
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 7 epochs.
# Epoch: 29 | Train Loss: 0.525 | Val. Loss: 0.676
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 8 epochs.
# Epoch: 30 | Train Loss: 0.518 | Val. Loss: 0.670
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 9 epochs.
# Epoch: 31 | Train Loss: 0.516 | Val. Loss: 0.666
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 10 epochs.
# Stopping early after 32 epochs due to no improvement in validation loss.
# Run 1 finished with best validation loss: 0.665
#
# Starting run 2/10
# MODEL INTIALIZATION
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from inf to 2.326. Saving checkpoint: RESULTS/STARE/RUN_2.pth
# Epoch: 01 | Train Loss: 1.480 | Val. Loss: 2.326
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 2.326 to 1.769. Saving checkpoint: RESULTS/STARE/RUN_2.pth
# Epoch: 02 | Train Loss: 0.994 | Val. Loss: 1.769
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 1.769 to 1.023. Saving checkpoint: RESULTS/STARE/RUN_2.pth
# Epoch: 03 | Train Loss: 0.891 | Val. Loss: 1.023
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 1.023 to 0.840. Saving checkpoint: RESULTS/STARE/RUN_2.pth
# Epoch: 04 | Train Loss: 0.844 | Val. Loss: 0.840
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.840 to 0.820. Saving checkpoint: RESULTS/STARE/RUN_2.pth
# Epoch: 05 | Train Loss: 0.810 | Val. Loss: 0.820
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.820 to 0.778. Saving checkpoint: RESULTS/STARE/RUN_2.pth
# Epoch: 06 | Train Loss: 0.787 | Val. Loss: 0.778
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.778 to 0.765. Saving checkpoint: RESULTS/STARE/RUN_2.pth
# Epoch: 07 | Train Loss: 0.768 | Val. Loss: 0.765
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.765 to 0.757. Saving checkpoint: RESULTS/STARE/RUN_2.pth
# Epoch: 08 | Train Loss: 0.743 | Val. Loss: 0.757
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 09 | Train Loss: 0.729 | Val. Loss: 0.762
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.757 to 0.731. Saving checkpoint: RESULTS/STARE/RUN_2.pth
# Epoch: 10 | Train Loss: 0.707 | Val. Loss: 0.731
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 11 | Train Loss: 0.693 | Val. Loss: 0.733
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 2 epochs.
# Epoch: 12 | Train Loss: 0.679 | Val. Loss: 0.766
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.731 to 0.719. Saving checkpoint: RESULTS/STARE/RUN_2.pth
# Epoch: 13 | Train Loss: 0.673 | Val. Loss: 0.719
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 14 | Train Loss: 0.656 | Val. Loss: 0.744
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 2 epochs.
# Epoch: 15 | Train Loss: 0.640 | Val. Loss: 0.790
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.719 to 0.700. Saving checkpoint: RESULTS/STARE/RUN_2.pth
# Epoch: 16 | Train Loss: 0.627 | Val. Loss: 0.700
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 17 | Train Loss: 0.612 | Val. Loss: 0.728
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 2 epochs.
# Epoch: 18 | Train Loss: 0.608 | Val. Loss: 0.707
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 3 epochs.
# Epoch: 19 | Train Loss: 0.595 | Val. Loss: 0.764
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 4 epochs.
# Epoch: 20 | Train Loss: 0.586 | Val. Loss: 0.722
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 5 epochs.
# Epoch: 21 | Train Loss: 0.581 | Val. Loss: 0.721
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 6 epochs.
# Epoch: 22 | Train Loss: 0.574 | Val. Loss: 0.736
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.700 to 0.695. Saving checkpoint: RESULTS/STARE/RUN_2.pth
# Epoch: 23 | Train Loss: 0.554 | Val. Loss: 0.695
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 24 | Train Loss: 0.549 | Val. Loss: 0.697
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 2 epochs.
# Epoch: 25 | Train Loss: 0.548 | Val. Loss: 0.704
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 3 epochs.
# Epoch: 26 | Train Loss: 0.544 | Val. Loss: 0.709
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 4 epochs.
# Epoch: 27 | Train Loss: 0.543 | Val. Loss: 0.707
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 5 epochs.
# Epoch: 28 | Train Loss: 0.540 | Val. Loss: 0.706
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 6 epochs.
# Epoch: 29 | Train Loss: 0.539 | Val. Loss: 0.705
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 7 epochs.
# Epoch: 30 | Train Loss: 0.538 | Val. Loss: 0.711
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 8 epochs.
# Epoch: 31 | Train Loss: 0.538 | Val. Loss: 0.713
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 9 epochs.
# Epoch: 32 | Train Loss: 0.537 | Val. Loss: 0.712
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 10 epochs.
# Stopping early after 33 epochs due to no improvement in validation loss.
# Run 2 finished with best validation loss: 0.695
#
# Starting run 3/10
# MODEL INTIALIZATION
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from inf to 2.311. Saving checkpoint: RESULTS/STARE/RUN_3.pth
# Epoch: 01 | Train Loss: 1.505 | Val. Loss: 2.311
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 2.311 to 1.424. Saving checkpoint: RESULTS/STARE/RUN_3.pth
# Epoch: 02 | Train Loss: 0.984 | Val. Loss: 1.424
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 1.424 to 1.013. Saving checkpoint: RESULTS/STARE/RUN_3.pth
# Epoch: 03 | Train Loss: 0.890 | Val. Loss: 1.013
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 1.013 to 0.847. Saving checkpoint: RESULTS/STARE/RUN_3.pth
# Epoch: 04 | Train Loss: 0.845 | Val. Loss: 0.847
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.847 to 0.787. Saving checkpoint: RESULTS/STARE/RUN_3.pth
# Epoch: 05 | Train Loss: 0.810 | Val. Loss: 0.787
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.787 to 0.781. Saving checkpoint: RESULTS/STARE/RUN_3.pth
# Epoch: 06 | Train Loss: 0.788 | Val. Loss: 0.781
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 07 | Train Loss: 0.760 | Val. Loss: 0.783
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.781 to 0.772. Saving checkpoint: RESULTS/STARE/RUN_3.pth
# Epoch: 08 | Train Loss: 0.744 | Val. Loss: 0.772
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.772 to 0.766. Saving checkpoint: RESULTS/STARE/RUN_3.pth
# Epoch: 09 | Train Loss: 0.730 | Val. Loss: 0.766
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 10 | Train Loss: 0.712 | Val. Loss: 0.776
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 2 epochs.
# Epoch: 11 | Train Loss: 0.691 | Val. Loss: 0.767
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 3 epochs.
# Epoch: 12 | Train Loss: 0.677 | Val. Loss: 0.785
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.766 to 0.740. Saving checkpoint: RESULTS/STARE/RUN_3.pth
# Epoch: 13 | Train Loss: 0.662 | Val. Loss: 0.740
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.740 to 0.738. Saving checkpoint: RESULTS/STARE/RUN_3.pth
# Epoch: 14 | Train Loss: 0.653 | Val. Loss: 0.738
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.738 to 0.715. Saving checkpoint: RESULTS/STARE/RUN_3.pth
# Epoch: 15 | Train Loss: 0.636 | Val. Loss: 0.715
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 16 | Train Loss: 0.622 | Val. Loss: 0.719
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.715 to 0.709. Saving checkpoint: RESULTS/STARE/RUN_3.pth
# Epoch: 17 | Train Loss: 0.612 | Val. Loss: 0.709
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 18 | Train Loss: 0.603 | Val. Loss: 0.729
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.709 to 0.708. Saving checkpoint: RESULTS/STARE/RUN_3.pth
# Epoch: 19 | Train Loss: 0.591 | Val. Loss: 0.708
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 20 | Train Loss: 0.582 | Val. Loss: 0.736
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 2 epochs.
# Epoch: 21 | Train Loss: 0.573 | Val. Loss: 0.734
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.708 to 0.692. Saving checkpoint: RESULTS/STARE/RUN_3.pth
# Epoch: 22 | Train Loss: 0.567 | Val. Loss: 0.692
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 23 | Train Loss: 0.564 | Val. Loss: 0.720
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 2 epochs.
# Epoch: 24 | Train Loss: 0.556 | Val. Loss: 0.699
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 3 epochs.
# Epoch: 25 | Train Loss: 0.547 | Val. Loss: 0.725
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 4 epochs.
# Epoch: 26 | Train Loss: 0.544 | Val. Loss: 0.719
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 5 epochs.
# Epoch: 27 | Train Loss: 0.536 | Val. Loss: 0.707
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 6 epochs.
# Epoch: 28 | Train Loss: 0.535 | Val. Loss: 0.730
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 7 epochs.
# Epoch: 29 | Train Loss: 0.522 | Val. Loss: 0.700
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 8 epochs.
# Epoch: 30 | Train Loss: 0.517 | Val. Loss: 0.697
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 9 epochs.
# Epoch: 31 | Train Loss: 0.512 | Val. Loss: 0.700
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 10 epochs.
# Stopping early after 32 epochs due to no improvement in validation loss.
# Run 3 finished with best validation loss: 0.692
#
# Starting run 4/10
# MODEL INTIALIZATION
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from inf to 2.162. Saving checkpoint: RESULTS/STARE/RUN_4.pth
# Epoch: 01 | Train Loss: 1.582 | Val. Loss: 2.162
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 2.162 to 1.527. Saving checkpoint: RESULTS/STARE/RUN_4.pth
# Epoch: 02 | Train Loss: 1.013 | Val. Loss: 1.527
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 1.527 to 1.000. Saving checkpoint: RESULTS/STARE/RUN_4.pth
# Epoch: 03 | Train Loss: 0.896 | Val. Loss: 1.000
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 1.000 to 0.829. Saving checkpoint: RESULTS/STARE/RUN_4.pth
# Epoch: 04 | Train Loss: 0.844 | Val. Loss: 0.829
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.829 to 0.781. Saving checkpoint: RESULTS/STARE/RUN_4.pth
# Epoch: 05 | Train Loss: 0.815 | Val. Loss: 0.781
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 06 | Train Loss: 0.789 | Val. Loss: 0.798
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.781 to 0.728. Saving checkpoint: RESULTS/STARE/RUN_4.pth
# Epoch: 07 | Train Loss: 0.765 | Val. Loss: 0.728
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.728 to 0.723. Saving checkpoint: RESULTS/STARE/RUN_4.pth
# Epoch: 08 | Train Loss: 0.740 | Val. Loss: 0.723
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 09 | Train Loss: 0.720 | Val. Loss: 0.739
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.723 to 0.701. Saving checkpoint: RESULTS/STARE/RUN_4.pth
# Epoch: 10 | Train Loss: 0.707 | Val. Loss: 0.701
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.701 to 0.699. Saving checkpoint: RESULTS/STARE/RUN_4.pth
# Epoch: 11 | Train Loss: 0.687 | Val. Loss: 0.699
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 12 | Train Loss: 0.673 | Val. Loss: 0.724
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 2 epochs.
# Epoch: 13 | Train Loss: 0.668 | Val. Loss: 0.726
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.699 to 0.690. Saving checkpoint: RESULTS/STARE/RUN_4.pth
# Epoch: 14 | Train Loss: 0.646 | Val. Loss: 0.690
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.690 to 0.685. Saving checkpoint: RESULTS/STARE/RUN_4.pth
# Epoch: 15 | Train Loss: 0.629 | Val. Loss: 0.685
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 16 | Train Loss: 0.614 | Val. Loss: 0.691
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.685 to 0.678. Saving checkpoint: RESULTS/STARE/RUN_4.pth
# Epoch: 17 | Train Loss: 0.606 | Val. Loss: 0.678
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 18 | Train Loss: 0.593 | Val. Loss: 0.690
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 2 epochs.
# Epoch: 19 | Train Loss: 0.584 | Val. Loss: 0.712
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 3 epochs.
# Epoch: 20 | Train Loss: 0.579 | Val. Loss: 0.706
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 4 epochs.
# Epoch: 21 | Train Loss: 0.571 | Val. Loss: 0.687
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 5 epochs.
# Epoch: 22 | Train Loss: 0.562 | Val. Loss: 0.690
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 6 epochs.
# Epoch: 23 | Train Loss: 0.558 | Val. Loss: 0.691
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.678 to 0.674. Saving checkpoint: RESULTS/STARE/RUN_4.pth
# Epoch: 24 | Train Loss: 0.546 | Val. Loss: 0.674
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 25 | Train Loss: 0.537 | Val. Loss: 0.685
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 2 epochs.
# Epoch: 26 | Train Loss: 0.531 | Val. Loss: 0.680
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 3 epochs.
# Epoch: 27 | Train Loss: 0.530 | Val. Loss: 0.683
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 4 epochs.
# Epoch: 28 | Train Loss: 0.529 | Val. Loss: 0.684
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 5 epochs.
# Epoch: 29 | Train Loss: 0.526 | Val. Loss: 0.680
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 6 epochs.
# Epoch: 30 | Train Loss: 0.525 | Val. Loss: 0.684
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 7 epochs.
# Epoch: 31 | Train Loss: 0.524 | Val. Loss: 0.682
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 8 epochs.
# Epoch: 32 | Train Loss: 0.522 | Val. Loss: 0.680
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 9 epochs.
# Epoch: 33 | Train Loss: 0.523 | Val. Loss: 0.680
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 10 epochs.
# Stopping early after 34 epochs due to no improvement in validation loss.
# Run 4 finished with best validation loss: 0.674
#
# Starting run 5/10
# MODEL INTIALIZATION
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from inf to 2.513. Saving checkpoint: RESULTS/STARE/RUN_5.pth
# Epoch: 01 | Train Loss: 1.510 | Val. Loss: 2.513
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 2.513 to 2.096. Saving checkpoint: RESULTS/STARE/RUN_5.pth
# Epoch: 02 | Train Loss: 0.986 | Val. Loss: 2.096
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 2.096 to 0.975. Saving checkpoint: RESULTS/STARE/RUN_5.pth
# Epoch: 03 | Train Loss: 0.890 | Val. Loss: 0.975
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.975 to 0.846. Saving checkpoint: RESULTS/STARE/RUN_5.pth
# Epoch: 04 | Train Loss: 0.844 | Val. Loss: 0.846
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.846 to 0.824. Saving checkpoint: RESULTS/STARE/RUN_5.pth
# Epoch: 05 | Train Loss: 0.807 | Val. Loss: 0.824
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.824 to 0.795. Saving checkpoint: RESULTS/STARE/RUN_5.pth
# Epoch: 06 | Train Loss: 0.784 | Val. Loss: 0.795
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 07 | Train Loss: 0.765 | Val. Loss: 0.813
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.795 to 0.753. Saving checkpoint: RESULTS/STARE/RUN_5.pth
# Epoch: 08 | Train Loss: 0.741 | Val. Loss: 0.753
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.753 to 0.738. Saving checkpoint: RESULTS/STARE/RUN_5.pth
# Epoch: 09 | Train Loss: 0.724 | Val. Loss: 0.738
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 10 | Train Loss: 0.706 | Val. Loss: 0.748
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 2 epochs.
# Epoch: 11 | Train Loss: 0.688 | Val. Loss: 0.759
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.738 to 0.698. Saving checkpoint: RESULTS/STARE/RUN_5.pth
# Epoch: 12 | Train Loss: 0.662 | Val. Loss: 0.698
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.698 to 0.694. Saving checkpoint: RESULTS/STARE/RUN_5.pth
# Epoch: 13 | Train Loss: 0.659 | Val. Loss: 0.694
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 14 | Train Loss: 0.641 | Val. Loss: 0.707
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.694 to 0.694. Saving checkpoint: RESULTS/STARE/RUN_5.pth
# Epoch: 15 | Train Loss: 0.622 | Val. Loss: 0.694
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.694 to 0.685. Saving checkpoint: RESULTS/STARE/RUN_5.pth
# Epoch: 16 | Train Loss: 0.614 | Val. Loss: 0.685
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 17 | Train Loss: 0.608 | Val. Loss: 0.702
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 2 epochs.
# Epoch: 18 | Train Loss: 0.596 | Val. Loss: 0.721
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 3 epochs.
# Epoch: 19 | Train Loss: 0.588 | Val. Loss: 0.733
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 4 epochs.
# Epoch: 20 | Train Loss: 0.581 | Val. Loss: 0.711
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 5 epochs.
# Epoch: 21 | Train Loss: 0.572 | Val. Loss: 0.703
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 6 epochs.
# Epoch: 22 | Train Loss: 0.567 | Val. Loss: 0.715
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 7 epochs.
# Epoch: 23 | Train Loss: 0.552 | Val. Loss: 0.696
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 8 epochs.
# Epoch: 24 | Train Loss: 0.544 | Val. Loss: 0.700
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 9 epochs.
# Epoch: 25 | Train Loss: 0.542 | Val. Loss: 0.693
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 10 epochs.
# Stopping early after 26 epochs due to no improvement in validation loss.
# Run 5 finished with best validation loss: 0.685
#
# Starting run 6/10
# MODEL INTIALIZATION
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from inf to 2.267. Saving checkpoint: RESULTS/STARE/RUN_6.pth
# Epoch: 01 | Train Loss: 1.682 | Val. Loss: 2.267
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 2.267 to 1.937. Saving checkpoint: RESULTS/STARE/RUN_6.pth
# Epoch: 02 | Train Loss: 1.029 | Val. Loss: 1.937
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 1.937 to 0.976. Saving checkpoint: RESULTS/STARE/RUN_6.pth
# Epoch: 03 | Train Loss: 0.909 | Val. Loss: 0.976
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.976 to 0.823. Saving checkpoint: RESULTS/STARE/RUN_6.pth
# Epoch: 04 | Train Loss: 0.853 | Val. Loss: 0.823
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.823 to 0.786. Saving checkpoint: RESULTS/STARE/RUN_6.pth
# Epoch: 05 | Train Loss: 0.817 | Val. Loss: 0.786
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.786 to 0.786. Saving checkpoint: RESULTS/STARE/RUN_6.pth
# Epoch: 06 | Train Loss: 0.790 | Val. Loss: 0.786
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.786 to 0.761. Saving checkpoint: RESULTS/STARE/RUN_6.pth
# Epoch: 07 | Train Loss: 0.764 | Val. Loss: 0.761
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 08 | Train Loss: 0.743 | Val. Loss: 0.774
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 2 epochs.
# Epoch: 09 | Train Loss: 0.727 | Val. Loss: 0.784
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.761 to 0.761. Saving checkpoint: RESULTS/STARE/RUN_6.pth
# Epoch: 10 | Train Loss: 0.711 | Val. Loss: 0.761
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.761 to 0.710. Saving checkpoint: RESULTS/STARE/RUN_6.pth
# Epoch: 11 | Train Loss: 0.692 | Val. Loss: 0.710
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 12 | Train Loss: 0.679 | Val. Loss: 0.721
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 2 epochs.
# Epoch: 13 | Train Loss: 0.657 | Val. Loss: 0.724
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.710 to 0.707. Saving checkpoint: RESULTS/STARE/RUN_6.pth
# Epoch: 14 | Train Loss: 0.642 | Val. Loss: 0.707
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 15 | Train Loss: 0.628 | Val. Loss: 0.710
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.707 to 0.702. Saving checkpoint: RESULTS/STARE/RUN_6.pth
# Epoch: 16 | Train Loss: 0.618 | Val. Loss: 0.702
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.702 to 0.699. Saving checkpoint: RESULTS/STARE/RUN_6.pth
# Epoch: 17 | Train Loss: 0.608 | Val. Loss: 0.699
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 18 | Train Loss: 0.596 | Val. Loss: 0.731
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 2 epochs.
# Epoch: 19 | Train Loss: 0.589 | Val. Loss: 0.707
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 3 epochs.
# Epoch: 20 | Train Loss: 0.584 | Val. Loss: 0.718
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.699 to 0.695. Saving checkpoint: RESULTS/STARE/RUN_6.pth
# Epoch: 21 | Train Loss: 0.577 | Val. Loss: 0.695
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 22 | Train Loss: 0.569 | Val. Loss: 0.734
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 2 epochs.
# Epoch: 23 | Train Loss: 0.568 | Val. Loss: 0.732
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 3 epochs.
# Epoch: 24 | Train Loss: 0.562 | Val. Loss: 0.718
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 4 epochs.
# Epoch: 25 | Train Loss: 0.552 | Val. Loss: 0.711
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 5 epochs.
# Epoch: 26 | Train Loss: 0.543 | Val. Loss: 0.764
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 6 epochs.
# Epoch: 27 | Train Loss: 0.536 | Val. Loss: 0.719
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 7 epochs.
# Epoch: 28 | Train Loss: 0.525 | Val. Loss: 0.717
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 8 epochs.
# Epoch: 29 | Train Loss: 0.522 | Val. Loss: 0.707
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# ...
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 20 | Train Loss: 0.585 | Val. Loss: 0.703
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.696 to 0.695. Saving checkpoint: RESULTS/STARE/RUN_9.pth
# Epoch: 21 | Train Loss: 0.574 | Val. Loss: 0.695
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 22 | Train Loss: 0.568 | Val. Loss: 0.712
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 2 epochs.
# Epoch: 23 | Train Loss: 0.560 | Val. Loss: 0.708
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 3 epochs.
# Epoch: 24 | Train Loss: 0.562 | Val. Loss: 0.707
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 4 epochs.
# Epoch: 25 | Train Loss: 0.560 | Val. Loss: 0.695
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 5 epochs.
# Epoch: 26 | Train Loss: 0.555 | Val. Loss: 0.714
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.695 to 0.688. Saving checkpoint: RESULTS/STARE/RUN_9.pth
# Epoch: 27 | Train Loss: 0.545 | Val. Loss: 0.688
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.688 to 0.686. Saving checkpoint: RESULTS/STARE/RUN_9.pth
# Epoch: 28 | Train Loss: 0.538 | Val. Loss: 0.686
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 29 | Train Loss: 0.536 | Val. Loss: 0.699
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 2 epochs.
# Epoch: 30 | Train Loss: 0.528 | Val. Loss: 0.699
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 3 epochs.
# Epoch: 31 | Train Loss: 0.529 | Val. Loss: 0.691
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 4 epochs.
# Epoch: 32 | Train Loss: 0.525 | Val. Loss: 0.706
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 5 epochs.
# Epoch: 33 | Train Loss: 0.519 | Val. Loss: 0.689
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 6 epochs.
# Epoch: 34 | Train Loss: 0.516 | Val. Loss: 0.691
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 7 epochs.
# Epoch: 35 | Train Loss: 0.505 | Val. Loss: 0.700
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 8 epochs.
# Epoch: 36 | Train Loss: 0.501 | Val. Loss: 0.692
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.686 to 0.685. Saving checkpoint: RESULTS/STARE/RUN_9.pth
# Epoch: 37 | Train Loss: 0.501 | Val. Loss: 0.685
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 38 | Train Loss: 0.498 | Val. Loss: 0.694
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 2 epochs.
# Epoch: 39 | Train Loss: 0.496 | Val. Loss: 0.694
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 3 epochs.
# Epoch: 40 | Train Loss: 0.496 | Val. Loss: 0.691
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 4 epochs.
# Epoch: 41 | Train Loss: 0.498 | Val. Loss: 0.694
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 5 epochs.
# Epoch: 42 | Train Loss: 0.495 | Val. Loss: 0.692
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 6 epochs.
# Epoch: 43 | Train Loss: 0.497 | Val. Loss: 0.686
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 7 epochs.
# Epoch: 44 | Train Loss: 0.494 | Val. Loss: 0.696
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 8 epochs.
# Epoch: 45 | Train Loss: 0.494 | Val. Loss: 0.695
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 9 epochs.
# Epoch: 46 | Train Loss: 0.494 | Val. Loss: 0.696
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 10 epochs.
# Stopping early after 47 epochs due to no improvement in validation loss.
# Run 9 finished with best validation loss: 0.685
#
# Starting run 10/10
# MODEL INTIALIZATION
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from inf to 2.370. Saving checkpoint: RESULTS/STARE/RUN_10.pth
# Epoch: 01 | Train Loss: 1.494 | Val. Loss: 2.370
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 2.370 to 1.681. Saving checkpoint: RESULTS/STARE/RUN_10.pth
# Epoch: 02 | Train Loss: 1.001 | Val. Loss: 1.681
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 1.681 to 0.934. Saving checkpoint: RESULTS/STARE/RUN_10.pth
# Epoch: 03 | Train Loss: 0.900 | Val. Loss: 0.934
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.934 to 0.923. Saving checkpoint: RESULTS/STARE/RUN_10.pth
# Epoch: 04 | Train Loss: 0.845 | Val. Loss: 0.923
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.923 to 0.811. Saving checkpoint: RESULTS/STARE/RUN_10.pth
# Epoch: 05 | Train Loss: 0.814 | Val. Loss: 0.811
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 06 | Train Loss: 0.785 | Val. Loss: 0.813
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.811 to 0.804. Saving checkpoint: RESULTS/STARE/RUN_10.pth
# Epoch: 07 | Train Loss: 0.762 | Val. Loss: 0.804
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.804 to 0.783. Saving checkpoint: RESULTS/STARE/RUN_10.pth
# Epoch: 08 | Train Loss: 0.740 | Val. Loss: 0.783
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.783 to 0.769. Saving checkpoint: RESULTS/STARE/RUN_10.pth
# Epoch: 09 | Train Loss: 0.718 | Val. Loss: 0.769
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.769 to 0.764. Saving checkpoint: RESULTS/STARE/RUN_10.pth
# Epoch: 10 | Train Loss: 0.697 | Val. Loss: 0.764
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 11 | Train Loss: 0.683 | Val. Loss: 0.784
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.764 to 0.748. Saving checkpoint: RESULTS/STARE/RUN_10.pth
# Epoch: 12 | Train Loss: 0.671 | Val. Loss: 0.748
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.748 to 0.729. Saving checkpoint: RESULTS/STARE/RUN_10.pth
# Epoch: 13 | Train Loss: 0.654 | Val. Loss: 0.729
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.729 to 0.714. Saving checkpoint: RESULTS/STARE/RUN_10.pth
# Epoch: 14 | Train Loss: 0.642 | Val. Loss: 0.714
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 15 | Train Loss: 0.633 | Val. Loss: 0.769
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.714 to 0.712. Saving checkpoint: RESULTS/STARE/RUN_10.pth
# Epoch: 16 | Train Loss: 0.618 | Val. Loss: 0.712
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 17 | Train Loss: 0.605 | Val. Loss: 0.726
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 2 epochs.
# Epoch: 18 | Train Loss: 0.592 | Val. Loss: 0.770
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 3 epochs.
# Epoch: 19 | Train Loss: 0.587 | Val. Loss: 0.730
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 4 epochs.
# Epoch: 20 | Train Loss: 0.584 | Val. Loss: 0.716
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 5 epochs.
# Epoch: 21 | Train Loss: 0.572 | Val. Loss: 0.726
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 6 epochs.
# Epoch: 22 | Train Loss: 0.566 | Val. Loss: 0.714
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 7 epochs.
# Epoch: 23 | Train Loss: 0.551 | Val. Loss: 0.716
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.712 to 0.699. Saving checkpoint: RESULTS/STARE/RUN_10.pth
# Epoch: 24 | Train Loss: 0.543 | Val. Loss: 0.699
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.699 to 0.697. Saving checkpoint: RESULTS/STARE/RUN_10.pth
# Epoch: 25 | Train Loss: 0.539 | Val. Loss: 0.697
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 26 | Train Loss: 0.536 | Val. Loss: 0.710
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 2 epochs.
# Epoch: 27 | Train Loss: 0.534 | Val. Loss: 0.714
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 3 epochs.
# Epoch: 28 | Train Loss: 0.535 | Val. Loss: 0.711
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 4 epochs.
# Epoch: 29 | Train Loss: 0.532 | Val. Loss: 0.715
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 5 epochs.
# Epoch: 30 | Train Loss: 0.531 | Val. Loss: 0.718
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 6 epochs.
# Epoch: 31 | Train Loss: 0.530 | Val. Loss: 0.709
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 7 epochs.
# Epoch: 32 | Train Loss: 0.529 | Val. Loss: 0.710
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 8 epochs.
# Epoch: 33 | Train Loss: 0.528 | Val. Loss: 0.712
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 9 epochs.
# Epoch: 34 | Train Loss: 0.527 | Val. Loss: 0.716
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 10 epochs.
# Stopping early after 35 epochs due to no improvement in validation loss.
# Run 10 finished with best validation loss: 0.697
#
# Mean best validation loss over 10 runs: 0.684
# Std of best validation loss over 10 runs: 0.010

# %%
# Plot accuracies over epochs
plt.figure()
plt.plot(range(1, epoch+2), total_train_loss, label=' train_losses')
plt.plot(range(1, epoch+2), total_val_loss, label='val_losses')
plt.xlabel('Epoch')
plt.ylabel('LOSS')
plt.legend()
plt.title('Train and Validation losses Over Epochs')
plt.show()

# %%
def visualize_predictions(model, loader, device, num_images=5):
    model.eval()
    num_images_plotted = 0
    with torch.no_grad():
        for idx, (images, masks) in enumerate(loader):
            images = images.to(device)
            outputs = model(images)[0]
            preds = torch.sigmoid(outputs) > 0.5
            preds = preds.cpu().numpy()
            masks = masks.cpu().numpy()

            for i in range(images.size(0)):
                plt.figure()
                plt.subplot(1, 3, 1)
                plt.imshow(images[i].permute(1, 2, 0).cpu())
                plt.title('Input Image')

                plt.subplot(1, 3, 2)
                plt.imshow(masks[i][0], cmap='gray')
                plt.title('Ground Truth')

                plt.subplot(1, 3, 3)
                plt.imshow(preds[i].transpose(1, 2, 0), cmap='gray')
                plt.title('Prediction')

                plt.show()
                print(i)

                num_images_plotted += i 
                if i+1 >= num_images:
                    break
            
            if idx+1 >= num_images or num_images_plotted >= num_images:
                break

visualize_predictions(model, val_loader, device, num_images=5)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# # Testing after Training

# %%
import glob
import os
weight_files = sorted(glob.glob(os.path.join(folder_path, "*.pth")))
print(weight_files)
# Out:
# ['RESULTS/STARE/RUN_1.pth', 'RESULTS/STARE/RUN_10.pth', 'RESULTS/STARE/RUN_2.pth', 'RESULTS/STARE/RUN_3.pth', 'RESULTS/STARE/RUN_4.pth', 'RESULTS/STARE/RUN_5.pth', 'RESULTS/STARE/RUN_6.pth', 'RESULTS/STARE/RUN_7.pth', 'RESULTS/STARE/RUN_8.pth', 'RESULTS/STARE/RUN_9.pth']

# %%
import torch
import numpy as np
from sklearn.metrics import (precision_score, recall_score, f1_score,
                             roc_auc_score, jaccard_score, accuracy_score,
                             confusion_matrix)

def calculate_iou(pred, target):
    intersection = (pred & target).sum()
    union = (pred | target).sum()
    iou = (intersection + 1e-6) / (union + 1e-6) 
    return iou

def calculate_dice(pred, target):
    intersection = (pred & target).sum()
    dice = (2 * intersection + 1e-6) / (pred.sum() + target.sum() + 1e-6)
    return dice

def calculate_specificity(pred, target):
    tn, fp, fn, tp = confusion_matrix(target, pred).ravel()
    specificity = tn / (tn + fp + 1e-6)
    return specificity

weight_files = sorted(glob.glob(os.path.join(folder_path, "*.pth")))

all_weight_ious = []
all_weight_dice = []
all_weight_precisions = []
all_weight_recalls = []
all_weight_f1s = []
all_weight_aucs = []
all_weight_jaccard = []
all_weight_accuracies = []
all_weight_specificities = []

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

output_file = (f'{folder_path}evaluation_results.txt')
with open(output_file, "w") as outfile:
    for idx, weight_file in enumerate(weight_files, start=1):
        MODEL.load_state_dict(torch.load(weight_file, map_location=device))
        MODEL.to(device)
        MODEL.eval()  

        batch_ious = []
        batch_dice = []
        batch_precisions = []
        batch_recalls = []
        batch_f1s = []
        batch_aucs = []
        batch_jaccard = []
        batch_accuracies = []
        batch_specificities = []

        with torch.no_grad():
            for batch in val_loader:
                images, masks = batch
                images = images.to(device)
                masks = masks.to(device)

                outputs = MODEL(images)[0]
                preds = torch.sigmoid(outputs) > 0.5  
                preds = preds.int()
                masks = masks.int()

                preds_np = preds.cpu().numpy().flatten()
                masks_np = masks.cpu().numpy().flatten()

                iou = calculate_iou(preds_np, masks_np)
                dice = calculate_dice(preds_np, masks_np)
                precision = precision_score(masks_np, preds_np, zero_division=1)
                recall = recall_score(masks_np, preds_np, zero_division=1)  
                f1 = f1_score(masks_np, preds_np, zero_division=1)
                jaccard = jaccard_score(masks_np, preds_np, zero_division=1)
                accuracy = accuracy_score(masks_np, preds_np)
                specificity = calculate_specificity(preds_np, masks_np)
                auc = roc_auc_score(masks_np, torch.sigmoid(outputs).cpu().numpy().flatten())

                batch_ious.append(iou)
                batch_dice.append(dice)
                batch_precisions.append(precision)
                batch_recalls.append(recall)
                batch_f1s.append(f1)
                batch_aucs.append(auc)
                batch_jaccard.append(jaccard)
                batch_accuracies.append(accuracy)
                batch_specificities.append(specificity)

        avg_iou = np.mean(batch_ious)
        avg_dice = np.mean(batch_dice)
        avg_precision = np.mean(batch_precisions)
        avg_recall = np.mean(batch_recalls)
        avg_f1 = np.mean(batch_f1s)
        avg_auc = np.mean(batch_aucs)
        avg_jaccard = np.mean(batch_jaccard)
        avg_accuracy = np.mean(batch_accuracies)
        avg_specificity = np.mean(batch_specificities)

        output_str = f"Weight File {idx} ({weight_file}):\n"
        output_str += f"  Average IoU: {avg_iou:.4f}\n"
        output_str += f"  Average Dice Coefficient: {avg_dice:.4f}\n"
        output_str += f"  Average Precision: {avg_precision:.4f}\n"
        output_str += f"  Average Recall (Sensitivity): {avg_recall:.4f}\n"
        output_str += f"  Average F1 Score: {avg_f1:.4f}\n"
        output_str += f"  Average AUC: {avg_auc:.4f}\n"
        output_str += f"  Average Jaccard Score: {avg_jaccard:.4f}\n"
        output_str += f"  Average Accuracy: {avg_accuracy:.4f}\n"
        output_str += f"  Average Specificity: {avg_specificity:.4f}\n\n"

        print(output_str)
        outfile.write(output_str)

        all_weight_ious.append(avg_iou)
        all_weight_dice.append(avg_dice)
        all_weight_precisions.append(avg_precision)
        all_weight_recalls.append(avg_recall)
        all_weight_f1s.append(avg_f1)
        all_weight_aucs.append(avg_auc)
        all_weight_jaccard.append(avg_jaccard)
        all_weight_accuracies.append(avg_accuracy)
        all_weight_specificities.append(avg_specificity)

    overall_str = "Overall Metrics Across All Weight Files:\n"
    overall_str += f"Mean IoU: {np.mean(all_weight_ious):.4f}, Std IoU: {np.std(all_weight_ious):.4f}\n"
    overall_str += f"Mean Dice Coefficient: {np.mean(all_weight_dice):.4f}, Std Dice: {np.std(all_weight_dice):.4f}\n"
    overall_str += f"Mean Precision: {np.mean(all_weight_precisions):.4f}, Std Precision: {np.std(all_weight_precisions):.4f}\n"
    overall_str += f"Mean Recall (Sensitivity): {np.mean(all_weight_recalls):.4f}, Std Recall: {np.std(all_weight_recalls):.4f}\n"
    overall_str += f"Mean F1 Score: {np.mean(all_weight_f1s):.4f}, Std F1: {np.std(all_weight_f1s):.4f}\n"
    overall_str += f"Mean AUC: {np.mean(all_weight_aucs):.4f}, Std AUC: {np.std(all_weight_aucs):.4f}\n"
    overall_str += f"Mean Jaccard Score: {np.mean(all_weight_jaccard):.4f}, Std Jaccard: {np.std(all_weight_jaccard):.4f}\n"
    overall_str += f"Mean Accuracy: {np.mean(all_weight_accuracies):.4f}, Std Accuracy: {np.std(all_weight_accuracies):.4f}\n"
    overall_str += f"Mean Specificity: {np.mean(all_weight_specificities):.4f}, Std Specificity: {np.std(all_weight_specificities):.4f}\n"

    print(overall_str)
    outfile.write(overall_str)
# Out:
# Weight File 1 (RESULTS/STARE/RUN_1.pth):
#   Average IoU: 0.5659
#   Average Dice Coefficient: 0.7228
#   Average Precision: 0.6175
#   Average Recall (Sensitivity): 0.8713
#   Average F1 Score: 0.7228
#   Average AUC: 0.9763
#   Average Jaccard Score: 0.5659
#   Average Accuracy: 0.9608
#   Average Specificity: 0.9664
#
#
# Weight File 2 (RESULTS/STARE/RUN_10.pth):
#   Average IoU: 0.5616
#   Average Dice Coefficient: 0.7193
#   Average Precision: 0.6268
#   Average Recall (Sensitivity): 0.8438
#   Average F1 Score: 0.7193
#   Average AUC: 0.9705
#   Average Jaccard Score: 0.5616
#   Average Accuracy: 0.9614
#   Average Specificity: 0.9687
#
#
# Weight File 3 (RESULTS/STARE/RUN_2.pth):
#   Average IoU: 0.5583
#   Average Dice Coefficient: 0.7166
#   Average Precision: 0.6219
#   Average Recall (Sensitivity): 0.8452
#   Average F1 Score: 0.7166
#   Average AUC: 0.9670
#   Average Jaccard Score: 0.5583
#   Average Accuracy: 0.9608
#   Average Specificity: 0.9680
#
#
# Weight File 4 (RESULTS/STARE/RUN_3.pth):
#   Average IoU: 0.5530
#   Average Dice Coefficient: 0.7122
#   Average Precision: 0.6155
#   Average Recall (Sensitivity): 0.8448
#   Average F1 Score: 0.7122
#   Average AUC: 0.9669
#   Average Jaccard Score: 0.5530
#   Average Accuracy: 0.9599
#   Average Specificity: 0.9671
#
#
# Weight File 5 (RESULTS/STARE/RUN_4.pth):
#   Average IoU: 0.5816
#   Average Dice Coefficient: 0.7355
#   Average Precision: 0.6517
#   Average Recall (Sensitivity): 0.8441
#   Average F1 Score: 0.7355
#   Average AUC: 0.9723
#   Average Jaccard Score: 0.5816
#   Average Accuracy: 0.9644
#   Average Specificity: 0.9719
#
#
# Weight File 6 (RESULTS/STARE/RUN_5.pth):
#   Average IoU: 0.5394
#   Average Dice Coefficient: 0.7008
#   Average Precision: 0.5786
#   Average Recall (Sensitivity): 0.8883
#   Average F1 Score: 0.7008
#   Average AUC: 0.9763
#   Average Jaccard Score: 0.5394
#   Average Accuracy: 0.9555
#   Average Specificity: 0.9597
#
#
# Weight File 7 (RESULTS/STARE/RUN_6.pth):
#   Average IoU: 0.5399
#   Average Dice Coefficient: 0.7012
#   Average Precision: 0.5804
#   Average Recall (Sensitivity): 0.8858
#   Average F1 Score: 0.7012
#   Average AUC: 0.9749
#   Average Jaccard Score: 0.5399
#   Average Accuracy: 0.9557
#   Average Specificity: 0.9601
#
#
# Weight File 8 (RESULTS/STARE/RUN_7.pth):
#   Average IoU: 0.5795
#   Average Dice Coefficient: 0.7338
#   Average Precision: 0.6483
#   Average Recall (Sensitivity): 0.8453
#   Average F1 Score: 0.7338
#   Average AUC: 0.9739
#   Average Jaccard Score: 0.5795
#   Average Accuracy: 0.9640
#   Average Specificity: 0.9714
#
#
# Weight File 9 (RESULTS/STARE/RUN_8.pth):
#   Average IoU: 0.5733
#   Average Dice Coefficient: 0.7288
#   Average Precision: 0.6341
#   Average Recall (Sensitivity): 0.8567
#   Average F1 Score: 0.7288
#   Average AUC: 0.9795
#   Average Jaccard Score: 0.5733
#   Average Accuracy: 0.9626
#   Average Specificity: 0.9692
#
#
# Weight File 10 (RESULTS/STARE/RUN_9.pth):
#   Average IoU: 0.5761
#   Average Dice Coefficient: 0.7310
#   Average Precision: 0.6433
#   Average Recall (Sensitivity): 0.8464
#   Average F1 Score: 0.7310
#   Average AUC: 0.9735
#   Average Jaccard Score: 0.5761
#   Average Accuracy: 0.9635
#   Average Specificity: 0.9708
#
#
# Overall Metrics Across All Weight Files:
# Mean IoU: 0.5629, Std IoU: 0.0146
# Mean Dice Coefficient: 0.7202, Std Dice: 0.0120
# Mean Precision: 0.6218, Std Precision: 0.0242
# Mean Recall (Sensitivity): 0.8572, Std Recall: 0.0170
# Mean F1 Score: 0.7202, Std F1: 0.0120
# Mean AUC: 0.9731, Std AUC: 0.0039
# Mean Jaccard Score: 0.5629, Std Jaccard: 0.0146
# Mean Accuracy: 0.9608, Std Accuracy: 0.0030
# Mean Specificity: 0.9673, Std Specificity: 0.0041
