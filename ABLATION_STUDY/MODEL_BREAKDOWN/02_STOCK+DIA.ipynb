# %% [markdown]
# # ENV

# %%
! module load mamba/latest
# Out:
# =====================================================================
# This module is only for creating or activating Python environments:
# $ mamba create -n myenv -c conda-forge python=3 <package_name>
# $ source activate myenv
#
# Only run "pip install" after activating an environment.
# Running pip without activating an environment is known to cause issues.
#
# To list available environments:
# $ mamba info --envs
#
# Other uses are not tested. More info: https://links.asu.edu/solpy
# =====================================================================

# %%
! source activate PYTORCH_ENV_AUG_2024

# %% [markdown]
# # Imports

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
import torchvision.transforms as transforms
from torchvision import datasets
from PIL import Image
import os
import numpy as np
import matplotlib.pyplot as plt
import albumentations as A
from albumentations.pytorch import ToTensorV2
from PIL import Image
from torchinfo import summary
import torch.nn.functional as F
from operator import add

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)
# Out:
# cuda

# %%
PATCH_SIZE = 256
OVERLAP = '50'

# %% [markdown]
# # Model

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class UNet(nn.Module):
    def __init__(self):
        super(UNet, self).__init__()
        
        # Downsampling (encoder) blocks
        self.enc1 = MultiPathBlock(in_channels = 1, out_channels = 16, stride=1, dilation= [1,3,5,7])
        self.enc2 = MultiPathBlock(in_channels = 16, out_channels = 32, stride=1, dilation= [1,3,5])
        self.enc3 = MultiPathBlock(in_channels = 32, out_channels = 64, stride=1, dilation= [1,3])
        self.enc4 = MultiPathBlock(in_channels = 64, out_channels = 128, stride=1, dilation= [1])

        # Bottleneck
        self.bottleneck = self.conv_block(128, 256)

        # Upsampling (decoder) blocks
        self.upconv4 = nn.ConvTranspose2d(256, 128, kernel_size=2, stride=2)
        self.dec4 = MultiPathBlock(in_channels = 128 + 128, out_channels = 128, stride=1, dilation= [1])

        self.upconv3 = nn.ConvTranspose2d(128, 64, kernel_size=2, stride=2)
        self.dec3 = MultiPathBlock(in_channels = 64 + 64, out_channels = 64, stride=1, dilation= [1,3])

        self.upconv2 = nn.ConvTranspose2d(64, 32, kernel_size=2, stride=2)
        self.dec2 = MultiPathBlock(in_channels = 32 + 32, out_channels = 32, stride=1, dilation= [1,3,5])

        self.upconv1 = nn.ConvTranspose2d(32, 16, kernel_size=2, stride=2)
        self.dec1 = MultiPathBlock(in_channels = 16 + 16, out_channels = 16, stride=1, dilation= [1,3,5,7])

        # Final output layer
        self.final_conv = nn.Conv2d(16, 1, kernel_size=1)


        # Intermediate Layers
        self.out_2 = self.conv_block_intermediate_output(32, 1)
        self.out_3 = self.conv_block_intermediate_output(64, 1)
        self.out_4 = self.conv_block_intermediate_output(128, 1)
    
    def conv_block_intermediate_output(self, in_channels, out_channels):
        return nn.Conv2d(in_channels, out_channels, kernel_size=1)
    def conv_block(self, in_channels, out_channels):
        block = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size = 3, dilation=1, padding = 1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels,  kernel_size = 3, dilation=1,padding = 1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True)
        )
        return block

    def forward(self, x):
        # Encoder path
        e1 = self.enc1(x)
        e2 = self.enc2(F.max_pool2d(e1, 2))
        e3 = self.enc3(F.max_pool2d(e2, 2))
        e4 = self.enc4(F.max_pool2d(e3, 2))

        # Bottleneck
        b = self.bottleneck(F.max_pool2d(e4, 2))

        # Decoder path
        d4 = self.upconv4(b)
        d4 = torch.cat((d4, e4), dim=1)
        d4 = self.dec4(d4)
        out_d4 = self.out_4(d4)  # Intermediate output for deep supervision

        d3 = self.upconv3(d4)
        d3 = torch.cat((d3, e3), dim=1)
        d3 = self.dec3(d3)
        out_d3 = self.out_3(d3)  # Intermediate output for deep supervision

        d2 = self.upconv2(d3)
        d2 = torch.cat((d2, e2), dim=1)
        d2 = self.dec2(d2)
        out_d2 = self.out_2(d2)  # Intermediate output for deep supervision

        d1 = self.upconv1(d2)
        d1 = torch.cat((d1, e1), dim=1)
        d1 = self.dec1(d1)

        # Final output
        out = self.final_conv(d1)
        return out, out_d4, out_d3, out_d2  # Return final and intermediate outputs

# Define the Standard Convolution Block
class StandardConvBlock(nn.Module):
    def __init__(self, in_channels, out_channels, stride=1, dilation=1):
        super(StandardConvBlock, self).__init__()
        self.conv = nn.Conv2d(
            in_channels, out_channels, kernel_size=3, stride=stride, padding=dilation, dilation=dilation, bias=False
        )
        self.bn = nn.BatchNorm2d(out_channels)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.conv(x)
        x = self.bn(x)
        x = self.relu(x)
        return x

class SinglePathBlock(nn.Module):
    def __init__(self,in_channels, out_channels, stride=1, dilation= 1):
        super(SinglePathBlock,self).__init__()
        
        self.single_path_block_1 =  nn.Sequential(
            StandardConvBlock(in_channels, out_channels, stride=stride, dilation=dilation),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(),
            )
        
        self.single_path_block_2 =  nn.Sequential(
            StandardConvBlock(out_channels, out_channels, stride=stride, dilation=dilation),
            nn.BatchNorm2d(out_channels),
            # CBAM(out_channels),
            nn.ReLU(),
            )
        
        self.channel_modification = nn.Conv2d(in_channels,out_channels,kernel_size = 1)

    def forward(self,x):

        identity = x
        out_block_1 = self.single_path_block_1(x)
        
        if out_block_1.shape[1] != x.shape[1]:
            identity = self.channel_modification(x)
        
        out_block_2 = self.single_path_block_2(out_block_1)
        
        out_block_2 = out_block_2 + identity

        return out_block_2


# Define the Residual Block with CBAM in parallel paths
class MultiPathBlock(nn.Module):
    def __init__(self, in_channels, out_channels, stride=1, dilation= [1, 3, 5, 7]):
        super(MultiPathBlock, self).__init__()
        
        self.parallel_paths = nn.ModuleList([
            SinglePathBlock(in_channels, out_channels, stride=1, dilation= d)
            for d in dilation
        ])

    def forward(self, x):
        # Add outputs of all parallel paths
        out = 0
        for path in self.parallel_paths:
            out += path(x)

        # Add the residual connection
        # out += identity
        # out = F.relu(out)
        return out

# Define the CBAM Block
class CBAM(nn.Module):
    def __init__(self, channels, reduction_ratio=16, kernel_size=7):
        super(CBAM, self).__init__()
        # Channel Attention Module
        self.channel_attention = nn.Sequential(
            nn.AdaptiveAvgPool2d(1),
            nn.Conv2d(channels, channels // reduction_ratio, kernel_size=1, bias=False),
            nn.ReLU(),
            nn.Conv2d(channels // reduction_ratio, channels, kernel_size=1, bias=False),
            nn.Sigmoid()
        )
        # Spatial Attention Module
        self.spatial_attention = nn.Sequential(
            nn.Conv2d(2, 1, kernel_size=kernel_size, stride=1, padding=kernel_size // 2, bias=False),
            nn.Sigmoid()
        )

    def forward(self, x):
        # Channel Attention
        channel_attention = self.channel_attention(x)
        x = x * channel_attention
        # Spatial Attention
        max_pool = torch.max(x, dim=1, keepdim=True)[0]
        avg_pool = torch.mean(x, dim=1, keepdim=True)
        spatial_attention = self.spatial_attention(torch.cat([max_pool, avg_pool], dim=1))
        x = x * spatial_attention
        return x

# %%
MODEL = UNet()
(summary(model=MODEL,
          input_size=(32, 1, PATCH_SIZE, PATCH_SIZE), # (batch_size, color_channels, height, width)
          col_names=["input_size", "output_size", "num_params", "trainable"],
          col_width=20,
          row_settings=["var_names"]
  ))
# Out:
# =======================================================================================================================================
# Layer (type (var_name))                                 Input Shape          Output Shape         Param #              Trainable
# =======================================================================================================================================
# UNet (UNet)                                             [32, 1, 256, 256]    [32, 1, 256, 256]    --                   True
# ├─MultiPathBlock (enc1)                                 [32, 1, 256, 256]    [32, 16, 256, 256]   --                   True
# │    └─ModuleList (parallel_paths)                      --                   --                   --                   True
# │    │    └─SinglePathBlock (0)                         [32, 1, 256, 256]    [32, 16, 256, 256]   2,608                True
# │    │    └─SinglePathBlock (1)                         [32, 1, 256, 256]    [32, 16, 256, 256]   2,608                True
# │    │    └─SinglePathBlock (2)                         [32, 1, 256, 256]    [32, 16, 256, 256]   2,608                True
# │    │    └─SinglePathBlock (3)                         [32, 1, 256, 256]    [32, 16, 256, 256]   2,608                True
# ├─MultiPathBlock (enc2)                                 [32, 16, 128, 128]   [32, 32, 128, 128]   --                   True
# │    └─ModuleList (parallel_paths)                      --                   --                   --                   True
# │    │    └─SinglePathBlock (0)                         [32, 16, 128, 128]   [32, 32, 128, 128]   14,624               True
# │    │    └─SinglePathBlock (1)                         [32, 16, 128, 128]   [32, 32, 128, 128]   14,624               True
# │    │    └─SinglePathBlock (2)                         [32, 16, 128, 128]   [32, 32, 128, 128]   14,624               True
# ├─MultiPathBlock (enc3)                                 [32, 32, 64, 64]     [32, 64, 64, 64]     --                   True
# │    └─ModuleList (parallel_paths)                      --                   --                   --                   True
# │    │    └─SinglePathBlock (0)                         [32, 32, 64, 64]     [32, 64, 64, 64]     57,920               True
# │    │    └─SinglePathBlock (1)                         [32, 32, 64, 64]     [32, 64, 64, 64]     57,920               True
# ├─MultiPathBlock (enc4)                                 [32, 64, 32, 32]     [32, 128, 32, 32]    --                   True
# │    └─ModuleList (parallel_paths)                      --                   --                   --                   True
# │    │    └─SinglePathBlock (0)                         [32, 64, 32, 32]     [32, 128, 32, 32]    230,528              True
# ├─Sequential (bottleneck)                               [32, 128, 16, 16]    [32, 256, 16, 16]    --                   True
# │    └─Conv2d (0)                                       [32, 128, 16, 16]    [32, 256, 16, 16]    295,168              True
# │    └─BatchNorm2d (1)                                  [32, 256, 16, 16]    [32, 256, 16, 16]    512                  True
# │    └─ReLU (2)                                         [32, 256, 16, 16]    [32, 256, 16, 16]    --                   --
# │    └─Conv2d (3)                                       [32, 256, 16, 16]    [32, 256, 16, 16]    590,080              True
# │    └─BatchNorm2d (4)                                  [32, 256, 16, 16]    [32, 256, 16, 16]    512                  True
# │    └─ReLU (5)                                         [32, 256, 16, 16]    [32, 256, 16, 16]    --                   --
# ├─ConvTranspose2d (upconv4)                             [32, 256, 16, 16]    [32, 128, 32, 32]    131,200              True
# ├─MultiPathBlock (dec4)                                 [32, 256, 32, 32]    [32, 128, 32, 32]    --                   True
# │    └─ModuleList (parallel_paths)                      --                   --                   --                   True
# │    │    └─SinglePathBlock (0)                         [32, 256, 32, 32]    [32, 128, 32, 32]    476,288              True
# ├─Conv2d (out_4)                                        [32, 128, 32, 32]    [32, 1, 32, 32]      129                  True
# ├─ConvTranspose2d (upconv3)                             [32, 128, 32, 32]    [32, 64, 64, 64]     32,832               True
# ├─MultiPathBlock (dec3)                                 [32, 128, 64, 64]    [32, 64, 64, 64]     --                   True
# │    └─ModuleList (parallel_paths)                      --                   --                   --                   True
# │    │    └─SinglePathBlock (0)                         [32, 128, 64, 64]    [32, 64, 64, 64]     119,360              True
# │    │    └─SinglePathBlock (1)                         [32, 128, 64, 64]    [32, 64, 64, 64]     119,360              True
# ├─Conv2d (out_3)                                        [32, 64, 64, 64]     [32, 1, 64, 64]      65                   True
# ├─ConvTranspose2d (upconv2)                             [32, 64, 64, 64]     [32, 32, 128, 128]   8,224                True
# ├─MultiPathBlock (dec2)                                 [32, 64, 128, 128]   [32, 32, 128, 128]   --                   True
# │    └─ModuleList (parallel_paths)                      --                   --                   --                   True
# │    │    └─SinglePathBlock (0)                         [32, 64, 128, 128]   [32, 32, 128, 128]   29,984               True
# │    │    └─SinglePathBlock (1)                         [32, 64, 128, 128]   [32, 32, 128, 128]   29,984               True
# │    │    └─SinglePathBlock (2)                         [32, 64, 128, 128]   [32, 32, 128, 128]   29,984               True
# ├─Conv2d (out_2)                                        [32, 32, 128, 128]   [32, 1, 128, 128]    33                   True
# ├─ConvTranspose2d (upconv1)                             [32, 32, 128, 128]   [32, 16, 256, 256]   2,064                True
# ├─MultiPathBlock (dec1)                                 [32, 32, 256, 256]   [32, 16, 256, 256]   --                   True
# │    └─ModuleList (parallel_paths)                      --                   --                   --                   True
# │    │    └─SinglePathBlock (0)                         [32, 32, 256, 256]   [32, 16, 256, 256]   7,568                True
# │    │    └─SinglePathBlock (1)                         [32, 32, 256, 256]   [32, 16, 256, 256]   7,568                True
# │    │    └─SinglePathBlock (2)                         [32, 32, 256, 256]   [32, 16, 256, 256]   7,568                True
# │    │    └─SinglePathBlock (3)                         [32, 32, 256, 256]   [32, 16, 256, 256]   7,568                True
# ├─Conv2d (final_conv)                                   [32, 16, 256, 256]   [32, 1, 256, 256]    17                   True
# =======================================================================================================================================
# Total params: 2,296,740
# Trainable params: 2,296,740
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 246.43
# =======================================================================================================================================
# Input size (MB): 8.39
# Forward/backward pass size (MB): 23611.05
# Params size (MB): 9.19
# Estimated Total Size (MB): 23628.62
# =======================================================================================================================================

# %%
# # Blood Vessel
train_image_dir = f'/scratch/raouti/FUNDUS_DATASETS/DRIVE/DRIVE_NOV_2024/{PATCH_SIZE}/PATCHIFY_DRIVE_{PATCH_SIZE}_{OVERLAP}/train/image/'
train_mask_dir =  f'/scratch/raouti/FUNDUS_DATASETS/DRIVE/DRIVE_NOV_2024/{PATCH_SIZE}/PATCHIFY_DRIVE_{PATCH_SIZE}_{OVERLAP}/train/mask/'
test_image_dir =  f'/scratch/raouti/FUNDUS_DATASETS/DRIVE/DRIVE_NOV_2024/{PATCH_SIZE}/PATCHIFY_DRIVE_{PATCH_SIZE}_{OVERLAP}/test/image/'
test_mask_dir =   f'/scratch/raouti/FUNDUS_DATASETS/DRIVE/DRIVE_NOV_2024/{PATCH_SIZE}/PATCHIFY_DRIVE_{PATCH_SIZE}_{OVERLAP}/test/mask/'

# %%
print(train_image_dir)
print(train_mask_dir)
print(test_image_dir)
print(test_mask_dir)
# Out:
# /scratch/raouti/FUNDUS_DATASETS/DRIVE/DRIVE_NOV_2024/256/PATCHIFY_DRIVE_256_50/train/image/
# /scratch/raouti/FUNDUS_DATASETS/DRIVE/DRIVE_NOV_2024/256/PATCHIFY_DRIVE_256_50/train/mask/
# /scratch/raouti/FUNDUS_DATASETS/DRIVE/DRIVE_NOV_2024/256/PATCHIFY_DRIVE_256_50/test/image/
# /scratch/raouti/FUNDUS_DATASETS/DRIVE/DRIVE_NOV_2024/256/PATCHIFY_DRIVE_256_50/test/mask/

# %%
img_testing = sorted(os.listdir(train_image_dir))
lab_testing = sorted(os.listdir(train_mask_dir))
print(len(img_testing))
img_path = os.path.join(train_image_dir,img_testing[10])
mask_path = os.path.join(train_mask_dir, lab_testing[10])
IMAGE = Image.open(img_path)
LAB = Image.open(mask_path)
# Out:
# 720

# %%
image_transform = transforms.Compose([
    transforms.Resize((PATCH_SIZE, PATCH_SIZE)),
    transforms.ToTensor()
])

IMAGE_TESTING = image_transform(IMAGE)
LAB_TESTING = image_transform(LAB)

# %%
plt.imshow(IMAGE_TESTING.permute(1,2,0),cmap = 'gray')

# %%
plt.imshow(LAB_TESTING.permute(1,2,0),cmap = 'gray')

# %%
class SegmentationDataset(Dataset):
    def __init__(self, image_dir, mask_dir, transform=None):
        self.image_dir = image_dir
        self.mask_dir = mask_dir
        self.transform = transform
        self.images = os.listdir(image_dir)
        self.labels = os.listdir(mask_dir)
        self.images.sort()
        self.labels.sort()


    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_path = os.path.join(self.image_dir, self.images[idx])
        mask_path = os.path.join(self.mask_dir, self.labels[idx])
        image = Image.open(img_path)
        mask = Image.open(mask_path)
        image = np.array(Image.open(img_path).convert("L"))  # Convert image to RGB and NumPy array
        mask = np.array(Image.open(mask_path).convert("L")) 

        if self.transform:
        #     image = self.transform(image)
        #     mask = self.transform(mask)
            transformed = self.transform(image=image, mask=mask)
            image = transformed['image'].float()/255
            mask = transformed['mask'].unsqueeze(0).float()/255

        return image, mask

# %%
train_transform = A.Compose([           
                                        A.Resize(PATCH_SIZE,PATCH_SIZE),  # Resize image and mask
                                        # A.Transpose(p=0.5),       # Randomly transpose the image
                                        # A.RandomBrightnessContrast(brightness_limit=0.2, contrast_limit=0.2, p=0.5),  # Adjust brightness and contrast
                                        # A.GaussianBlur(blur_limit=(3, 7), p=0.3),  # Apply Gaussian blur
                                        # A.CoarseDropout(max_holes=8, max_height=32, max_width=32, min_holes=4, min_height=8, min_width=8, fill_value=0, p=0.5),  # Add CutOut
                                        ToTensorV2() # Convert to PyTorch tensors
                                        ])

val_transform = A.Compose([A.Resize(PATCH_SIZE,PATCH_SIZE),
                                    ToTensorV2() 
                                     ])


train_dataset = SegmentationDataset(image_dir=train_image_dir, mask_dir=train_mask_dir, transform=train_transform)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)

val_dataset = SegmentationDataset(image_dir=test_image_dir, mask_dir=test_mask_dir, transform=val_transform)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

# %%
img,lab= next(iter(train_loader))

# %%
img.shape,lab.shape
# Out:
# (torch.Size([32, 1, 256, 256]), torch.Size([32, 1, 256, 256]))

# %%
img[0].dtype,img[0].max(),img[0].min(),
# Out:
# (torch.float32, tensor(0.8549), tensor(0.0118))

# %%
plt.imshow(torch.permute(img[3],(1,2,0)),cmap = 'gray')

# %%
plt.imshow(torch.permute(lab[3],(1,2,0)),cmap = 'gray')

# %%
RES_TESTING = MODEL(IMAGE_TESTING.unsqueeze(0).to(device))
print(RES_TESTING[1].shape)
# Out:
# torch.Size([1, 1, 32, 32])

# %%
plt.imshow(torch.permute(RES_TESTING[0][0].detach().cpu(),(1,2,0)),cmap = 'gray')

# %%
print(f'type = {type(RES_TESTING[0][0])}')
print(f'max = {torch.max(RES_TESTING[0][0])}')
print(f'min = {torch.min(RES_TESTING[0][0])}')
# Out:
# type = <class 'torch.Tensor'>
# max = 7.570381164550781
# min = -12.33138656616211

# %%
sigmoid_output = torch.sigmoid(RES_TESTING[0][0])
plt.imshow(torch.permute(sigmoid_output.detach().cpu(),(1,2,0)),cmap = 'gray')

# %%
print(f'type = {type(sigmoid_output)}')
print(f'max = {torch.max(sigmoid_output)}')
print(f'min = {torch.min(sigmoid_output)}')
# Out:
# type = <class 'torch.Tensor'>
# max = 0.9994847774505615
# min = 4.411080226418562e-06

# %%
sigmoid_output_threshold = (torch.sigmoid(RES_TESTING[0][0]) > 0.5)
plt.imshow(torch.permute(sigmoid_output_threshold.detach().cpu(),(1,2,0)),cmap = 'gray')

# %%
print(f'type = {type(sigmoid_output_threshold)}')
print(f'max = {torch.max(sigmoid_output_threshold)}')
print(f'min = {torch.min(sigmoid_output_threshold)}')
# Out:
# type = <class 'torch.Tensor'>
# max = True
# min = False

# %% [markdown]
# # Training

# %%
# import torch
# import torch.nn as nn
# import torch.optim as optim
# from torch.optim.lr_scheduler import StepLR
# import torch.nn.utils as utils
# from torch.optim.lr_scheduler import ReduceLROnPlateau

# initial_lr = 0.001
# weight_decay = 0.01 
# momentum_value = 0.9
# device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# model = MODEL

# optimizer = optim.Adam(model.parameters(), lr=initial_lr, betas=(0.9, 0.999))  # Adam optimizer with default beta values
# scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=5, verbose=True)

# %%
def train(model, loader, optimizer, criterion, device,scheduler):
    model.train()


    total_loss = 0
    len_loader = len(loader)
    max_grad_norm = 1

    for idx,(images, masks) in enumerate(loader):
        images, masks = images.to(device), masks.to(device)
        optimizer.zero_grad()


        outputs, out_d4, out_d3, out_d2 = model(images)       
        # loss = LOSS_FUNC(outputs, out_d4, out_d3, out_d2, masks, criterion)
        
        # outputs = model(images)       
        loss = criterion(outputs, masks)
        
        loss.backward()
        # utils.clip_grad_norm_(model.parameters(), max_grad_norm)
        optimizer.step()
        total_loss += loss.item()
        
    print(f"_______________________Training - __________________________________")
    epoch_loss = total_loss/ len_loader
    return  epoch_loss

def validate(model, loader, criterion, device,scheduler):

    model.eval()
    total_loss = 0
    len_loader = len(loader)
    with torch.no_grad():
        for idx,(images, masks) in enumerate(loader):
            images, masks = images.to(device), masks.to(device)

            outputs, out_d4, out_d3, out_d2 = model(images)
            # loss = LOSS_FUNC(outputs, out_d4, out_d3, out_d2, masks, criterion)
            
            # outputs = model(images)
            loss = criterion(outputs, masks)
            
            total_loss += loss.item()
    scheduler.step(loss)
    print(f"_______________________Validation - __________________________________")
    epoch_loss = total_loss/ len_loader
    return  epoch_loss

# %% [markdown]
# # Loss Function

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class DiceLoss(nn.Module):
    def __init__(self, weight=None, size_average=True):
        super(DiceLoss, self).__init__()

    def forward(self, inputs, targets, smooth=1):

        #comment out if your model contains a sigmoid or equivalent activation layer
        inputs = torch.sigmoid(inputs)

        #flatten label and prediction tensors
        inputs = inputs.view(-1)
        targets = targets.view(-1)

        intersection = (inputs * targets).sum()
        dice = (2.*intersection + smooth)/(inputs.sum() + targets.sum() + smooth)

        return 1 - dice

class DiceBCELoss(nn.Module):
    def __init__(self, weight=None, size_average=True):
        super(DiceBCELoss, self).__init__()

    def forward(self, inputs, targets, smooth=1):

        #comment out if your model contains a sigmoid or equivalent activation layer
        inputs = torch.sigmoid(inputs)

        #flatten label and prediction tensors
        inputs = inputs.view(-1)
        targets = targets.view(-1)

        intersection = (inputs * targets).sum()
        dice_loss = 1 - (2.*intersection + smooth)/(inputs.sum() + targets.sum() + smooth)
        BCE = F.binary_cross_entropy(inputs, targets, reduction='mean')
        Dice_BCE = BCE + dice_loss

        return Dice_BCE

def LOSS_FUNC(segmentation_head, aux_out1, aux_out2, aux_out3, masks, criterion):
    # Main loss (for the segmentation head output)
    loss_head = criterion(segmentation_head, masks)

    # Resize the masks to match the sizes of auxiliary outputs and calculate their losses
    mask_aux_1_resized = F.interpolate(masks, size=aux_out1.shape[2:], mode='bilinear', align_corners=True)
    loss_aux1 = criterion(aux_out1, mask_aux_1_resized)

    mask_aux_2_resized = F.interpolate(masks, size=aux_out2.shape[2:], mode='bilinear', align_corners=True)
    loss_aux2 = criterion(aux_out2, mask_aux_2_resized)

    mask_aux_3_resized = F.interpolate(masks, size=aux_out3.shape[2:], mode='bilinear', align_corners=True)
    loss_aux3 = criterion(aux_out3, mask_aux_3_resized)

    # Combine the losses for deep supervision with weights
    total_loss = loss_head + (0.3 * loss_aux1) + (0.2 * loss_aux2) + (0.1 * loss_aux3)
    # total_loss = loss_head 

    return total_loss

# %%
model_no = '02_FINAL_STOCK_DIA'
checkpoint_name = f'RESULTS/MODEL_{model_no}/MODEL_{model_no}_RUN'
log_file_name = f'RESULTS/MODEL_{model_no}/training_log.txt'
folder_path = f"RESULTS/MODEL_{model_no}/"  
folder_path
# Out:
# 'RESULTS/MODEL_02_FINAL_STOCK_DIA/'

# %%
# !pwd
# Out:
# /scratch/raouti/JAN_2025_SEG_REPEAT/Blood_Vessel/FINAL_MODELS

# %%
import torch
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR
import torch.nn.utils as utils
from torch.optim.lr_scheduler import ReduceLROnPlateau


criterion = DiceBCELoss()
num_epochs = 100  
patience = 10  
num_runs = 10  
best_valid_losses = [] 

initial_lr = 0.001
weight_decay = 0.01 
momentum_value = 0.9
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

with open(log_file_name, 'w') as log_file:
        log_file.write(f"STARTING")
    
for run in range(num_runs):
    
    print(f"Starting run {run+1}/{num_runs}")
    print(f"MODEL INTIALIZATION")
    model = UNet().to(device)
    optimizer = optim.Adam(model.parameters(), lr=initial_lr, betas=(0.9, 0.999))  # Adam optimizer with default beta values
    scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=5, verbose=True)

    with open(log_file_name, 'a') as log_file:
        log_file.write(f"RUN NO {run+1}/{num_runs}\n")
        log_file.write("MODEL INTIALIZATION \n")

    best_valid_loss = float("inf")
    total_train_loss = []
    total_val_loss = []
    early_stopping_counter = 0 

    for epoch in range(num_epochs):
        train_loss = train(model, train_loader, optimizer, criterion, device, scheduler)
        valid_loss = validate(model, val_loader, criterion, device, scheduler)
        
        total_train_loss.append(train_loss)
        total_val_loss.append(valid_loss)
    
        if valid_loss < best_valid_loss:
            # Create a checkpoint filename that includes the run and epoch number
            checkpoint_path = f"{checkpoint_name}_{run+1}.pth"
            print(f"Valid loss improved from {best_valid_loss:.3f} to {valid_loss:.3f}. Saving checkpoint: {checkpoint_path}")
            best_valid_loss = valid_loss
            torch.save(model.state_dict(), checkpoint_path)
            early_stopping_counter = 0  # reset counter after improvement
        else:
            early_stopping_counter += 1
            print(f"No improvement in validation loss for {early_stopping_counter} epochs.")
    
        if early_stopping_counter >= patience:
            print(f"Stopping early after {epoch+1} epochs due to no improvement in validation loss.")
            break

        log_message = f'Epoch: {epoch+1:02} | Train Loss: {train_loss:.3f} | Val. Loss: {valid_loss:.3f}\n'
        print(log_message)
        
        with open(log_file_name, 'a') as log_file:
            log_file.write(log_message)
    
    best_valid_losses.append(best_valid_loss)
    best_log = f"Run {run+1} finished with best validation loss: {best_valid_loss:.3f}\n"
    print(best_log)

    with open(log_file_name, 'a') as log_file:
        log_file.write(best_log)

# Compute mean and standard deviation across the 10 runs
mean_valid_loss = np.mean(best_valid_losses)
std_valid_loss = np.std(best_valid_losses)
print(f"Mean best validation loss over {num_runs} runs: {mean_valid_loss:.3f}")
print(f"Std of best validation loss over {num_runs} runs: {std_valid_loss:.3f}")
# Out:
# Starting run 1/10
# MODEL INTIALIZATION
# /home/raouti/.local/lib/python3.12/site-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from inf to 1.437. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_1.pth
# Epoch: 01 | Train Loss: 0.806 | Val. Loss: 1.437
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 1.437 to 0.861. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_1.pth
# Epoch: 02 | Train Loss: 0.508 | Val. Loss: 0.861
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.861 to 0.438. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_1.pth
# Epoch: 03 | Train Loss: 0.463 | Val. Loss: 0.438
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.438 to 0.395. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_1.pth
# Epoch: 04 | Train Loss: 0.442 | Val. Loss: 0.395
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.395 to 0.379. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_1.pth
# Epoch: 05 | Train Loss: 0.422 | Val. Loss: 0.379
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.379 to 0.370. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_1.pth
# Epoch: 06 | Train Loss: 0.409 | Val. Loss: 0.370
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.370 to 0.363. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_1.pth
# Epoch: 07 | Train Loss: 0.398 | Val. Loss: 0.363
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 08 | Train Loss: 0.386 | Val. Loss: 0.377
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 2 epochs.
# Epoch: 09 | Train Loss: 0.381 | Val. Loss: 0.363
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.363 to 0.362. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_1.pth
# Epoch: 10 | Train Loss: 0.371 | Val. Loss: 0.362
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 11 | Train Loss: 0.365 | Val. Loss: 0.369
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.362 to 0.353. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_1.pth
# Epoch: 12 | Train Loss: 0.356 | Val. Loss: 0.353
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 13 | Train Loss: 0.353 | Val. Loss: 0.366
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 2 epochs.
# Epoch: 14 | Train Loss: 0.342 | Val. Loss: 0.360
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 3 epochs.
# Epoch: 15 | Train Loss: 0.332 | Val. Loss: 0.358
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 4 epochs.
# Epoch: 16 | Train Loss: 0.326 | Val. Loss: 0.361
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 5 epochs.
# Epoch: 17 | Train Loss: 0.318 | Val. Loss: 0.387
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 6 epochs.
# Epoch: 18 | Train Loss: 0.312 | Val. Loss: 0.363
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 7 epochs.
# Epoch: 19 | Train Loss: 0.300 | Val. Loss: 0.370
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 8 epochs.
# Epoch: 20 | Train Loss: 0.291 | Val. Loss: 0.379
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 9 epochs.
# Epoch: 21 | Train Loss: 0.284 | Val. Loss: 0.384
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 10 epochs.
# Stopping early after 22 epochs due to no improvement in validation loss.
# Run 1 finished with best validation loss: 0.353
#
# Starting run 2/10
# MODEL INTIALIZATION
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from inf to 1.430. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_2.pth
# Epoch: 01 | Train Loss: 1.013 | Val. Loss: 1.430
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 1.430 to 0.889. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_2.pth
# Epoch: 02 | Train Loss: 0.539 | Val. Loss: 0.889
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.889 to 0.487. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_2.pth
# Epoch: 03 | Train Loss: 0.488 | Val. Loss: 0.487
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.487 to 0.406. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_2.pth
# Epoch: 04 | Train Loss: 0.461 | Val. Loss: 0.406
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.406 to 0.390. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_2.pth
# Epoch: 05 | Train Loss: 0.445 | Val. Loss: 0.390
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.390 to 0.378. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_2.pth
# Epoch: 06 | Train Loss: 0.428 | Val. Loss: 0.378
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 07 | Train Loss: 0.414 | Val. Loss: 0.385
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 3 epochs.
# Epoch: 17 | Train Loss: 0.339 | Val. Loss: 0.367
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 4 epochs.
# Epoch: 18 | Train Loss: 0.330 | Val. Loss: 0.373
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 5 epochs.
# Epoch: 19 | Train Loss: 0.323 | Val. Loss: 0.378
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 6 epochs.
# Epoch: 20 | Train Loss: 0.315 | Val. Loss: 0.370
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 7 epochs.
# Epoch: 21 | Train Loss: 0.310 | Val. Loss: 0.374
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 8 epochs.
# Epoch: 22 | Train Loss: 0.295 | Val. Loss: 0.369
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 9 epochs.
# Epoch: 23 | Train Loss: 0.290 | Val. Loss: 0.371
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 10 epochs.
# Stopping early after 24 epochs due to no improvement in validation loss.
# Run 2 finished with best validation loss: 0.359
#
# Starting run 3/10
# MODEL INTIALIZATION
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from inf to 1.365. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_3.pth
# Epoch: 01 | Train Loss: 0.718 | Val. Loss: 1.365
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 1.365 to 0.979. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_3.pth
# Epoch: 02 | Train Loss: 0.485 | Val. Loss: 0.979
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.979 to 0.417. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_3.pth
# Epoch: 03 | Train Loss: 0.445 | Val. Loss: 0.417
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.417 to 0.377. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_3.pth
# Epoch: 04 | Train Loss: 0.423 | Val. Loss: 0.377
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.377 to 0.370. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_3.pth
# Epoch: 05 | Train Loss: 0.410 | Val. Loss: 0.370
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.370 to 0.368. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_3.pth
# Epoch: 06 | Train Loss: 0.396 | Val. Loss: 0.368
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.368 to 0.361. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_3.pth
# Epoch: 07 | Train Loss: 0.387 | Val. Loss: 0.361
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 08 | Train Loss: 0.378 | Val. Loss: 0.362
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 2 epochs.
# Epoch: 09 | Train Loss: 0.366 | Val. Loss: 0.369
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 3 epochs.
# Epoch: 10 | Train Loss: 0.360 | Val. Loss: 0.363
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 4 epochs.
# Epoch: 11 | Train Loss: 0.350 | Val. Loss: 0.363
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 5 epochs.
# Epoch: 12 | Train Loss: 0.345 | Val. Loss: 0.365
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 6 epochs.
# Epoch: 13 | Train Loss: 0.330 | Val. Loss: 0.369
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 7 epochs.
# Epoch: 14 | Train Loss: 0.318 | Val. Loss: 0.371
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 8 epochs.
# Epoch: 15 | Train Loss: 0.308 | Val. Loss: 0.400
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 9 epochs.
# Epoch: 16 | Train Loss: 0.299 | Val. Loss: 0.380
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 10 epochs.
# Stopping early after 17 epochs due to no improvement in validation loss.
# Run 3 finished with best validation loss: 0.361
#
# Starting run 4/10
# MODEL INTIALIZATION
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from inf to 1.433. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_4.pth
# Epoch: 01 | Train Loss: 0.862 | Val. Loss: 1.433
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 1.433 to 0.803. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_4.pth
# Epoch: 02 | Train Loss: 0.509 | Val. Loss: 0.803
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.803 to 0.497. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_4.pth
# Epoch: 03 | Train Loss: 0.461 | Val. Loss: 0.497
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.497 to 0.393. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_4.pth
# Epoch: 04 | Train Loss: 0.436 | Val. Loss: 0.393
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.393 to 0.387. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_4.pth
# Epoch: 05 | Train Loss: 0.423 | Val. Loss: 0.387
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.387 to 0.369. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_4.pth
# Epoch: 06 | Train Loss: 0.408 | Val. Loss: 0.369
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.369 to 0.366. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_4.pth
# Epoch: 07 | Train Loss: 0.395 | Val. Loss: 0.366
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.366 to 0.362. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_4.pth
# Epoch: 08 | Train Loss: 0.383 | Val. Loss: 0.362
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 09 | Train Loss: 0.374 | Val. Loss: 0.363
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 2 epochs.
# Epoch: 10 | Train Loss: 0.368 | Val. Loss: 0.365
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.362 to 0.359. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_4.pth
# Epoch: 11 | Train Loss: 0.359 | Val. Loss: 0.359
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 12 | Train Loss: 0.350 | Val. Loss: 0.362
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 2 epochs.
# Epoch: 13 | Train Loss: 0.341 | Val. Loss: 0.364
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 3 epochs.
# Epoch: 14 | Train Loss: 0.331 | Val. Loss: 0.368
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 4 epochs.
# Epoch: 15 | Train Loss: 0.322 | Val. Loss: 0.367
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 5 epochs.
# Epoch: 16 | Train Loss: 0.311 | Val. Loss: 0.377
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 6 epochs.
# Epoch: 17 | Train Loss: 0.304 | Val. Loss: 0.374
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 7 epochs.
# Epoch: 18 | Train Loss: 0.295 | Val. Loss: 0.375
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 8 epochs.
# Epoch: 19 | Train Loss: 0.282 | Val. Loss: 0.375
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 9 epochs.
# Epoch: 20 | Train Loss: 0.275 | Val. Loss: 0.379
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 10 epochs.
# Stopping early after 21 epochs due to no improvement in validation loss.
# Run 4 finished with best validation loss: 0.359
#
# Starting run 5/10
# MODEL INTIALIZATION
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from inf to 1.370. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_5.pth
# Epoch: 01 | Train Loss: 0.738 | Val. Loss: 1.370
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 1.370 to 1.025. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_5.pth
# Epoch: 02 | Train Loss: 0.483 | Val. Loss: 1.025
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 1.025 to 0.469. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_5.pth
# Epoch: 03 | Train Loss: 0.450 | Val. Loss: 0.469
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.469 to 0.379. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_5.pth
# Epoch: 04 | Train Loss: 0.428 | Val. Loss: 0.379
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.379 to 0.368. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_5.pth
# Epoch: 05 | Train Loss: 0.414 | Val. Loss: 0.368
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.368 to 0.367. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_5.pth
# Epoch: 06 | Train Loss: 0.400 | Val. Loss: 0.367
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.367 to 0.363. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_5.pth
# Epoch: 07 | Train Loss: 0.393 | Val. Loss: 0.363
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 08 | Train Loss: 0.380 | Val. Loss: 0.364
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.363 to 0.356. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_5.pth
# Epoch: 09 | Train Loss: 0.375 | Val. Loss: 0.356
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.356 to 0.355. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_5.pth
# Epoch: 10 | Train Loss: 0.365 | Val. Loss: 0.355
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 11 | Train Loss: 0.358 | Val. Loss: 0.357
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 2 epochs.
# Epoch: 12 | Train Loss: 0.350 | Val. Loss: 0.361
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 3 epochs.
# Epoch: 13 | Train Loss: 0.342 | Val. Loss: 0.372
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 4 epochs.
# Epoch: 14 | Train Loss: 0.338 | Val. Loss: 0.374
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 5 epochs.
# Epoch: 15 | Train Loss: 0.328 | Val. Loss: 0.356
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 6 epochs.
# Epoch: 16 | Train Loss: 0.320 | Val. Loss: 0.372
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 7 epochs.
# Epoch: 17 | Train Loss: 0.308 | Val. Loss: 0.365
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 8 epochs.
# Epoch: 18 | Train Loss: 0.301 | Val. Loss: 0.382
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 9 epochs.
# Epoch: 19 | Train Loss: 0.295 | Val. Loss: 0.399
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 10 epochs.
# Stopping early after 20 epochs due to no improvement in validation loss.
# Run 5 finished with best validation loss: 0.355
#
# Starting run 6/10
# MODEL INTIALIZATION
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from inf to 1.557. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_6.pth
# Epoch: 01 | Train Loss: 0.795 | Val. Loss: 1.557
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 1.557 to 0.947. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_6.pth
# Epoch: 02 | Train Loss: 0.497 | Val. Loss: 0.947
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.947 to 0.429. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_6.pth
# Epoch: 03 | Train Loss: 0.456 | Val. Loss: 0.429
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.429 to 0.391. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_6.pth
# Epoch: 04 | Train Loss: 0.432 | Val. Loss: 0.391
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.391 to 0.384. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_6.pth
# Epoch: 05 | Train Loss: 0.416 | Val. Loss: 0.384
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.384 to 0.365. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_6.pth
# Epoch: 06 | Train Loss: 0.401 | Val. Loss: 0.365
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 07 | Train Loss: 0.388 | Val. Loss: 0.370
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 2 epochs.
# Epoch: 08 | Train Loss: 0.384 | Val. Loss: 0.367
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.365 to 0.362. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_6.pth
# Epoch: 09 | Train Loss: 0.372 | Val. Loss: 0.362
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.362 to 0.358. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_6.pth
# Epoch: 10 | Train Loss: 0.364 | Val. Loss: 0.358
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 11 | Train Loss: 0.354 | Val. Loss: 0.362
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.358 to 0.358. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_6.pth
# Epoch: 12 | Train Loss: 0.346 | Val. Loss: 0.358
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 13 | Train Loss: 0.344 | Val. Loss: 0.364
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 2 epochs.
# Epoch: 14 | Train Loss: 0.334 | Val. Loss: 0.371
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 3 epochs.
# Epoch: 15 | Train Loss: 0.322 | Val. Loss: 0.367
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 4 epochs.
# Epoch: 16 | Train Loss: 0.318 | Val. Loss: 0.366
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 5 epochs.
# Epoch: 17 | Train Loss: 0.310 | Val. Loss: 0.371
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 6 epochs.
# Epoch: 18 | Train Loss: 0.299 | Val. Loss: 0.384
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 7 epochs.
# Epoch: 19 | Train Loss: 0.293 | Val. Loss: 0.378
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 8 epochs.
# Epoch: 20 | Train Loss: 0.281 | Val. Loss: 0.371
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 9 epochs.
# Epoch: 21 | Train Loss: 0.273 | Val. Loss: 0.376
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 10 epochs.
# Stopping early after 22 epochs due to no improvement in validation loss.
# Run 6 finished with best validation loss: 0.358
#
# Starting run 7/10
# MODEL INTIALIZATION
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from inf to 1.438. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_7.pth
# Epoch: 01 | Train Loss: 0.897 | Val. Loss: 1.438
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 1.438 to 1.022. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_7.pth
# Epoch: 02 | Train Loss: 0.512 | Val. Loss: 1.022
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 1.022 to 0.472. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_7.pth
# Epoch: 03 | Train Loss: 0.467 | Val. Loss: 0.472
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.472 to 0.389. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_7.pth
# Epoch: 04 | Train Loss: 0.443 | Val. Loss: 0.389
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.389 to 0.380. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_7.pth
# Epoch: 05 | Train Loss: 0.426 | Val. Loss: 0.380
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.380 to 0.373. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_7.pth
# Epoch: 06 | Train Loss: 0.411 | Val. Loss: 0.373
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.373 to 0.366. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_7.pth
# Epoch: 07 | Train Loss: 0.399 | Val. Loss: 0.366
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.366 to 0.362. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_7.pth
# Epoch: 08 | Train Loss: 0.390 | Val. Loss: 0.362
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.362 to 0.360. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_7.pth
# Epoch: 09 | Train Loss: 0.382 | Val. Loss: 0.360
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.360 to 0.356. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_7.pth
# Epoch: 10 | Train Loss: 0.377 | Val. Loss: 0.356
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 11 | Train Loss: 0.366 | Val. Loss: 0.360
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.356 to 0.354. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_7.pth
# Epoch: 12 | Train Loss: 0.357 | Val. Loss: 0.354
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 13 | Train Loss: 0.357 | Val. Loss: 0.365
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 9 epochs.
# Epoch: 24 | Train Loss: 0.319 | Val. Loss: 0.360
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 10 epochs.
# Stopping early after 25 epochs due to no improvement in validation loss.
# Run 7 finished with best validation loss: 0.354
#
# Starting run 8/10
# MODEL INTIALIZATION
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from inf to 1.533. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_8.pth
# Epoch: 01 | Train Loss: 0.728 | Val. Loss: 1.533
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 1.533 to 0.856. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_8.pth
# Epoch: 02 | Train Loss: 0.495 | Val. Loss: 0.856
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.856 to 0.420. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_8.pth
# Epoch: 03 | Train Loss: 0.457 | Val. Loss: 0.420
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.420 to 0.394. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_8.pth
# Epoch: 04 | Train Loss: 0.434 | Val. Loss: 0.394
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.394 to 0.386. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_8.pth
# Epoch: 05 | Train Loss: 0.423 | Val. Loss: 0.386
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.386 to 0.370. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_8.pth
# Epoch: 06 | Train Loss: 0.406 | Val. Loss: 0.370
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.370 to 0.367. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_8.pth
# Epoch: 07 | Train Loss: 0.392 | Val. Loss: 0.367
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 08 | Train Loss: 0.382 | Val. Loss: 0.369
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.367 to 0.360. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_8.pth
# Epoch: 09 | Train Loss: 0.371 | Val. Loss: 0.360
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 10 | Train Loss: 0.361 | Val. Loss: 0.363
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 2 epochs.
# Epoch: 11 | Train Loss: 0.351 | Val. Loss: 0.361
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 3 epochs.
# Epoch: 12 | Train Loss: 0.343 | Val. Loss: 0.374
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 4 epochs.
# Epoch: 13 | Train Loss: 0.331 | Val. Loss: 0.371
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 5 epochs.
# Epoch: 14 | Train Loss: 0.322 | Val. Loss: 0.372
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 6 epochs.
# Epoch: 15 | Train Loss: 0.310 | Val. Loss: 0.373
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 7 epochs.
# Epoch: 16 | Train Loss: 0.296 | Val. Loss: 0.369
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 8 epochs.
# Epoch: 17 | Train Loss: 0.287 | Val. Loss: 0.371
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 9 epochs.
# Epoch: 18 | Train Loss: 0.283 | Val. Loss: 0.374
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 10 epochs.
# Stopping early after 19 epochs due to no improvement in validation loss.
# Run 8 finished with best validation loss: 0.360
#
# Starting run 9/10
# MODEL INTIALIZATION
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from inf to 1.542. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_9.pth
# Epoch: 01 | Train Loss: 0.712 | Val. Loss: 1.542
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 1.542 to 0.919. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_9.pth
# Epoch: 02 | Train Loss: 0.483 | Val. Loss: 0.919
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.919 to 0.435. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_9.pth
# Epoch: 03 | Train Loss: 0.446 | Val. Loss: 0.435
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.435 to 0.380. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_9.pth
# Epoch: 04 | Train Loss: 0.426 | Val. Loss: 0.380
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.380 to 0.376. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_9.pth
# Epoch: 05 | Train Loss: 0.410 | Val. Loss: 0.376
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.376 to 0.361. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_9.pth
# Epoch: 06 | Train Loss: 0.397 | Val. Loss: 0.361
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.361 to 0.358. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_9.pth
# Epoch: 07 | Train Loss: 0.384 | Val. Loss: 0.358
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 08 | Train Loss: 0.374 | Val. Loss: 0.365
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 2 epochs.
# Epoch: 09 | Train Loss: 0.366 | Val. Loss: 0.375
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 3 epochs.
# Epoch: 10 | Train Loss: 0.359 | Val. Loss: 0.359
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.358 to 0.357. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_9.pth
# Epoch: 11 | Train Loss: 0.346 | Val. Loss: 0.357
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 12 | Train Loss: 0.336 | Val. Loss: 0.361
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 2 epochs.
# Epoch: 13 | Train Loss: 0.329 | Val. Loss: 0.374
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 3 epochs.
# Epoch: 14 | Train Loss: 0.318 | Val. Loss: 0.366
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 4 epochs.
# Epoch: 15 | Train Loss: 0.304 | Val. Loss: 0.379
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 5 epochs.
# Epoch: 16 | Train Loss: 0.293 | Val. Loss: 0.374
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 6 epochs.
# Epoch: 17 | Train Loss: 0.283 | Val. Loss: 0.377
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 7 epochs.
# Epoch: 18 | Train Loss: 0.269 | Val. Loss: 0.375
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 8 epochs.
# Epoch: 19 | Train Loss: 0.263 | Val. Loss: 0.381
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 9 epochs.
# Epoch: 20 | Train Loss: 0.259 | Val. Loss: 0.381
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 10 epochs.
# Stopping early after 21 epochs due to no improvement in validation loss.
# Run 9 finished with best validation loss: 0.357
#
# Starting run 10/10
# MODEL INTIALIZATION
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from inf to 1.428. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_10.pth
# Epoch: 01 | Train Loss: 0.781 | Val. Loss: 1.428
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 1.428 to 0.853. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_10.pth
# Epoch: 02 | Train Loss: 0.495 | Val. Loss: 0.853
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.853 to 0.429. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_10.pth
# Epoch: 03 | Train Loss: 0.458 | Val. Loss: 0.429
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.429 to 0.393. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_10.pth
# Epoch: 04 | Train Loss: 0.435 | Val. Loss: 0.393
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.393 to 0.369. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_10.pth
# Epoch: 05 | Train Loss: 0.420 | Val. Loss: 0.369
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 06 | Train Loss: 0.404 | Val. Loss: 0.371
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.369 to 0.362. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_10.pth
# Epoch: 07 | Train Loss: 0.394 | Val. Loss: 0.362
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.362 to 0.360. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_10.pth
# Epoch: 08 | Train Loss: 0.384 | Val. Loss: 0.360
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.360 to 0.357. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_10.pth
# Epoch: 09 | Train Loss: 0.375 | Val. Loss: 0.357
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 10 | Train Loss: 0.367 | Val. Loss: 0.362
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 2 epochs.
# Epoch: 11 | Train Loss: 0.360 | Val. Loss: 0.361
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 3 epochs.
# Epoch: 12 | Train Loss: 0.351 | Val. Loss: 0.362
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.357 to 0.356. Saving checkpoint: RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_10.pth
# Epoch: 13 | Train Loss: 0.345 | Val. Loss: 0.356
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 14 | Train Loss: 0.337 | Val. Loss: 0.366
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 2 epochs.
# Epoch: 15 | Train Loss: 0.330 | Val. Loss: 0.361
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 3 epochs.
# Epoch: 16 | Train Loss: 0.320 | Val. Loss: 0.370
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 4 epochs.
# Epoch: 17 | Train Loss: 0.315 | Val. Loss: 0.370
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 5 epochs.
# Epoch: 18 | Train Loss: 0.308 | Val. Loss: 0.368
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 6 epochs.
# Epoch: 19 | Train Loss: 0.298 | Val. Loss: 0.368
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 7 epochs.
# Epoch: 20 | Train Loss: 0.285 | Val. Loss: 0.369
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 8 epochs.
# Epoch: 21 | Train Loss: 0.279 | Val. Loss: 0.371
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 9 epochs.
# Epoch: 22 | Train Loss: 0.277 | Val. Loss: 0.371
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 10 epochs.
# Stopping early after 23 epochs due to no improvement in validation loss.
# Run 10 finished with best validation loss: 0.356
#
# Mean best validation loss over 10 runs: 0.357
# Std of best validation loss over 10 runs: 0.003

# %%
# Plot accuracies over epochs
plt.figure()
plt.plot(range(1, epoch+2), total_train_loss, label=' train_losses')
plt.plot(range(1, epoch+2), total_val_loss, label='val_losses')
plt.xlabel('Epoch')
plt.ylabel('LOSS')
plt.legend()
plt.title('Train and Validation losses Over Epochs')
plt.show()

# %%
def visualize_predictions(model, loader, device, num_images=5):
    model.eval()
    num_images_plotted = 0
    with torch.no_grad():
        for idx, (images, masks) in enumerate(loader):
            images = images.to(device)
            outputs = model(images)[0]
            preds = torch.sigmoid(outputs) > 0.5
            preds = preds.cpu().numpy()
            masks = masks.cpu().numpy()

            for i in range(images.size(0)):
                plt.figure()
                plt.subplot(1, 3, 1)
                plt.imshow(images[i].permute(1, 2, 0).cpu())
                plt.title('Input Image')

                plt.subplot(1, 3, 2)
                plt.imshow(masks[i][0], cmap='gray')
                plt.title('Ground Truth')

                plt.subplot(1, 3, 3)
                plt.imshow(preds[i].transpose(1, 2, 0), cmap='gray')
                plt.title('Prediction')

                plt.show()
                print(i)

                num_images_plotted += i 
                if i+1 >= num_images:
                    break
            
            if idx+1 >= num_images or num_images_plotted >= num_images:
                break

# Visualize predictions on the validation set
visualize_predictions(model, val_loader, device, num_images=5)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
weight_file = 'RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_10.pth'
MODEL.load_state_dict(torch.load(weight_file, map_location=device))
MODEL.to(device)
MODEL.eval()
# Out:
# UNet(
#   (enc1): MultiPathBlock(
#     (parallel_paths): ModuleList(
#       (0): SinglePathBlock(
#         (single_path_block_1): Sequential(
#           (0): StandardConvBlock(
#             (conv): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU()
#           )
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (single_path_block_2): Sequential(
#           (0): StandardConvBlock(
#             (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU()
#           )
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (channel_modification): Conv2d(1, 16, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (1): SinglePathBlock(
#         (single_path_block_1): Sequential(
#           (0): StandardConvBlock(
#             (conv): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1), padding=(3, 3), dilation=(3, 3), bias=False)
#             (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU()
#           )
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (single_path_block_2): Sequential(
#           (0): StandardConvBlock(
#             (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(3, 3), dilation=(3, 3), bias=False)
#             (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU()
#           )
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (channel_modification): Conv2d(1, 16, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (2): SinglePathBlock(
#         (single_path_block_1): Sequential(
#           (0): StandardConvBlock(
#             (conv): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1), padding=(5, 5), dilation=(5, 5), bias=False)
#             (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU()
#           )
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (single_path_block_2): Sequential(
#           (0): StandardConvBlock(
#             (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(5, 5), dilation=(5, 5), bias=False)
#             (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU()
#           )
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (channel_modification): Conv2d(1, 16, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (3): SinglePathBlock(
#         (single_path_block_1): Sequential(
#           (0): StandardConvBlock(
#             (conv): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1), padding=(7, 7), dilation=(7, 7), bias=False)
#             (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU()
#           )
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (single_path_block_2): Sequential(
#           (0): StandardConvBlock(
#             (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(7, 7), dilation=(7, 7), bias=False)
#             (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU()
#           )
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (channel_modification): Conv2d(1, 16, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#   )
#   (enc2): MultiPathBlock(
#     (parallel_paths): ModuleList(
#       (0): SinglePathBlock(
#         (single_path_block_1): Sequential(
#           (0): StandardConvBlock(
#             (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU()
#           )
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (single_path_block_2): Sequential(
#           (0): StandardConvBlock(
#             (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU()
#           )
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (channel_modification): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (1): SinglePathBlock(
#         (single_path_block_1): Sequential(
#           (0): StandardConvBlock(
#             (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(3, 3), dilation=(3, 3), bias=False)
#             (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU()
#           )
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (single_path_block_2): Sequential(
#           (0): StandardConvBlock(
#             (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(3, 3), dilation=(3, 3), bias=False)
#             (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU()
#           )
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (channel_modification): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (2): SinglePathBlock(
#         (single_path_block_1): Sequential(
#           (0): StandardConvBlock(
#             (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(5, 5), dilation=(5, 5), bias=False)
#             (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU()
#           )
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (single_path_block_2): Sequential(
#           (0): StandardConvBlock(
#             (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(5, 5), dilation=(5, 5), bias=False)
#             (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU()
#           )
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (channel_modification): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#   )
#   (enc3): MultiPathBlock(
#     (parallel_paths): ModuleList(
#       (0): SinglePathBlock(
#         (single_path_block_1): Sequential(
#           (0): StandardConvBlock(
#             (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU()
#           )
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (single_path_block_2): Sequential(
#           (0): StandardConvBlock(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU()
#           )
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (channel_modification): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (1): SinglePathBlock(
#         (single_path_block_1): Sequential(
#           (0): StandardConvBlock(
#             (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(3, 3), dilation=(3, 3), bias=False)
#             (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU()
#           )
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (single_path_block_2): Sequential(
#           (0): StandardConvBlock(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(3, 3), dilation=(3, 3), bias=False)
#             (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU()
#           )
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (channel_modification): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#   )
#   (enc4): MultiPathBlock(
#     (parallel_paths): ModuleList(
#       (0): SinglePathBlock(
#         (single_path_block_1): Sequential(
#           (0): StandardConvBlock(
#             (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU()
#           )
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (single_path_block_2): Sequential(
#           (0): StandardConvBlock(
#             (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU()
#           )
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (channel_modification): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#   )
#   (bottleneck): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#   )
#   (upconv4): ConvTranspose2d(256, 128, kernel_size=(2, 2), stride=(2, 2))
#   (dec4): MultiPathBlock(
#     (parallel_paths): ModuleList(
#       (0): SinglePathBlock(
#         (single_path_block_1): Sequential(
#           (0): StandardConvBlock(
#             (conv): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU()
#           )
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (single_path_block_2): Sequential(
#           (0): StandardConvBlock(
#             (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU()
#           )
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (channel_modification): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#   )
#   (upconv3): ConvTranspose2d(128, 64, kernel_size=(2, 2), stride=(2, 2))
#   (dec3): MultiPathBlock(
#     (parallel_paths): ModuleList(
#       (0): SinglePathBlock(
#         (single_path_block_1): Sequential(
#           (0): StandardConvBlock(
#             (conv): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU()
#           )
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (single_path_block_2): Sequential(
#           (0): StandardConvBlock(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU()
#           )
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (channel_modification): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (1): SinglePathBlock(
#         (single_path_block_1): Sequential(
#           (0): StandardConvBlock(
#             (conv): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(3, 3), dilation=(3, 3), bias=False)
#             (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU()
#           )
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (single_path_block_2): Sequential(
#           (0): StandardConvBlock(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(3, 3), dilation=(3, 3), bias=False)
#             (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU()
#           )
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (channel_modification): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#   )
#   (upconv2): ConvTranspose2d(64, 32, kernel_size=(2, 2), stride=(2, 2))
#   (dec2): MultiPathBlock(
#     (parallel_paths): ModuleList(
#       (0): SinglePathBlock(
#         (single_path_block_1): Sequential(
#           (0): StandardConvBlock(
#             (conv): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU()
#           )
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (single_path_block_2): Sequential(
#           (0): StandardConvBlock(
#             (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU()
#           )
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (channel_modification): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (1): SinglePathBlock(
#         (single_path_block_1): Sequential(
#           (0): StandardConvBlock(
#             (conv): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(3, 3), dilation=(3, 3), bias=False)
#             (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU()
#           )
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (single_path_block_2): Sequential(
#           (0): StandardConvBlock(
#             (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(3, 3), dilation=(3, 3), bias=False)
#             (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU()
#           )
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (channel_modification): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (2): SinglePathBlock(
#         (single_path_block_1): Sequential(
#           (0): StandardConvBlock(
#             (conv): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(5, 5), dilation=(5, 5), bias=False)
#             (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU()
#           )
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (single_path_block_2): Sequential(
#           (0): StandardConvBlock(
#             (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(5, 5), dilation=(5, 5), bias=False)
#             (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU()
#           )
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (channel_modification): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#   )
#   (upconv1): ConvTranspose2d(32, 16, kernel_size=(2, 2), stride=(2, 2))
#   (dec1): MultiPathBlock(
#     (parallel_paths): ModuleList(
#       (0): SinglePathBlock(
#         (single_path_block_1): Sequential(
#           (0): StandardConvBlock(
#             (conv): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU()
#           )
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (single_path_block_2): Sequential(
#           (0): StandardConvBlock(
#             (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU()
#           )
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (channel_modification): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (1): SinglePathBlock(
#         (single_path_block_1): Sequential(
#           (0): StandardConvBlock(
#             (conv): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(3, 3), dilation=(3, 3), bias=False)
#             (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU()
#           )
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (single_path_block_2): Sequential(
#           (0): StandardConvBlock(
#             (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(3, 3), dilation=(3, 3), bias=False)
#             (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU()
#           )
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (channel_modification): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (2): SinglePathBlock(
#         (single_path_block_1): Sequential(
#           (0): StandardConvBlock(
#             (conv): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(5, 5), dilation=(5, 5), bias=False)
#             (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU()
#           )
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (single_path_block_2): Sequential(
#           (0): StandardConvBlock(
#             (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(5, 5), dilation=(5, 5), bias=False)
#             (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU()
#           )
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (channel_modification): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (3): SinglePathBlock(
#         (single_path_block_1): Sequential(
#           (0): StandardConvBlock(
#             (conv): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(7, 7), dilation=(7, 7), bias=False)
#             (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU()
#           )
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (single_path_block_2): Sequential(
#           (0): StandardConvBlock(
#             (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(7, 7), dilation=(7, 7), bias=False)
#             (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU()
#           )
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (channel_modification): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#   )
#   (final_conv): Conv2d(16, 1, kernel_size=(1, 1), stride=(1, 1))
#   (out_2): Conv2d(32, 1, kernel_size=(1, 1), stride=(1, 1))
#   (out_3): Conv2d(64, 1, kernel_size=(1, 1), stride=(1, 1))
#   (out_4): Conv2d(128, 1, kernel_size=(1, 1), stride=(1, 1))
# )

# %%
import matplotlib.pyplot as plt
import torch

def visualize_predictions(model, loader, device, num_images=5):
    model.eval()
    num_images_plotted = 0
    with torch.no_grad():
        for idx, (images, masks) in enumerate(loader):
            images = images.to(device)
            outputs = model(images)[0]
            preds = torch.sigmoid(outputs) > 0.5
            preds = preds.cpu().numpy()
            masks = masks.cpu().numpy()

            for i in range(images.size(0)):
                plt.figure(figsize=(10, 4))

                # Plot input image
                plt.subplot(1, 3, 1)
                img = images[i].cpu()
                if img.shape[0] == 1:
                    img = img.repeat(3, 1, 1)  # Convert grayscale to RGB
                plt.imshow(img.permute(1, 2, 0))
                plt.title('Input Image', fontsize=10)
                plt.axis('off')

                # Ground truth
                plt.subplot(1, 3, 2)
                plt.imshow(masks[i][0], cmap='gray')
                plt.title('Ground Truth', fontsize=10)
                plt.axis('off')

                # Prediction
                plt.subplot(1, 3, 3)
                plt.imshow(preds[i][0], cmap='gray')
                plt.title('Prediction', fontsize=10)
                plt.axis('off')

                plt.tight_layout()
                plt.show()

                num_images_plotted += 1
                if num_images_plotted >= num_images:
                    return
visualize_predictions(MODEL, val_loader, device, num_images=5)

# %% [markdown]
# # Testing after Training

# %%
import glob
import os
weight_files = sorted(glob.glob(os.path.join(folder_path, "*.pth")))
print(weight_files)
# Out:
# ['RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_1.pth', 'RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_10.pth', 'RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_2.pth', 'RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_3.pth', 'RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_4.pth', 'RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_5.pth', 'RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_6.pth', 'RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_7.pth', 'RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_8.pth', 'RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_9.pth']

# %%
import torch
import numpy as np
from sklearn.metrics import (precision_score, recall_score, f1_score,
                             roc_auc_score, jaccard_score, accuracy_score,
                             confusion_matrix)

# ------------------ Define Metric Functions ------------------
def calculate_iou(pred, target):
    intersection = (pred & target).sum()
    union = (pred | target).sum()
    iou = (intersection + 1e-6) / (union + 1e-6)  # Avoid division by zero
    return iou

def calculate_dice(pred, target):
    intersection = (pred & target).sum()
    dice = (2 * intersection + 1e-6) / (pred.sum() + target.sum() + 1e-6)
    return dice

def calculate_specificity(pred, target):
    # Compute confusion matrix values: tn, fp, fn, tp
    tn, fp, fn, tp = confusion_matrix(target, pred).ravel()
    specificity = tn / (tn + fp + 1e-6)
    return specificity

# ------------------ List of Weight Files ------------------
# Update the weight file names as needed.

weight_files = sorted(glob.glob(os.path.join(folder_path, "*.pth")))[:3]

# ------------------ Lists for Overall Metrics ------------------
all_weight_ious = []
all_weight_dice = []
all_weight_precisions = []
all_weight_recalls = []
all_weight_f1s = []
all_weight_aucs = []
all_weight_jaccard = []
all_weight_accuracies = []
all_weight_specificities = []

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

output_file = (f'{folder_path}evaluation_results.txt')
# Open a text file to store the results (this will overwrite any existing file)
with open(output_file, "w") as outfile:
    # Loop through each weight file
    for idx, weight_file in enumerate(weight_files, start=1):
        # Load the weights into the model
        MODEL.load_state_dict(torch.load(weight_file, map_location=device))
        MODEL.to(device)
        MODEL.eval()  # Set the model to evaluation mode

        # Temporary lists for current weight file (per-batch metrics)
        batch_ious = []
        batch_dice = []
        batch_precisions = []
        batch_recalls = []
        batch_f1s = []
        batch_aucs = []
        batch_jaccard = []
        batch_accuracies = []
        batch_specificities = []

        with torch.no_grad():
            for batch in val_loader:
                images, masks = batch
                images = images.to(device)
                masks = masks.to(device)

                # Get model outputs and predictions
                outputs = MODEL(images)[0]
                preds = torch.sigmoid(outputs) > 0.5  # Threshold at 0.5
                preds = preds.int()
                masks = masks.int()

                # Flatten for metric computation
                preds_np = preds.cpu().numpy().flatten()
                masks_np = masks.cpu().numpy().flatten()

                # Calculate metrics for the current batch
                iou = calculate_iou(preds_np, masks_np)
                dice = calculate_dice(preds_np, masks_np)
                precision = precision_score(masks_np, preds_np, zero_division=1)
                recall = recall_score(masks_np, preds_np, zero_division=1)  # Sensitivity
                f1 = f1_score(masks_np, preds_np, zero_division=1)
                jaccard = jaccard_score(masks_np, preds_np, zero_division=1)
                accuracy = accuracy_score(masks_np, preds_np)
                specificity = calculate_specificity(preds_np, masks_np)
                # For AUC, use continuous sigmoid outputs without thresholding
                auc = roc_auc_score(masks_np, torch.sigmoid(outputs).cpu().numpy().flatten())

                # Append current batch metrics
                batch_ious.append(iou)
                batch_dice.append(dice)
                batch_precisions.append(precision)
                batch_recalls.append(recall)
                batch_f1s.append(f1)
                batch_aucs.append(auc)
                batch_jaccard.append(jaccard)
                batch_accuracies.append(accuracy)
                batch_specificities.append(specificity)

        # Compute average metrics for the current weight file
        avg_iou = np.mean(batch_ious)
        avg_dice = np.mean(batch_dice)
        avg_precision = np.mean(batch_precisions)
        avg_recall = np.mean(batch_recalls)
        avg_f1 = np.mean(batch_f1s)
        avg_auc = np.mean(batch_aucs)
        avg_jaccard = np.mean(batch_jaccard)
        avg_accuracy = np.mean(batch_accuracies)
        avg_specificity = np.mean(batch_specificities)

        # Create an output string for the current weight file
        output_str = f"Weight File {idx} ({weight_file}):\n"
        output_str += f"  Average IoU: {avg_iou:.4f}\n"
        output_str += f"  Average Dice Coefficient: {avg_dice:.4f}\n"
        output_str += f"  Average Precision: {avg_precision:.4f}\n"
        output_str += f"  Average Recall (Sensitivity): {avg_recall:.4f}\n"
        output_str += f"  Average F1 Score: {avg_f1:.4f}\n"
        output_str += f"  Average AUC: {avg_auc:.4f}\n"
        output_str += f"  Average Jaccard Score: {avg_jaccard:.4f}\n"
        output_str += f"  Average Accuracy: {avg_accuracy:.4f}\n"
        output_str += f"  Average Specificity: {avg_specificity:.4f}\n\n"

        # Print to console and write to file
        print(output_str)
        outfile.write(output_str)

        # Append current averages to overall lists
        all_weight_ious.append(avg_iou)
        all_weight_dice.append(avg_dice)
        all_weight_precisions.append(avg_precision)
        all_weight_recalls.append(avg_recall)
        all_weight_f1s.append(avg_f1)
        all_weight_aucs.append(avg_auc)
        all_weight_jaccard.append(avg_jaccard)
        all_weight_accuracies.append(avg_accuracy)
        all_weight_specificities.append(avg_specificity)

    # ------------------ Overall Statistics ------------------
    overall_str = "Overall Metrics Across All Weight Files:\n"
    overall_str += f"Mean IoU: {np.mean(all_weight_ious):.4f}, Std IoU: {np.std(all_weight_ious):.4f}\n"
    overall_str += f"Mean Dice Coefficient: {np.mean(all_weight_dice):.4f}, Std Dice: {np.std(all_weight_dice):.4f}\n"
    overall_str += f"Mean Precision: {np.mean(all_weight_precisions):.4f}, Std Precision: {np.std(all_weight_precisions):.4f}\n"
    overall_str += f"Mean Recall (Sensitivity): {np.mean(all_weight_recalls):.4f}, Std Recall: {np.std(all_weight_recalls):.4f}\n"
    overall_str += f"Mean F1 Score: {np.mean(all_weight_f1s):.4f}, Std F1: {np.std(all_weight_f1s):.4f}\n"
    overall_str += f"Mean AUC: {np.mean(all_weight_aucs):.4f}, Std AUC: {np.std(all_weight_aucs):.4f}\n"
    overall_str += f"Mean Jaccard Score: {np.mean(all_weight_jaccard):.4f}, Std Jaccard: {np.std(all_weight_jaccard):.4f}\n"
    overall_str += f"Mean Accuracy: {np.mean(all_weight_accuracies):.4f}, Std Accuracy: {np.std(all_weight_accuracies):.4f}\n"
    overall_str += f"Mean Specificity: {np.mean(all_weight_specificities):.4f}, Std Specificity: {np.std(all_weight_specificities):.4f}\n"

    print(overall_str)
    outfile.write(overall_str)
# Out:
# Weight File 1 (RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_1.pth):
#   Average IoU: 0.5459
#   Average Dice Coefficient: 0.7056
#   Average Precision: 0.5707
#   Average Recall (Sensitivity): 0.9267
#   Average F1 Score: 0.7056
#   Average AUC: 0.9882
#   Average Jaccard Score: 0.5459
#   Average Accuracy: 0.9597
#   Average Specificity: 0.9616
#
#
# Weight File 2 (RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_10.pth):
#   Average IoU: 0.5387
#   Average Dice Coefficient: 0.6995
#   Average Precision: 0.5624
#   Average Recall (Sensitivity): 0.9290
#   Average F1 Score: 0.6995
#   Average AUC: 0.9877
#   Average Jaccard Score: 0.5387
#   Average Accuracy: 0.9584
#   Average Specificity: 0.9601
#
#
# Weight File 3 (RESULTS/MODEL_02_FINAL_STOCK_DIA/MODEL_02_FINAL_STOCK_DIA_RUN_2.pth):
#   Average IoU: 0.5597
#   Average Dice Coefficient: 0.7170
#   Average Precision: 0.5896
#   Average Recall (Sensitivity): 0.9183
#   Average F1 Score: 0.7170
#   Average AUC: 0.9879
#   Average Jaccard Score: 0.5597
#   Average Accuracy: 0.9622
#   Average Specificity: 0.9647
#
#
# Overall Metrics Across All Weight Files:
# Mean IoU: 0.5481, Std IoU: 0.0087
# Mean Dice Coefficient: 0.7074, Std Dice: 0.0072
# Mean Precision: 0.5742, Std Precision: 0.0114
# Mean Recall (Sensitivity): 0.9247, Std Recall: 0.0046
# Mean F1 Score: 0.7074, Std F1: 0.0072
# Mean AUC: 0.9879, Std AUC: 0.0002
# Mean Jaccard Score: 0.5481, Std Jaccard: 0.0087
# Mean Accuracy: 0.9601, Std Accuracy: 0.0016
# Mean Specificity: 0.9621, Std Specificity: 0.0019
