# %% [markdown]
# # ENV

# %%
! module load mamba/latest
# Out:
# =====================================================================
# This module is only for creating or activating Python environments:
# $ mamba create -n myenv -c conda-forge python=3 <package_name>
# $ source activate myenv
#
# Only run "pip install" after activating an environment.
# Running pip without activating an environment is known to cause issues.
#
# To list available environments:
# $ mamba info --envs
#
# Other uses are not tested. More info: https://links.asu.edu/solpy
# =====================================================================

# %%
! source activate PYTORCH_ENV_AUG_2024

# %% [markdown]
# # Imports

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
import torchvision.transforms as transforms
from torchvision import datasets
from PIL import Image
import os
import numpy as np
import matplotlib.pyplot as plt
import albumentations as A
from albumentations.pytorch import ToTensorV2
from PIL import Image
from torchinfo import summary
import torch.nn.functional as F
from operator import add

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)
# Out:
# cuda

# %%
PATCH_SIZE = 256
OVERLAP = '50'

# %% [markdown]
# # Model

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class UNet(nn.Module):
    def __init__(self):
        super(UNet, self).__init__()

        # Downsampling (encoder) blocks
        self.enc1 = self.conv_block(1, 16)
        self.enc2 = self.conv_block(16, 32)
        self.enc3 = self.conv_block(32, 64)
        self.enc4 = self.conv_block(64, 128)

        # Bottleneck
        self.bottleneck = self.conv_block(128, 256)

        # Upsampling (decoder) blocks
        self.upconv4 = nn.ConvTranspose2d(256, 128, kernel_size=2, stride=2)
        self.dec4 = self.conv_block(128 + 128, 128)

        self.upconv3 = nn.ConvTranspose2d(128, 64, kernel_size=2, stride=2)
        self.dec3 = self.conv_block(64 + 64, 64)

        self.upconv2 = nn.ConvTranspose2d(64, 32, kernel_size=2, stride=2)
        self.dec2 = self.conv_block(32 + 32, 32)

        self.upconv1 = nn.ConvTranspose2d(32, 16, kernel_size=2, stride=2)
        self.dec1 = self.conv_block(16 + 16, 16)

        # Final output layer
        self.final_conv = nn.Conv2d(16, 1, kernel_size=1)

    def conv_block(self, in_channels, out_channels):
        block = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True)
        )
        return block

    def forward(self, x):
        # Encoder path
        e1 = self.enc1(x)
        e2 = self.enc2(F.max_pool2d(e1, 2))
        e3 = self.enc3(F.max_pool2d(e2, 2))
        e4 = self.enc4(F.max_pool2d(e3, 2))

        # Bottleneck
        b = self.bottleneck(F.max_pool2d(e4, 2))

        # Decoder path
        d4 = self.upconv4(b)
        d4 = torch.cat((d4, e4), dim=1)
        d4 = self.dec4(d4)

        d3 = self.upconv3(d4)
        d3 = torch.cat((d3, e3), dim=1)
        d3 = self.dec3(d3)

        d2 = self.upconv2(d3)
        d2 = torch.cat((d2, e2), dim=1)
        d2 = self.dec2(d2)

        d1 = self.upconv1(d2)
        d1 = torch.cat((d1, e1), dim=1)
        d1 = self.dec1(d1)

        # Final output
        out = self.final_conv(d1)
        return out

# %%
MODEL = UNet()
(summary(model=MODEL,
          input_size=(32, 1, PATCH_SIZE, PATCH_SIZE), # (batch_size, color_channels, height, width)
          col_names=["input_size", "output_size", "num_params", "trainable"],
          col_width=20,
          row_settings=["var_names"]
  ))
# Out:
# ========================================================================================================================
# Layer (type (var_name))                  Input Shape          Output Shape         Param #              Trainable
# ========================================================================================================================
# UNet (UNet)                              [32, 1, 256, 256]    [32, 1, 256, 256]    --                   True
# ├─Sequential (enc1)                      [32, 1, 256, 256]    [32, 16, 256, 256]   --                   True
# │    └─Conv2d (0)                        [32, 1, 256, 256]    [32, 16, 256, 256]   160                  True
# │    └─BatchNorm2d (1)                   [32, 16, 256, 256]   [32, 16, 256, 256]   32                   True
# │    └─ReLU (2)                          [32, 16, 256, 256]   [32, 16, 256, 256]   --                   --
# │    └─Conv2d (3)                        [32, 16, 256, 256]   [32, 16, 256, 256]   2,320                True
# │    └─BatchNorm2d (4)                   [32, 16, 256, 256]   [32, 16, 256, 256]   32                   True
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 109.64
# ========================================================================================================================
# Input size (MB): 8.39
# Forward/backward pass size (MB): 4613.73
# Params size (MB): 7.78
# Estimated Total Size (MB): 4629.90
# ========================================================================================================================

# %%
# # Blood Vessel
train_image_dir = f'/scratch/raouti/FUNDUS_DATASETS/DRIVE/DRIVE_NOV_2024/{PATCH_SIZE}/PATCHIFY_DRIVE_{PATCH_SIZE}_{OVERLAP}/train/image/'
train_mask_dir =  f'/scratch/raouti/FUNDUS_DATASETS/DRIVE/DRIVE_NOV_2024/{PATCH_SIZE}/PATCHIFY_DRIVE_{PATCH_SIZE}_{OVERLAP}/train/mask/'
test_image_dir =  f'/scratch/raouti/FUNDUS_DATASETS/DRIVE/DRIVE_NOV_2024/{PATCH_SIZE}/PATCHIFY_DRIVE_{PATCH_SIZE}_{OVERLAP}/test/image/'
test_mask_dir =   f'/scratch/raouti/FUNDUS_DATASETS/DRIVE/DRIVE_NOV_2024/{PATCH_SIZE}/PATCHIFY_DRIVE_{PATCH_SIZE}_{OVERLAP}/test/mask/'

# %%
print(train_image_dir)
print(train_mask_dir)
print(test_image_dir)
print(test_mask_dir)
# Out:
# /scratch/raouti/FUNDUS_DATASETS/DRIVE/DRIVE_NOV_2024/256/PATCHIFY_DRIVE_256_50/train/image/
# /scratch/raouti/FUNDUS_DATASETS/DRIVE/DRIVE_NOV_2024/256/PATCHIFY_DRIVE_256_50/train/mask/
# /scratch/raouti/FUNDUS_DATASETS/DRIVE/DRIVE_NOV_2024/256/PATCHIFY_DRIVE_256_50/test/image/
# /scratch/raouti/FUNDUS_DATASETS/DRIVE/DRIVE_NOV_2024/256/PATCHIFY_DRIVE_256_50/test/mask/

# %%
img_testing = sorted(os.listdir(train_image_dir))
lab_testing = sorted(os.listdir(train_mask_dir))
print(len(img_testing))
img_path = os.path.join(train_image_dir,img_testing[10])
mask_path = os.path.join(train_mask_dir, lab_testing[10])
IMAGE = Image.open(img_path)
LAB = Image.open(mask_path)
# Out:
# 720

# %%
image_transform = transforms.Compose([
    transforms.Resize((PATCH_SIZE, PATCH_SIZE)),
    transforms.ToTensor()
])

IMAGE_TESTING = image_transform(IMAGE)
LAB_TESTING = image_transform(LAB)

# %%
plt.imshow(IMAGE_TESTING.permute(1,2,0),cmap = 'gray')

# %%
plt.imshow(LAB_TESTING.permute(1,2,0),cmap = 'gray')

# %%
class SegmentationDataset(Dataset):
    def __init__(self, image_dir, mask_dir, transform=None):
        self.image_dir = image_dir
        self.mask_dir = mask_dir
        self.transform = transform
        self.images = os.listdir(image_dir)
        self.labels = os.listdir(mask_dir)
        self.images.sort()
        self.labels.sort()


    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_path = os.path.join(self.image_dir, self.images[idx])
        mask_path = os.path.join(self.mask_dir, self.labels[idx])
        image = Image.open(img_path)
        mask = Image.open(mask_path)
        image = np.array(Image.open(img_path).convert("L"))  # Convert image to RGB and NumPy array
        mask = np.array(Image.open(mask_path).convert("L")) 

        if self.transform:
        #     image = self.transform(image)
        #     mask = self.transform(mask)
            transformed = self.transform(image=image, mask=mask)
            image = transformed['image'].float()/255
            mask = transformed['mask'].unsqueeze(0).float()/255

        return image, mask

# %%
train_transform = A.Compose([           
                                        A.Resize(PATCH_SIZE,PATCH_SIZE),  # Resize image and mask
                                        # A.Transpose(p=0.5),       # Randomly transpose the image
                                        # A.RandomBrightnessContrast(brightness_limit=0.2, contrast_limit=0.2, p=0.5),  # Adjust brightness and contrast
                                        # A.GaussianBlur(blur_limit=(3, 7), p=0.3),  # Apply Gaussian blur
                                        # A.CoarseDropout(max_holes=8, max_height=32, max_width=32, min_holes=4, min_height=8, min_width=8, fill_value=0, p=0.5),  # Add CutOut
                                        ToTensorV2() # Convert to PyTorch tensors
                                        ])

val_transform = A.Compose([A.Resize(PATCH_SIZE,PATCH_SIZE),
                                    ToTensorV2() 
                                     ])


train_dataset = SegmentationDataset(image_dir=train_image_dir, mask_dir=train_mask_dir, transform=train_transform)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)

val_dataset = SegmentationDataset(image_dir=test_image_dir, mask_dir=test_mask_dir, transform=val_transform)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

# %%
img,lab= next(iter(train_loader))

# %%
img.shape,lab.shape
# Out:
# (torch.Size([32, 1, 256, 256]), torch.Size([32, 1, 256, 256]))

# %%
img[0].dtype,img[0].max(),img[0].min(),
# Out:
# (torch.float32, tensor(0.9843), tensor(0.0118))

# %%
plt.imshow(torch.permute(img[3],(1,2,0)),cmap = 'gray')

# %%
plt.imshow(torch.permute(lab[3],(1,2,0)),cmap = 'gray')

# %%
RES_TESTING = MODEL(IMAGE_TESTING.unsqueeze(0).to(device))
print(RES_TESTING.shape)
# Out:
# torch.Size([1, 1, 256, 256])

# %%
plt.imshow(torch.permute(RES_TESTING[0].detach().cpu(),(1,2,0)),cmap = 'gray')

# %%
print(f'type = {type(RES_TESTING[0])}')
print(f'max = {torch.max(RES_TESTING[0])}')
print(f'min = {torch.min(RES_TESTING[0])}')
# Out:
# type = <class 'torch.Tensor'>
# max = 5.217626571655273
# min = -1.1664600372314453

# %%
sigmoid_output = torch.sigmoid(RES_TESTING[0])
plt.imshow(torch.permute(sigmoid_output.detach().cpu(),(1,2,0)),cmap = 'gray')

# %%
print(f'type = {type(sigmoid_output)}')
print(f'max = {torch.max(sigmoid_output)}')
print(f'min = {torch.min(sigmoid_output)}')
# Out:
# type = <class 'torch.Tensor'>
# max = 0.994608998298645
# min = 0.23749545216560364

# %%
sigmoid_output_threshold = (torch.sigmoid(RES_TESTING[0]) > 0.5)
plt.imshow(torch.permute(sigmoid_output_threshold.detach().cpu(),(1,2,0)),cmap = 'gray')

# %%
print(f'type = {type(sigmoid_output_threshold)}')
print(f'max = {torch.max(sigmoid_output_threshold)}')
print(f'min = {torch.min(sigmoid_output_threshold)}')
# Out:
# type = <class 'torch.Tensor'>
# max = True
# min = False

# %% [markdown]
# # Training

# %%
# import torch
# import torch.nn as nn
# import torch.optim as optim
# from torch.optim.lr_scheduler import StepLR
# import torch.nn.utils as utils
# from torch.optim.lr_scheduler import ReduceLROnPlateau

# initial_lr = 0.001
# weight_decay = 0.01 
# momentum_value = 0.9
# device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# model = MODEL

# optimizer = optim.Adam(model.parameters(), lr=initial_lr, betas=(0.9, 0.999))  # Adam optimizer with default beta values
# scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=5, verbose=True)

# %%
def train(model, loader, optimizer, criterion, device,scheduler):
    model.train()


    total_loss = 0
    len_loader = len(loader)
    max_grad_norm = 1

    for idx,(images, masks) in enumerate(loader):
        images, masks = images.to(device), masks.to(device)
        optimizer.zero_grad()
        outputs = model(images)       
        loss = criterion(outputs, masks)
        loss.backward()
        # utils.clip_grad_norm_(model.parameters(), max_grad_norm)
        optimizer.step()
        total_loss += loss.item()
        
    print(f"_______________________Training - __________________________________")
    epoch_loss = total_loss/ len_loader
    return  epoch_loss

def validate(model, loader, criterion, device,scheduler):

    model.eval()
    total_loss = 0
    len_loader = len(loader)
    with torch.no_grad():
        for idx,(images, masks) in enumerate(loader):
            images, masks = images.to(device), masks.to(device)
            outputs = model(images)
            loss = criterion(outputs, masks)
            total_loss += loss.item()
    scheduler.step(loss)
    print(f"_______________________Validation - __________________________________")
    epoch_loss = total_loss/ len_loader
    return  epoch_loss

# %% [markdown]
# # Loss Function

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class DiceLoss(nn.Module):
    def __init__(self, weight=None, size_average=True):
        super(DiceLoss, self).__init__()

    def forward(self, inputs, targets, smooth=1):

        #comment out if your model contains a sigmoid or equivalent activation layer
        inputs = torch.sigmoid(inputs)

        #flatten label and prediction tensors
        inputs = inputs.view(-1)
        targets = targets.view(-1)

        intersection = (inputs * targets).sum()
        dice = (2.*intersection + smooth)/(inputs.sum() + targets.sum() + smooth)

        return 1 - dice

class DiceBCELoss(nn.Module):
    def __init__(self, weight=None, size_average=True):
        super(DiceBCELoss, self).__init__()

    def forward(self, inputs, targets, smooth=1):

        #comment out if your model contains a sigmoid or equivalent activation layer
        inputs = torch.sigmoid(inputs)

        #flatten label and prediction tensors
        inputs = inputs.view(-1)
        targets = targets.view(-1)

        intersection = (inputs * targets).sum()
        dice_loss = 1 - (2.*intersection + smooth)/(inputs.sum() + targets.sum() + smooth)
        BCE = F.binary_cross_entropy(inputs, targets, reduction='mean')
        Dice_BCE = BCE + dice_loss

        return Dice_BCE

# %%
# !pwd
# Out:
# /scratch/raouti/JAN_2025_SEG_REPEAT/Blood_Vessel/FINAL_MODELS

# %%
# import torch

# criterion = DiceBCELoss()
# num_epochs = 100  
# patience = 10  

# best_valid_loss = float("inf")
# total_train_loss = []
# total_val_loss = []

# early_stopping_counter = 0 

# for epoch in range(num_epochs):
#     train_loss = train(model, train_loader, optimizer, criterion, device, scheduler)
#     valid_loss = validate(model, val_loader, criterion, device, scheduler)
    
#     total_train_loss.append(train_loss)
#     total_val_loss.append(valid_loss)

#     if valid_loss < best_valid_loss:
#         data_str = f"Valid loss improved from {best_valid_loss:.3f} to {valid_loss:.3f}. Saving checkpoint: {checkpoint_path}"
#         print(data_str)
#         best_valid_loss = valid_loss
#         torch.save(model.state_dict(), checkpoint_path)
#         early_stopping_counter = 0  # reset counter after improvement
#     else:
#         early_stopping_counter += 1
#         print(f"No improvement in validation loss for {early_stopping_counter} epochs.")

#     if early_stopping_counter >= patience:
#         print(f"Stopping early after {epoch+1} epochs due to no improvement in validation loss.")
#         break

#     data_str = f'Epoch: {epoch+1:02} |'
#     data_str += f'\tTrain Loss: {train_loss:.3f} |'
#     data_str += f'\tVal. Loss: {valid_loss:.3f}\n'
#     print(data_str)

# %%
model_no = '01'
checkpoint_name = f'RESULTS/MODEL_{model_no}/MODEL_{model_no}_RUN'
log_file_name = f'RESULTS/MODEL_{model_no}/training_log.txt'
folder_path = f"RESULTS/MODEL_{model_no}/"  
folder_path
# Out:
# 'RESULTS/MODEL_01/'

# %%
import torch
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR
import torch.nn.utils as utils
from torch.optim.lr_scheduler import ReduceLROnPlateau


criterion = DiceBCELoss()
num_epochs = 100  
patience = 10  
num_runs = 10  
best_valid_losses = [] 

initial_lr = 0.001
weight_decay = 0.01 
momentum_value = 0.9
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

with open(log_file_name, 'w') as log_file:
        log_file.write(f"STARTING")
    
for run in range(num_runs):
    
    print(f"Starting run {run+1}/{num_runs}")
    print(f"MODEL INTIALIZATION")
    model = UNet().to(device)
    optimizer = optim.Adam(model.parameters(), lr=initial_lr, betas=(0.9, 0.999))  # Adam optimizer with default beta values
    scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=5, verbose=True)

    with open(log_file_name, 'a') as log_file:
        log_file.write(f"RUN NO {run+1}/{num_runs}\n")
        log_file.write("MODEL INTIALIZATION \n")

    best_valid_loss = float("inf")
    total_train_loss = []
    total_val_loss = []
    early_stopping_counter = 0 

    for epoch in range(num_epochs):
        train_loss = train(model, train_loader, optimizer, criterion, device, scheduler)
        valid_loss = validate(model, val_loader, criterion, device, scheduler)
        
        total_train_loss.append(train_loss)
        total_val_loss.append(valid_loss)
    
        if valid_loss < best_valid_loss:
            # Create a checkpoint filename that includes the run and epoch number
            checkpoint_path = f"{checkpoint_name}_{run+1}.pth"
            print(f"Valid loss improved from {best_valid_loss:.3f} to {valid_loss:.3f}. Saving checkpoint: {checkpoint_path}")
            best_valid_loss = valid_loss
            torch.save(model.state_dict(), checkpoint_path)
            early_stopping_counter = 0  # reset counter after improvement
        else:
            early_stopping_counter += 1
            print(f"No improvement in validation loss for {early_stopping_counter} epochs.")
    
        if early_stopping_counter >= patience:
            print(f"Stopping early after {epoch+1} epochs due to no improvement in validation loss.")
            break

        log_message = f'Epoch: {epoch+1:02} | Train Loss: {train_loss:.3f} | Val. Loss: {valid_loss:.3f}\n'
        print(log_message)
        
        with open(log_file_name, 'a') as log_file:
            log_file.write(log_message)
    
    best_valid_losses.append(best_valid_loss)
    best_log = f"Run {run+1} finished with best validation loss: {best_valid_loss:.3f}\n"
    print(best_log)

    with open(log_file_name, 'a') as log_file:
        log_file.write(best_log)

# Compute mean and standard deviation across the 10 runs
mean_valid_loss = np.mean(best_valid_losses)
std_valid_loss = np.std(best_valid_losses)
print(f"Mean best validation loss over {num_runs} runs: {mean_valid_loss:.3f}")
print(f"Std of best validation loss over {num_runs} runs: {std_valid_loss:.3f}")
# Out:
# Starting run 1/10
# MODEL INTIALIZATION
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from inf to 1.517. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_1.pth
# Epoch: 01 | Train Loss: 1.421 | Val. Loss: 1.517
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 1.517 to 1.361. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_1.pth
# Epoch: 02 | Train Loss: 1.256 | Val. Loss: 1.361
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 1.361 to 1.138. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_1.pth
# Epoch: 03 | Train Loss: 1.168 | Val. Loss: 1.138
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 1.138 to 1.081. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_1.pth
# Epoch: 04 | Train Loss: 1.089 | Val. Loss: 1.081
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 1.081 to 1.001. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_1.pth
# Epoch: 05 | Train Loss: 1.013 | Val. Loss: 1.001
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 1.001 to 0.912. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_1.pth
# Epoch: 06 | Train Loss: 0.941 | Val. Loss: 0.912
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.912 to 0.849. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_1.pth
# Epoch: 07 | Train Loss: 0.865 | Val. Loss: 0.849
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.849 to 0.757. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_1.pth
# Epoch: 08 | Train Loss: 0.792 | Val. Loss: 0.757
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.757 to 0.718. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_1.pth
# Epoch: 09 | Train Loss: 0.730 | Val. Loss: 0.718
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.718 to 0.650. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_1.pth
# Epoch: 10 | Train Loss: 0.674 | Val. Loss: 0.650
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.650 to 0.600. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_1.pth
# Epoch: 11 | Train Loss: 0.624 | Val. Loss: 0.600
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.600 to 0.561. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_1.pth
# Epoch: 12 | Train Loss: 0.580 | Val. Loss: 0.561
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.561 to 0.521. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_1.pth
# Epoch: 13 | Train Loss: 0.543 | Val. Loss: 0.521
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.521 to 0.494. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_1.pth
# Epoch: 14 | Train Loss: 0.510 | Val. Loss: 0.494
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.494 to 0.473. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_1.pth
# Epoch: 15 | Train Loss: 0.482 | Val. Loss: 0.473
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.473 to 0.451. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_1.pth
# Epoch: 16 | Train Loss: 0.459 | Val. Loss: 0.451
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.451 to 0.435. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_1.pth
# Epoch: 17 | Train Loss: 0.440 | Val. Loss: 0.435
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.435 to 0.420. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_1.pth
# Epoch: 18 | Train Loss: 0.424 | Val. Loss: 0.420
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.420 to 0.412. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_1.pth
# Epoch: 19 | Train Loss: 0.411 | Val. Loss: 0.412
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.412 to 0.403. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_1.pth
# Epoch: 20 | Train Loss: 0.397 | Val. Loss: 0.403
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.403 to 0.400. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_1.pth
# Epoch: 21 | Train Loss: 0.386 | Val. Loss: 0.400
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.400 to 0.390. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_1.pth
# Epoch: 22 | Train Loss: 0.377 | Val. Loss: 0.390
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.390 to 0.385. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_1.pth
# Epoch: 23 | Train Loss: 0.366 | Val. Loss: 0.385
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.385 to 0.380. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_1.pth
# Epoch: 24 | Train Loss: 0.359 | Val. Loss: 0.380
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 25 | Train Loss: 0.349 | Val. Loss: 0.382
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 2 epochs.
# Epoch:
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.387 to 0.380. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_2.pth
# Epoch: 19 | Train Loss: 0.371 | Val. Loss: 0.380
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 20 | Train Loss: 0.362 | Val. Loss: 0.399
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.380 to 0.368. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_2.pth
# Epoch: 21 | Train Loss: 0.356 | Val. Loss: 0.368
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 22 | Train Loss: 0.346 | Val. Loss: 0.369
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 2 epochs.
# Epoch: 23 | Train Loss: 0.339 | Val. Loss: 0.371
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 3 epochs.
# Epoch: 24 | Train Loss: 0.330 | Val. Loss: 0.377
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 4 epochs.
# Epoch: 25 | Train Loss: 0.323 | Val. Loss: 0.371
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 5 epochs.
# Epoch: 26 | Train Loss: 0.316 | Val. Loss: 0.375
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 6 epochs.
# Epoch: 27 | Train Loss: 0.309 | Val. Loss: 0.378
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 7 epochs.
# Epoch: 28 | Train Loss: 0.302 | Val. Loss: 0.376
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 8 epochs.
# Epoch: 29 | Train Loss: 0.295 | Val. Loss: 0.373
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 9 epochs.
# Epoch: 30 | Train Loss: 0.290 | Val. Loss: 0.376
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 10 epochs.
# Stopping early after 31 epochs due to no improvement in validation loss.
# Run 2 finished with best validation loss: 0.368
#
# Starting run 3/10
# MODEL INTIALIZATION
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from inf to 1.483. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_3.pth
# Epoch: 01 | Train Loss: 1.441 | Val. Loss: 1.483
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 1.483 to 1.373. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_3.pth
# Epoch: 02 | Train Loss: 1.280 | Val. Loss: 1.373
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 1.373 to 1.162. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_3.pth
# Epoch: 03 | Train Loss: 1.199 | Val. Loss: 1.162
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 1.162 to 1.083. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_3.pth
# Epoch: 04 | Train Loss: 1.123 | Val. Loss: 1.083
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 1.083 to 1.031. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_3.pth
# Epoch: 05 | Train Loss: 1.056 | Val. Loss: 1.031
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 1.031 to 0.955. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_3.pth
# Epoch: 06 | Train Loss: 0.989 | Val. Loss: 0.955
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.955 to 0.906. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_3.pth
# Epoch: 07 | Train Loss: 0.924 | Val. Loss: 0.906
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.906 to 0.844. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_3.pth
# Epoch: 08 | Train Loss: 0.862 | Val. Loss: 0.844
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.844 to 0.784. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_3.pth
# Epoch: 09 | Train Loss: 0.803 | Val. Loss: 0.784
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.784 to 0.725. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_3.pth
# Epoch: 10 | Train Loss: 0.746 | Val. Loss: 0.725
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.725 to 0.681. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_3.pth
# Epoch: 11 | Train Loss: 0.695 | Val. Loss: 0.681
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.681 to 0.644. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_3.pth
# Epoch: 12 | Train Loss: 0.645 | Val. Loss: 0.644
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.644 to 0.595. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_3.pth
# Epoch: 13 | Train Loss: 0.605 | Val. Loss: 0.595
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.595 to 0.573. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_3.pth
# Epoch: 14 | Train Loss: 0.566 | Val. Loss: 0.573
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.573 to 0.528. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_3.pth
# Epoch: 15 | Train Loss: 0.532 | Val. Loss: 0.528
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.528 to 0.523. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_3.pth
# Epoch: 16 | Train Loss: 0.504 | Val. Loss: 0.523
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.523 to 0.481. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_3.pth
# Epoch: 17 | Train Loss: 0.478 | Val. Loss: 0.481
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.481 to 0.467. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_3.pth
# Epoch: 18 | Train Loss: 0.450 | Val. Loss: 0.467
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.467 to 0.449. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_3.pth
# Epoch: 19 | Train Loss: 0.432 | Val. Loss: 0.449
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.449 to 0.431. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_3.pth
# Epoch: 20 | Train Loss: 0.415 | Val. Loss: 0.431
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.431 to 0.429. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_3.pth
# Epoch: 21 | Train Loss: 0.397 | Val. Loss: 0.429
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.429 to 0.422. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_3.pth
# Epoch: 22 | Train Loss: 0.382 | Val. Loss: 0.422
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.422 to 0.409. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_3.pth
# Epoch: 23 | Train Loss: 0.368 | Val. Loss: 0.409
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 24 | Train Loss: 0.350 | Val. Loss: 0.414
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.409 to 0.407. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_3.pth
# Epoch: 25 | Train Loss: 0.340 | Val. Loss: 0.407
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.407 to 0.404. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_3.pth
# Epoch: 26 | Train Loss: 0.330 | Val. Loss: 0.404
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.404 to 0.400. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_3.pth
# Epoch: 27 | Train Loss: 0.319 | Val. Loss: 0.400
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.400 to 0.395. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_3.pth
# Epoch: 28 | Train Loss: 0.308 | Val. Loss: 0.395
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch:
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.392 to 0.390. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_9.pth
# Epoch: 32 | Train Loss: 0.285 | Val. Loss: 0.390
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 33 | Train Loss: 0.280 | Val. Loss: 0.394
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 2 epochs.
# Epoch: 34 | Train Loss: 0.273 | Val. Loss: 0.392
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 3 epochs.
# Epoch: 35 | Train Loss: 0.273 | Val. Loss: 0.391
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 4 epochs.
# Epoch: 36 | Train Loss: 0.267 | Val. Loss: 0.392
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 5 epochs.
# Epoch: 37 | Train Loss: 0.261 | Val. Loss: 0.391
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 6 epochs.
# Epoch: 38 | Train Loss: 0.259 | Val. Loss: 0.391
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 7 epochs.
# Epoch: 39 | Train Loss: 0.257 | Val. Loss: 0.396
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 8 epochs.
# Epoch: 40 | Train Loss: 0.256 | Val. Loss: 0.396
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 9 epochs.
# Epoch: 41 | Train Loss: 0.253 | Val. Loss: 0.395
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.390 to 0.384. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_9.pth
# Epoch: 42 | Train Loss: 0.245 | Val. Loss: 0.384
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 43 | Train Loss: 0.238 | Val. Loss: 0.386
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 2 epochs.
# Epoch: 44 | Train Loss: 0.237 | Val. Loss: 0.386
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 3 epochs.
# Epoch: 45 | Train Loss: 0.237 | Val. Loss: 0.388
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 4 epochs.
# Epoch: 46 | Train Loss: 0.236 | Val. Loss: 0.387
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 5 epochs.
# Epoch: 47 | Train Loss: 0.235 | Val. Loss: 0.389
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 6 epochs.
# Epoch: 48 | Train Loss: 0.233 | Val. Loss: 0.388
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 7 epochs.
# Epoch: 49 | Train Loss: 0.233 | Val. Loss: 0.388
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 8 epochs.
# Epoch: 50 | Train Loss: 0.234 | Val. Loss: 0.389
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 9 epochs.
# Epoch: 51 | Train Loss: 0.233 | Val. Loss: 0.388
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 10 epochs.
# Stopping early after 52 epochs due to no improvement in validation loss.
# Run 9 finished with best validation loss: 0.384
#
# Starting run 10/10
# MODEL INTIALIZATION
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from inf to 1.357. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_10.pth
# Epoch: 01 | Train Loss: 1.233 | Val. Loss: 1.357
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 1.357 to 1.113. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_10.pth
# Epoch: 02 | Train Loss: 1.074 | Val. Loss: 1.113
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 1.113 to 0.955. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_10.pth
# Epoch: 03 | Train Loss: 0.985 | Val. Loss: 0.955
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.955 to 0.885. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_10.pth
# Epoch: 04 | Train Loss: 0.904 | Val. Loss: 0.885
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.885 to 0.804. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_10.pth
# Epoch: 05 | Train Loss: 0.829 | Val. Loss: 0.804
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.804 to 0.743. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_10.pth
# Epoch: 06 | Train Loss: 0.761 | Val. Loss: 0.743
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.743 to 0.675. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_10.pth
# Epoch: 07 | Train Loss: 0.699 | Val. Loss: 0.675
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.675 to 0.607. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_10.pth
# Epoch: 08 | Train Loss: 0.642 | Val. Loss: 0.607
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.607 to 0.573. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_10.pth
# Epoch: 09 | Train Loss: 0.594 | Val. Loss: 0.573
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.573 to 0.558. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_10.pth
# Epoch: 10 | Train Loss: 0.553 | Val. Loss: 0.558
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.558 to 0.530. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_10.pth
# Epoch: 11 | Train Loss: 0.518 | Val. Loss: 0.530
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.530 to 0.489. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_10.pth
# Epoch: 12 | Train Loss: 0.488 | Val. Loss: 0.489
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.489 to 0.456. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_10.pth
# Epoch: 13 | Train Loss: 0.462 | Val. Loss: 0.456
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.456 to 0.442. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_10.pth
# Epoch: 14 | Train Loss: 0.442 | Val. Loss: 0.442
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.442 to 0.429. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_10.pth
# Epoch: 15 | Train Loss: 0.424 | Val. Loss: 0.429
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.429 to 0.414. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_10.pth
# Epoch: 16 | Train Loss: 0.407 | Val. Loss: 0.414
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 17 | Train Loss: 0.392 | Val. Loss: 0.429
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.414 to 0.406. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_10.pth
# Epoch: 18 | Train Loss: 0.378 | Val. Loss: 0.406
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.406 to 0.391. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_10.pth
# Epoch: 19 | Train Loss: 0.368 | Val. Loss: 0.391
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 20 | Train Loss: 0.355 | Val. Loss: 0.392
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.391 to 0.385. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_10.pth
# Epoch: 21 | Train Loss: 0.346 | Val. Loss: 0.385
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 22 | Train Loss: 0.333 | Val. Loss: 0.393
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 2 epochs.
# Epoch: 23 | Train Loss: 0.324 | Val. Loss: 0.388
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.385 to 0.383. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_10.pth
# Epoch: 24 | Train Loss: 0.314 | Val. Loss: 0.383
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 25 | Train Loss: 0.307 | Val. Loss: 0.387
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.383 to 0.381. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_10.pth
# Epoch: 26 | Train Loss: 0.303 | Val. Loss: 0.381
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# Valid loss improved from 0.381 to 0.379. Saving checkpoint: RESULTS/MODEL_02/MODEL_02_RUN_10.pth
# Epoch: 27 | Train Loss: 0.296 | Val. Loss: 0.379
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 1 epochs.
# Epoch: 28 | Train Loss: 0.288 | Val. Loss: 0.383
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 2 epochs.
# Epoch: 29 | Train Loss: 0.278 | Val. Loss: 0.382
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 3 epochs.
# Epoch: 30 | Train Loss: 0.275 | Val. Loss: 0.389
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 4 epochs.
# Epoch: 31 | Train Loss: 0.271 | Val. Loss: 0.390
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 5 epochs.
# Epoch: 32 | Train Loss: 0.267 | Val. Loss: 0.393
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 6 epochs.
# Epoch: 33 | Train Loss: 0.264 | Val. Loss: 0.391
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 7 epochs.
# Epoch: 34 | Train Loss: 0.254 | Val. Loss: 0.380
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 8 epochs.
# Epoch: 35 | Train Loss: 0.250 | Val. Loss: 0.381
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 9 epochs.
# Epoch: 36 | Train Loss: 0.248 | Val. Loss: 0.382
#
# _______________________Training - __________________________________
# _______________________Validation - __________________________________
# No improvement in validation loss for 10 epochs.
# Stopping early after 37 epochs due to no improvement in validation loss.
# Run 10 finished with best validation loss: 0.379
#
# Mean best validation loss over 10 runs: 0.375
# Std of best validation loss over 10 runs: 0.008

# %%
# Plot accuracies over epochs
plt.figure()
plt.plot(range(1, epoch+2), total_train_loss, label=' train_losses')
plt.plot(range(1, epoch+2), total_val_loss, label='val_losses')
plt.xlabel('Epoch')
plt.ylabel('LOSS')
plt.legend()
plt.title('Train and Validation losses Over Epochs')
plt.show()

# %%
def visualize_predictions(model, loader, device, num_images=5):
    model.eval()
    num_images_plotted = 0
    with torch.no_grad():
        for idx, (images, masks) in enumerate(loader):
            images = images.to(device)
            outputs = model(images)
            preds = torch.sigmoid(outputs) > 0.5
            preds = preds.cpu().numpy()
            masks = masks.cpu().numpy()

            for i in range(images.size(0)):
                plt.figure()
                plt.subplot(1, 3, 1)
                plt.imshow(images[i].permute(1, 2, 0).cpu())
                plt.title('Input Image')

                plt.subplot(1, 3, 2)
                plt.imshow(masks[i][0], cmap='gray')
                plt.title('Ground Truth')

                plt.subplot(1, 3, 3)
                plt.imshow(preds[i].transpose(1, 2, 0), cmap='gray')
                plt.title('Prediction')

                plt.show()
                print(i)

                num_images_plotted += i 
                if i+1 >= num_images:
                    break
            
            if idx+1 >= num_images or num_images_plotted >= num_images:
                break

# Visualize predictions on the validation set
visualize_predictions(model, val_loader, device, num_images=5)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
weight_file = 'RESULTS/MODEL_01/MODEL_01_RUN_10.pth'
MODEL.load_state_dict(torch.load(weight_file, map_location=device))
MODEL.to(device)
MODEL.eval()
# Out:
# UNet(
#   (enc1): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#   )
#   (enc2): Sequential(
#     (0): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#   )
#   (enc3): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#   )
#   (enc4): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#   )
#   (bottleneck): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#   )
#   (upconv4): ConvTranspose2d(256, 128, kernel_size=(2, 2), stride=(2, 2))
#   (dec4): Sequential(
#     (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#   )
#   (upconv3): ConvTranspose2d(128, 64, kernel_size=(2, 2), stride=(2, 2))
#   (dec3): Sequential(
#     (0): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#   )
#   (upconv2): ConvTranspose2d(64, 32, kernel_size=(2, 2), stride=(2, 2))
#   (dec2): Sequential(
#     (0): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#   )
#   (upconv1): ConvTranspose2d(32, 16, kernel_size=(2, 2), stride=(2, 2))
#   (dec1): Sequential(
#     (0): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#   )
#   (final_conv): Conv2d(16, 1, kernel_size=(1, 1), stride=(1, 1))
# )

# %%
import matplotlib.pyplot as plt
import torch

def visualize_predictions(model, loader, device, num_images=5):
    model.eval()
    num_images_plotted = 0
    with torch.no_grad():
        for idx, (images, masks) in enumerate(loader):
            images = images.to(device)
            outputs = model(images)
            preds = torch.sigmoid(outputs) > 0.5
            preds = preds.cpu().numpy()
            masks = masks.cpu().numpy()

            for i in range(images.size(0)):
                plt.figure(figsize=(10, 4))

                # Plot input image
                plt.subplot(1, 3, 1)
                img = images[i].cpu()
                if img.shape[0] == 1:
                    img = img.repeat(3, 1, 1)  # Convert grayscale to RGB
                plt.imshow(img.permute(1, 2, 0))
                plt.title('Input Image', fontsize=10)
                plt.axis('off')

                # Ground truth
                plt.subplot(1, 3, 2)
                plt.imshow(masks[i][0], cmap='gray')
                plt.title('Ground Truth', fontsize=10)
                plt.axis('off')

                # Prediction
                plt.subplot(1, 3, 3)
                plt.imshow(preds[i][0], cmap='gray')
                plt.title('Prediction', fontsize=10)
                plt.axis('off')

                plt.tight_layout()
                plt.show()

                num_images_plotted += 1
                if num_images_plotted >= num_images:
                    return
visualize_predictions(MODEL, val_loader, device, num_images=5)

# %% [markdown]
# # Testing after Training

# %%
# checkpoint_path

# %%
# MODEL.load_state_dict(torch.load(checkpoint_path, map_location=device))
# MODEL.eval()

# %%
# import torch
# import numpy as np
# from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, jaccard_score, accuracy_score, confusion_matrix

# # Function to calculate IoU
# def calculate_iou(pred, target):
#     intersection = (pred & target).sum()
#     union = (pred | target).sum()
#     iou = (intersection + 1e-6) / (union + 1e-6)  # Adding epsilon to avoid division by zero
#     return iou

# # Function to calculate Dice coefficient
# def calculate_dice(pred, target):
#     intersection = (pred & target).sum()
#     dice = (2 * intersection + 1e-6) / (pred.sum() + target.sum() + 1e-6)
#     return dice

# # Function to calculate specificity
# def calculate_specificity(pred, target):
#     tn, fp, fn, tp = confusion_matrix(target, pred).ravel()
#     specificity = tn / (tn + fp + 1e-6)  # Adding epsilon to avoid division by zero
#     return specificity

# # Loop through the validation dataset and calculate metrics
# all_precisions = []
# all_recalls = []
# all_f1_scores = []
# all_ious = []
# all_dice_scores = []
# all_sensitivities = []
# all_aucs = []
# all_jaccard_scores = []
# all_accuracies = []
# all_specificities = []

# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# MODEL.eval()  # Set the model to evaluation mode
# with torch.no_grad():
#     for batch in val_loader:
#         images, masks = batch
#         images = images.to(device)
#         masks = masks.to(device)
        
#         # Get predictions
#         outputs = MODEL(images)
#         preds = torch.sigmoid(outputs) > 0.5  # Thresholding at 0.5 for binary segmentation
#         preds = preds.int()
#         masks = masks.int()
        
#         # Flatten arrays for metric calculation
#         preds_np = preds.cpu().numpy().flatten()
#         masks_np = masks.cpu().numpy().flatten()
        
#         # Calculate metrics
#         iou = calculate_iou(preds_np, masks_np)
#         dice = calculate_dice(preds_np, masks_np)
#         precision = precision_score(masks_np, preds_np, zero_division=1)
#         recall = recall_score(masks_np, preds_np, zero_division=1)  # Sensitivity
#         f1 = f1_score(masks_np, preds_np, zero_division=1)
#         jaccard = jaccard_score(masks_np, preds_np, zero_division=1)
#         accuracy = accuracy_score(masks_np, preds_np)
#         specificity = calculate_specificity(preds_np, masks_np)
        
#         # Calculate AUC (requires non-binary outputs)
#         auc = roc_auc_score(masks_np, torch.sigmoid(outputs).cpu().numpy().flatten())
        
#         # Append results
#         all_ious.append(iou)
#         all_dice_scores.append(dice)
#         all_precisions.append(precision)
#         all_recalls.append(recall)
#         all_f1_scores.append(f1)
#         all_sensitivities.append(recall)
#         all_aucs.append(auc)
#         all_jaccard_scores.append(jaccard)
#         all_accuracies.append(accuracy)
#         all_specificities.append(specificity)

# # Print average metrics
# print("Average IoU:", np.mean(all_ious))
# print("Average Dice Coefficient:", np.mean(all_dice_scores))
# print("Average Precision:", np.mean(all_precisions))
# print("Average Recall (Sensitivity):", np.mean(all_recalls))
# print("Average F1 Score:", np.mean(all_f1_scores))
# print("Average AUC:", np.mean(all_aucs))
# print("Average Jaccard Score:", np.mean(all_jaccard_scores))
# print("Average Accuracy:", np.mean(all_accuracies))
# print("Average Specificity:", np.mean(all_specificities))

# %%
import glob
import os
weight_files = sorted(glob.glob(os.path.join(folder_path, "*.pth")))
print(weight_files)
# Out:
# ['RESULTS/MODEL_02/MODEL_02_RUN_1.pth', 'RESULTS/MODEL_02/MODEL_02_RUN_10.pth', 'RESULTS/MODEL_02/MODEL_02_RUN_2.pth', 'RESULTS/MODEL_02/MODEL_02_RUN_3.pth', 'RESULTS/MODEL_02/MODEL_02_RUN_4.pth', 'RESULTS/MODEL_02/MODEL_02_RUN_5.pth', 'RESULTS/MODEL_02/MODEL_02_RUN_6.pth', 'RESULTS/MODEL_02/MODEL_02_RUN_7.pth', 'RESULTS/MODEL_02/MODEL_02_RUN_8.pth', 'RESULTS/MODEL_02/MODEL_02_RUN_9.pth']

# %%
import torch
import numpy as np
from sklearn.metrics import (precision_score, recall_score, f1_score,
                             roc_auc_score, jaccard_score, accuracy_score,
                             confusion_matrix)

# ------------------ Define Metric Functions ------------------
def calculate_iou(pred, target):
    intersection = (pred & target).sum()
    union = (pred | target).sum()
    iou = (intersection + 1e-6) / (union + 1e-6)  # Avoid division by zero
    return iou

def calculate_dice(pred, target):
    intersection = (pred & target).sum()
    dice = (2 * intersection + 1e-6) / (pred.sum() + target.sum() + 1e-6)
    return dice

def calculate_specificity(pred, target):
    # Compute confusion matrix values: tn, fp, fn, tp
    tn, fp, fn, tp = confusion_matrix(target, pred).ravel()
    specificity = tn / (tn + fp + 1e-6)
    return specificity

# ------------------ List of Weight Files ------------------
# Update the weight file names as needed.

weight_files = sorted(glob.glob(os.path.join(folder_path, "*.pth")))

# ------------------ Lists for Overall Metrics ------------------
all_weight_ious = []
all_weight_dice = []
all_weight_precisions = []
all_weight_recalls = []
all_weight_f1s = []
all_weight_aucs = []
all_weight_jaccard = []
all_weight_accuracies = []
all_weight_specificities = []

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

output_file = (f'{folder_path}evaluation_results.txt')
# Open a text file to store the results (this will overwrite any existing file)
with open(output_file, "w") as outfile:
    # Loop through each weight file
    for idx, weight_file in enumerate(weight_files, start=1):
        # Load the weights into the model
        MODEL.load_state_dict(torch.load(weight_file, map_location=device))
        MODEL.to(device)
        MODEL.eval()  # Set the model to evaluation mode

        # Temporary lists for current weight file (per-batch metrics)
        batch_ious = []
        batch_dice = []
        batch_precisions = []
        batch_recalls = []
        batch_f1s = []
        batch_aucs = []
        batch_jaccard = []
        batch_accuracies = []
        batch_specificities = []

        with torch.no_grad():
            for batch in val_loader:
                images, masks = batch
                images = images.to(device)
                masks = masks.to(device)

                # Get model outputs and predictions
                outputs = MODEL(images)
                preds = torch.sigmoid(outputs) > 0.5  # Threshold at 0.5
                preds = preds.int()
                masks = masks.int()

                # Flatten for metric computation
                preds_np = preds.cpu().numpy().flatten()
                masks_np = masks.cpu().numpy().flatten()

                # Calculate metrics for the current batch
                iou = calculate_iou(preds_np, masks_np)
                dice = calculate_dice(preds_np, masks_np)
                precision = precision_score(masks_np, preds_np, zero_division=1)
                recall = recall_score(masks_np, preds_np, zero_division=1)  # Sensitivity
                f1 = f1_score(masks_np, preds_np, zero_division=1)
                jaccard = jaccard_score(masks_np, preds_np, zero_division=1)
                accuracy = accuracy_score(masks_np, preds_np)
                specificity = calculate_specificity(preds_np, masks_np)
                # For AUC, use continuous sigmoid outputs without thresholding
                auc = roc_auc_score(masks_np, torch.sigmoid(outputs).cpu().numpy().flatten())

                # Append current batch metrics
                batch_ious.append(iou)
                batch_dice.append(dice)
                batch_precisions.append(precision)
                batch_recalls.append(recall)
                batch_f1s.append(f1)
                batch_aucs.append(auc)
                batch_jaccard.append(jaccard)
                batch_accuracies.append(accuracy)
                batch_specificities.append(specificity)

        # Compute average metrics for the current weight file
        avg_iou = np.mean(batch_ious)
        avg_dice = np.mean(batch_dice)
        avg_precision = np.mean(batch_precisions)
        avg_recall = np.mean(batch_recalls)
        avg_f1 = np.mean(batch_f1s)
        avg_auc = np.mean(batch_aucs)
        avg_jaccard = np.mean(batch_jaccard)
        avg_accuracy = np.mean(batch_accuracies)
        avg_specificity = np.mean(batch_specificities)

        # Create an output string for the current weight file
        output_str = f"Weight File {idx} ({weight_file}):\n"
        output_str += f"  Average IoU: {avg_iou:.4f}\n"
        output_str += f"  Average Dice Coefficient: {avg_dice:.4f}\n"
        output_str += f"  Average Precision: {avg_precision:.4f}\n"
        output_str += f"  Average Recall (Sensitivity): {avg_recall:.4f}\n"
        output_str += f"  Average F1 Score: {avg_f1:.4f}\n"
        output_str += f"  Average AUC: {avg_auc:.4f}\n"
        output_str += f"  Average Jaccard Score: {avg_jaccard:.4f}\n"
        output_str += f"  Average Accuracy: {avg_accuracy:.4f}\n"
        output_str += f"  Average Specificity: {avg_specificity:.4f}\n\n"

        # Print to console and write to file
        print(output_str)
        outfile.write(output_str)

        # Append current averages to overall lists
        all_weight_ious.append(avg_iou)
        all_weight_dice.append(avg_dice)
        all_weight_precisions.append(avg_precision)
        all_weight_recalls.append(avg_recall)
        all_weight_f1s.append(avg_f1)
        all_weight_aucs.append(avg_auc)
        all_weight_jaccard.append(avg_jaccard)
        all_weight_accuracies.append(avg_accuracy)
        all_weight_specificities.append(avg_specificity)

    # ------------------ Overall Statistics ------------------
    overall_str = "Overall Metrics Across All Weight Files:\n"
    overall_str += f"Mean IoU: {np.mean(all_weight_ious):.4f}, Std IoU: {np.std(all_weight_ious):.4f}\n"
    overall_str += f"Mean Dice Coefficient: {np.mean(all_weight_dice):.4f}, Std Dice: {np.std(all_weight_dice):.4f}\n"
    overall_str += f"Mean Precision: {np.mean(all_weight_precisions):.4f}, Std Precision: {np.std(all_weight_precisions):.4f}\n"
    overall_str += f"Mean Recall (Sensitivity): {np.mean(all_weight_recalls):.4f}, Std Recall: {np.std(all_weight_recalls):.4f}\n"
    overall_str += f"Mean F1 Score: {np.mean(all_weight_f1s):.4f}, Std F1: {np.std(all_weight_f1s):.4f}\n"
    overall_str += f"Mean AUC: {np.mean(all_weight_aucs):.4f}, Std AUC: {np.std(all_weight_aucs):.4f}\n"
    overall_str += f"Mean Jaccard Score: {np.mean(all_weight_jaccard):.4f}, Std Jaccard: {np.std(all_weight_jaccard):.4f}\n"
    overall_str += f"Mean Accuracy: {np.mean(all_weight_accuracies):.4f}, Std Accuracy: {np.std(all_weight_accuracies):.4f}\n"
    overall_str += f"Mean Specificity: {np.mean(all_weight_specificities):.4f}, Std Specificity: {np.std(all_weight_specificities):.4f}\n"

    print(overall_str)
    outfile.write(overall_str)
# Out:
# Weight File 1 (RESULTS/MODEL_02/MODEL_02_RUN_1.pth):
#   Average IoU: 0.5405
#   Average Dice Coefficient: 0.7011
#   Average Precision: 0.5706
#   Average Recall (Sensitivity): 0.9127
#   Average F1 Score: 0.7011
#   Average AUC: 0.9854
#   Average Jaccard Score: 0.5405
#   Average Accuracy: 0.9594
#   Average Specificity: 0.9621
#
#
# Weight File 2 (RESULTS/MODEL_02/MODEL_02_RUN_10.pth):
#   Average IoU: 0.5350
#   Average Dice Coefficient: 0.6963
#   Average Precision: 0.5622
#   Average Recall (Sensitivity): 0.9182
#   Average F1 Score: 0.6963
#   Average AUC: 0.9859
#   Average Jaccard Score: 0.5350
#   Average Accuracy: 0.9583
#   Average Specificity: 0.9605
#
#
# Weight File 3 (RESULTS/MODEL_02/MODEL_02_RUN_2.pth):
#   Average IoU: 0.5478
#   Average Dice Coefficient: 0.7071
#   Average Precision: 0.5722
#   Average Recall (Sensitivity): 0.9285
#   Average F1 Score: 0.7071
#   Average AUC: 0.9878
#   Average Jaccard Score: 0.5478
#   Average Accuracy: 0.9599
#   Average Specificity: 0.9617
#
#
# Weight File 4 (RESULTS/MODEL_02/MODEL_02_RUN_3.pth):
#   Average IoU: 0.5371
#   Average Dice Coefficient: 0.6982
#   Average Precision: 0.5660
#   Average Recall (Sensitivity): 0.9145
#   Average F1 Score: 0.6982
#   Average AUC: 0.9858
#   Average Jaccard Score: 0.5371
#   Average Accuracy: 0.9588
#   Average Specificity: 0.9613
#
#
# Weight File 5 (RESULTS/MODEL_02/MODEL_02_RUN_4.pth):
#   Average IoU: 0.5361
#   Average Dice Coefficient: 0.6972
#   Average Precision: 0.5575
#   Average Recall (Sensitivity): 0.9340
#   Average F1 Score: 0.6972
#   Average AUC: 0.9880
#   Average Jaccard Score: 0.5361
#   Average Accuracy: 0.9577
#   Average Specificity: 0.9591
#
#
# Weight File 6 (RESULTS/MODEL_02/MODEL_02_RUN_5.pth):
#   Average IoU: 0.5400
#   Average Dice Coefficient: 0.7005
#   Average Precision: 0.5611
#   Average Recall (Sensitivity): 0.9353
#   Average F1 Score: 0.7005
#   Average AUC: 0.9874
#   Average Jaccard Score: 0.5400
#   Average Accuracy: 0.9583
#   Average Specificity: 0.9596
#
#
# Weight File 7 (RESULTS/MODEL_02/MODEL_02_RUN_6.pth):
#   Average IoU: 0.5361
#   Average Dice Coefficient: 0.6973
#   Average Precision: 0.5612
#   Average Recall (Sensitivity): 0.9240
#   Average F1 Score: 0.6973
#   Average AUC: 0.9858
#   Average Jaccard Score: 0.5361
#   Average Accuracy: 0.9582
#   Average Specificity: 0.9601
#
#
# Weight File 8 (RESULTS/MODEL_02/MODEL_02_RUN_7.pth):
#   Average IoU: 0.5257
#   Average Dice Coefficient: 0.6884
#   Average Precision: 0.5494
#   Average Recall (Sensitivity): 0.9253
#   Average F1 Score: 0.6884
#   Average AUC: 0.9842
#   Average Jaccard Score: 0.5257
#   Average Accuracy: 0.9563
#   Average Specificity: 0.9581
#
#
# Weight File 9 (RESULTS/MODEL_02/MODEL_02_RUN_8.pth):
#   Average IoU: 0.5376
#   Average Dice Coefficient: 0.6987
#   Average Precision: 0.5636
#   Average Recall (Sensitivity): 0.9223
#   Average F1 Score: 0.6987
#   Average AUC: 0.9867
#   Average Jaccard Score: 0.5376
#   Average Accuracy: 0.9585
#   Average Specificity: 0.9606
#
#
# Weight File 10 (RESULTS/MODEL_02/MODEL_02_RUN_9.pth):
#   Average IoU: 0.5330
#   Average Dice Coefficient: 0.6948
#   Average Precision: 0.5613
#   Average Recall (Sensitivity): 0.9147
#   Average F1 Score: 0.6948
#   Average AUC: 0.9821
#   Average Jaccard Score: 0.5330
#   Average Accuracy: 0.9581
#   Average Specificity: 0.9606
#
#
# Overall Metrics Across All Weight Files:
# Mean IoU: 0.5369, Std IoU: 0.0054
# Mean Dice Coefficient: 0.6980, Std Dice: 0.0045
# Mean Precision: 0.5625, Std Precision: 0.0061
# Mean Recall (Sensitivity): 0.9230, Std Recall: 0.0076
# Mean F1 Score: 0.6980, Std F1: 0.0045
# Mean AUC: 0.9859, Std AUC: 0.0017
# Mean Jaccard Score: 0.5369, Std Jaccard: 0.0054
# Mean Accuracy: 0.9584, Std Accuracy: 0.0009
# Mean Specificity: 0.9604, Std Specificity: 0.0011
